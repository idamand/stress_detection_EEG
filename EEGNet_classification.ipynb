# %%
from prepare_data import prepare_data
from classifiers import EEGNet_classifier

# %%
train_data, train_labels, test_data, test_labels, val_data, val_labels = prepare_data('raw', 'STAI')
# Out:
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# ERROR:root:Failed to read data for recording P006_S002_001
# ERROR:root:Failed to read data for recording P006_S002_002
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74912
#     Range : 0 ... 74911 =      0.000 ...   299.644 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74944
#     Range : 0 ... 74943 =      0.000 ...   299.772 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74912
#     Range : 0 ... 74911 =      0.000 ...   299.644 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74896
#     Range : 0 ... 74895 =      0.000 ...   299.580 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74960
#     Range : 0 ... 74959 =      0.000 ...   299.836 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# ERROR:root:Failed to read data for recording P028_S002_001
# ERROR:root:Failed to read data for recording P028_S002_002
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74912
#     Range : 0 ... 74911 =      0.000 ...   299.644 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74944
#     Range : 0 ... 74943 =      0.000 ...   299.772 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74912
#     Range : 0 ... 74911 =      0.000 ...   299.644 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74896
#     Range : 0 ... 74895 =      0.000 ...   299.580 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74960
#     Range : 0 ... 74959 =      0.000 ...   299.836 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 59 events and 1251 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 59 events and 1251 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 59 events and 1251 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 59 events and 1251 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 59 events and 1251 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Subjects test:  ['P011', 'P020', 'P015', 'P014', 'P008', 'P009']
#  Subjects train:  ['P016', 'P006', 'P019', 'P022', 'P018', 'P002', 'P013', 'P027', 'P004', 'P028', 'P003', 'P024', 'P007', 'P017', 'P026', 'P023']
#  Subjects val:  ['P021', 'P005', 'P025', 'P010', 'P001', 'P012']
# Shape of train data set: (3540, 8, 1251)
# Shape of train labels set: (3540, 1)
# Shape of test data set: (1416, 8, 1251)
# Shape of test labels set: (1416, 1)
# Shape of validation data set: (1416, 8, 1251)
# Shape of validation labels set: (1416, 1)

# %%
probs_eeg = EEGNet_classifier(train_data, test_data, val_data, train_labels, test_labels, val_labels)
# Out:
# Epoch 1/300
#
# Epoch 1: val_loss improved from inf to 0.68036, saving model to /tmp/checkpoint.h5
# 56/56 - 5s - loss: 0.5735 - accuracy: 0.7102 - val_loss: 0.6804 - val_accuracy: 0.6250 - 5s/epoch - 93ms/step
# Epoch 2/300
#
# Epoch 2: val_loss improved from 0.68036 to 0.66738, saving model to /tmp/checkpoint.h5
# 56/56 - 4s - loss: 0.5142 - accuracy: 0.7559 - val_loss: 0.6674 - val_accuracy: 0.6250 - 4s/epoch - 79ms/step
# Epoch 3/300
#
# Epoch 3: val_loss improved from 0.66738 to 0.65999, saving model to /tmp/checkpoint.h5
# 56/56 - 4s - loss: 0.4640 - accuracy: 0.7624 - val_loss: 0.6600 - val_accuracy: 0.6250 - 4s/epoch - 79ms/step
# Epoch 4/300
#
# Epoch 4: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.3975 - accuracy: 0.8085 - val_loss: 0.6782 - val_accuracy: 0.6250 - 4s/epoch - 78ms/step
# Epoch 5/300
#
# Epoch 5: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.3810 - accuracy: 0.8266 - val_loss: 0.6997 - val_accuracy: 0.6250 - 4s/epoch - 78ms/step
# Epoch 6/300
#
# Epoch 6: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.3535 - accuracy: 0.8412 - val_loss: 0.7287 - val_accuracy: 0.6151 - 4s/epoch - 80ms/step
# Epoch 7/300
#
# Epoch 7: val_loss did not improve from 0.65999
# 56/56 - 5s - loss: 0.3257 - accuracy: 0.8576 - val_loss: 0.7994 - val_accuracy: 0.6370 - 5s/epoch - 84ms/step
# Epoch 8/300
#
# Epoch 8: val_loss did not improve from 0.65999
# 56/56 - 5s - loss: 0.3053 - accuracy: 0.8695 - val_loss: 0.9797 - val_accuracy: 0.5840 - 5s/epoch - 83ms/step
# Epoch 9/300
#
# Epoch 9: val_loss did not improve from 0.65999
# 56/56 - 5s - loss: 0.2828 - accuracy: 0.8785 - val_loss: 1.1122 - val_accuracy: 0.5480 - 5s/epoch - 84ms/step
# Epoch 10/300
#
# Epoch 10: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.2699 - accuracy: 0.8893 - val_loss: 1.2926 - val_accuracy: 0.4760 - 4s/epoch - 78ms/step
# Epoch 11/300
#
# Epoch 11: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.2591 - accuracy: 0.8912 - val_loss: 1.6772 - val_accuracy: 0.4167 - 4s/epoch - 79ms/step
# Epoch 12/300
#
# Epoch 12: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.2393 - accuracy: 0.9037 - val_loss: 2.1110 - val_accuracy: 0.4167 - 4s/epoch - 78ms/step
# Epoch 13/300
#
# Epoch 13: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.2283 - accuracy: 0.9054 - val_loss: 1.9340 - val_accuracy: 0.4266 - 4s/epoch - 79ms/step
# Epoch 14/300
#
# Epoch 14: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.2293 - accuracy: 0.9062 - val_loss: 1.8283 - val_accuracy: 0.4386 - 4s/epoch - 78ms/step
# Epoch 15/300
#
# Epoch 15: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.2084 - accuracy: 0.9203 - val_loss: 1.9841 - val_accuracy: 0.4562 - 4s/epoch - 79ms/step
# Epoch 16/300
#
# Epoch 16: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1972 - accuracy: 0.9198 - val_loss: 1.9800 - val_accuracy: 0.4647 - 4s/epoch - 78ms/step
# Epoch 17/300
#
# Epoch 17: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.2037 - accuracy: 0.9127 - val_loss: 2.0990 - val_accuracy: 0.4273 - 4s/epoch - 79ms/step
# Epoch 18/300
#
# Epoch 18: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1881 - accuracy: 0.9251 - val_loss: 1.8391 - val_accuracy: 0.5219 - 4s/epoch - 79ms/step
# Epoch 19/300
#
# Epoch 19: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1830 - accuracy: 0.9288 - val_loss: 2.0195 - val_accuracy: 0.4668 - 4s/epoch - 78ms/step
# Epoch 20/300
#
# Epoch 20: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1946 - accuracy: 0.9169 - val_loss: 2.0971 - val_accuracy: 0.4484 - 4s/epoch - 79ms/step
# Epoch 21/300
#
# Epoch 21: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1764 - accuracy: 0.9226 - val_loss: 2.4915 - val_accuracy: 0.4456 - 4s/epoch - 79ms/step
# Epoch 22/300
#
# Epoch 22: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1781 - accuracy: 0.9206 - val_loss: 1.9670 - val_accuracy: 0.5466 - 4s/epoch - 79ms/step
# Epoch 23/300
#
# Epoch 23: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1747 - accuracy: 0.9314 - val_loss: 2.0166 - val_accuracy: 0.5205 - 4s/epoch - 78ms/step
# Epoch 24/300
#
# Epoch 24: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1647 - accuracy: 0.9308 - val_loss: 2.4589 - val_accuracy: 0.5212 - 4s/epoch - 78ms/step
# Epoch 25/300
#
# Epoch 25: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1586 - accuracy: 0.9308 - val_loss: 2.4220 - val_accuracy: 0.4908 - 4s/epoch - 78ms/step
# Epoch 26/300
#
# Epoch 26: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1588 - accuracy: 0.9333 - val_loss: 2.4352 - val_accuracy: 0.5268 - 4s/epoch - 79ms/step
# Epoch 27/300
#
# Epoch 27: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1604 - accuracy: 0.9285 - val_loss: 2.7039 - val_accuracy: 0.4555 - 4s/epoch - 78ms/step
# Epoch 28/300
#
# Epoch 28: val_loss did not improve from 0.65999
# 56/56 - 5s - loss: 0.1520 - accuracy: 0.9387 - val_loss: 2.4526 - val_accuracy: 0.4590 - 5s/epoch - 81ms/step
# Epoch 29/300
#
# Epoch 29: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1668 - accuracy: 0.9271 - val_loss: 2.2930 - val_accuracy: 0.5360 - 4s/epoch - 75ms/step
# Epoch 30/300
#
# Epoch 30: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1603 - accuracy: 0.9291 - val_loss: 2.4617 - val_accuracy: 0.4972 - 4s/epoch - 75ms/step
# Epoch 31/300
#
# Epoch 31: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1568 - accuracy: 0.9308 - val_loss: 2.7305 - val_accuracy: 0.4831 - 4s/epoch - 75ms/step
# Epoch 32/300
#
# Epoch 32: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1530 - accuracy: 0.9362 - val_loss: 2.8832 - val_accuracy: 0.4562 - 4s/epoch - 75ms/step
# Epoch 33/300
#
# Epoch 33: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1475 - accuracy: 0.9393 - val_loss: 2.3575 - val_accuracy: 0.5099 - 4s/epoch - 75ms/step
# Epoch 34/300
#
# Epoch 34: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1521 - accuracy: 0.9331 - val_loss: 2.5342 - val_accuracy: 0.5071 - 4s/epoch - 77ms/step
# Epoch 35/300
#
# Epoch 35: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1572 - accuracy: 0.9291 - val_loss: 2.7557 - val_accuracy: 0.4301 - 4s/epoch - 75ms/step
# Epoch 36/300
#
# Epoch 36: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1462 - accuracy: 0.9364 - val_loss: 2.6762 - val_accuracy: 0.4753 - 4s/epoch - 77ms/step
# Epoch 37/300
#
# Epoch 37: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1471 - accuracy: 0.9319 - val_loss: 2.4800 - val_accuracy: 0.5657 - 4s/epoch - 78ms/step
# Epoch 38/300
#
# Epoch 38: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1395 - accuracy: 0.9395 - val_loss: 2.4726 - val_accuracy: 0.5473 - 4s/epoch - 75ms/step
# Epoch 39/300
#
# Epoch 39: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1381 - accuracy: 0.9393 - val_loss: 2.7484 - val_accuracy: 0.5191 - 4s/epoch - 75ms/step
# Epoch 40/300
#
# Epoch 40: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1398 - accuracy: 0.9441 - val_loss: 2.6103 - val_accuracy: 0.5671 - 4s/epoch - 75ms/step
# Epoch 41/300
#
# Epoch 41: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1383 - accuracy: 0.9410 - val_loss: 2.4381 - val_accuracy: 0.5339 - 4s/epoch - 77ms/step
# Epoch 42/300
#
# Epoch 42: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1308 - accuracy: 0.9432 - val_loss: 2.8721 - val_accuracy: 0.5325 - 4s/epoch - 78ms/step
# Epoch 43/300
#
# Epoch 43: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1458 - accuracy: 0.9384 - val_loss: 2.6211 - val_accuracy: 0.5339 - 4s/epoch - 76ms/step
# Epoch 44/300
#
# Epoch 44: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1382 - accuracy: 0.9427 - val_loss: 2.8356 - val_accuracy: 0.5332 - 4s/epoch - 75ms/step
# Epoch 45/300
#
# Epoch 45: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1278 - accuracy: 0.9432 - val_loss: 2.7103 - val_accuracy: 0.6229 - 4s/epoch - 78ms/step
# Epoch 46/300
#
# Epoch 46: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1313 - accuracy: 0.9435 - val_loss: 3.0114 - val_accuracy: 0.5162 - 4s/epoch - 79ms/step
# Epoch 47/300
#
# Epoch 47: val_loss did not improve from 0.65999
# 56/56 - 5s - loss: 0.1299 - accuracy: 0.9446 - val_loss: 2.5126 - val_accuracy: 0.6045 - 5s/epoch - 84ms/step
# Epoch 48/300
#
# Epoch 48: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1330 - accuracy: 0.9449 - val_loss: 2.8645 - val_accuracy: 0.4590 - 4s/epoch - 79ms/step
# Epoch 49/300
#
# Epoch 49: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1297 - accuracy: 0.9446 - val_loss: 2.8916 - val_accuracy: 0.5148 - 4s/epoch - 78ms/step
# Epoch 50/300
#
# Epoch 50: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1230 - accuracy: 0.9528 - val_loss: 2.4694 - val_accuracy: 0.5445 - 4s/epoch - 80ms/step
# Epoch 51/300
#
# Epoch 51: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1368 - accuracy: 0.9424 - val_loss: 2.8434 - val_accuracy: 0.4901 - 4s/epoch - 78ms/step
# Epoch 52/300
#
# Epoch 52: val_loss did not improve from 0.65999
# 56/56 - 5s - loss: 0.1143 - accuracy: 0.9548 - val_loss: 3.0596 - val_accuracy: 0.5508 - 5s/epoch - 82ms/step
# Epoch 53/300
#
# Epoch 53: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1245 - accuracy: 0.9506 - val_loss: 2.7598 - val_accuracy: 0.5600 - 4s/epoch - 80ms/step
# Epoch 54/300
#
# Epoch 54: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1264 - accuracy: 0.9412 - val_loss: 2.7936 - val_accuracy: 0.6066 - 4s/epoch - 76ms/step
# Epoch 55/300
#
# Epoch 55: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1174 - accuracy: 0.9503 - val_loss: 2.8888 - val_accuracy: 0.5388 - 4s/epoch - 76ms/step
# Epoch 56/300
#
# Epoch 56: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1152 - accuracy: 0.9520 - val_loss: 2.9685 - val_accuracy: 0.5706 - 4s/epoch - 77ms/step
# Epoch 57/300
#
# Epoch 57: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1180 - accuracy: 0.9483 - val_loss: 2.7959 - val_accuracy: 0.5282 - 4s/epoch - 76ms/step
# Epoch 58/300
#
# Epoch 58: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1163 - accuracy: 0.9508 - val_loss: 3.1675 - val_accuracy: 0.5360 - 4s/epoch - 78ms/step
# Epoch 59/300
#
# Epoch 59: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1057 - accuracy: 0.9565 - val_loss: 2.9226 - val_accuracy: 0.5537 - 4s/epoch - 75ms/step
# Epoch 60/300
#
# Epoch 60: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1042 - accuracy: 0.9525 - val_loss: 2.9751 - val_accuracy: 0.5847 - 4s/epoch - 77ms/step
# Epoch 61/300
#
# Epoch 61: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1166 - accuracy: 0.9573 - val_loss: 3.0180 - val_accuracy: 0.6250 - 4s/epoch - 77ms/step
# Epoch 62/300
#
# Epoch 62: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1131 - accuracy: 0.9554 - val_loss: 2.5294 - val_accuracy: 0.6201 - 4s/epoch - 76ms/step
# Epoch 63/300
#
# Epoch 63: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1168 - accuracy: 0.9494 - val_loss: 3.1518 - val_accuracy: 0.4972 - 4s/epoch - 78ms/step
# Epoch 64/300
#
# Epoch 64: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1048 - accuracy: 0.9602 - val_loss: 3.1356 - val_accuracy: 0.5720 - 4s/epoch - 77ms/step
# Epoch 65/300
#
# Epoch 65: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1053 - accuracy: 0.9571 - val_loss: 3.3135 - val_accuracy: 0.5169 - 4s/epoch - 77ms/step
# Epoch 66/300
#
# Epoch 66: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1145 - accuracy: 0.9520 - val_loss: 3.1814 - val_accuracy: 0.5403 - 4s/epoch - 76ms/step
# Epoch 67/300
#
# Epoch 67: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0964 - accuracy: 0.9621 - val_loss: 2.7312 - val_accuracy: 0.5233 - 4s/epoch - 75ms/step
# Epoch 68/300
#
# Epoch 68: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1099 - accuracy: 0.9525 - val_loss: 3.1310 - val_accuracy: 0.5445 - 4s/epoch - 79ms/step
# Epoch 69/300
#
# Epoch 69: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0993 - accuracy: 0.9607 - val_loss: 2.9403 - val_accuracy: 0.5678 - 4s/epoch - 79ms/step
# Epoch 70/300
#
# Epoch 70: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1013 - accuracy: 0.9593 - val_loss: 3.1163 - val_accuracy: 0.5141 - 4s/epoch - 75ms/step
# Epoch 71/300
#
# Epoch 71: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1029 - accuracy: 0.9579 - val_loss: 3.0203 - val_accuracy: 0.5247 - 4s/epoch - 76ms/step
# Epoch 72/300
#
# Epoch 72: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0982 - accuracy: 0.9636 - val_loss: 3.4297 - val_accuracy: 0.4364 - 4s/epoch - 75ms/step
# Epoch 73/300
#
# Epoch 73: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0989 - accuracy: 0.9621 - val_loss: 3.5428 - val_accuracy: 0.4661 - 4s/epoch - 75ms/step
# Epoch 74/300
#
# Epoch 74: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0957 - accuracy: 0.9613 - val_loss: 3.4390 - val_accuracy: 0.4816 - 4s/epoch - 75ms/step
# Epoch 75/300
#
# Epoch 75: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0957 - accuracy: 0.9593 - val_loss: 3.4533 - val_accuracy: 0.4993 - 4s/epoch - 76ms/step
# Epoch 76/300
#
# Epoch 76: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1027 - accuracy: 0.9579 - val_loss: 3.1599 - val_accuracy: 0.5374 - 4s/epoch - 75ms/step
# Epoch 77/300
#
# Epoch 77: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1015 - accuracy: 0.9588 - val_loss: 3.5849 - val_accuracy: 0.4816 - 4s/epoch - 75ms/step
# Epoch 78/300
#
# Epoch 78: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0849 - accuracy: 0.9653 - val_loss: 3.1416 - val_accuracy: 0.5381 - 4s/epoch - 75ms/step
# Epoch 79/300
#
# Epoch 79: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0850 - accuracy: 0.9675 - val_loss: 3.2738 - val_accuracy: 0.5395 - 4s/epoch - 78ms/step
# Epoch 80/300
#
# Epoch 80: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0929 - accuracy: 0.9644 - val_loss: 3.6563 - val_accuracy: 0.5099 - 4s/epoch - 76ms/step
# Epoch 81/300
#
# Epoch 81: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0913 - accuracy: 0.9621 - val_loss: 3.3386 - val_accuracy: 0.5304 - 4s/epoch - 75ms/step
# Epoch 82/300
#
# Epoch 82: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0899 - accuracy: 0.9655 - val_loss: 2.9209 - val_accuracy: 0.4958 - 4s/epoch - 78ms/step
# Epoch 83/300
#
# Epoch 83: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1030 - accuracy: 0.9579 - val_loss: 3.0769 - val_accuracy: 0.5212 - 4s/epoch - 75ms/step
# Epoch 84/300
#
# Epoch 84: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0942 - accuracy: 0.9613 - val_loss: 2.9719 - val_accuracy: 0.5071 - 4s/epoch - 76ms/step
# Epoch 85/300
#
# Epoch 85: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1003 - accuracy: 0.9548 - val_loss: 3.2505 - val_accuracy: 0.5784 - 4s/epoch - 77ms/step
# Epoch 86/300
#
# Epoch 86: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0867 - accuracy: 0.9698 - val_loss: 3.4443 - val_accuracy: 0.5367 - 4s/epoch - 78ms/step
# Epoch 87/300
#
# Epoch 87: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0929 - accuracy: 0.9624 - val_loss: 3.6750 - val_accuracy: 0.5092 - 4s/epoch - 77ms/step
# Epoch 88/300
#
# Epoch 88: val_loss did not improve from 0.65999
# 56/56 - 5s - loss: 0.0849 - accuracy: 0.9669 - val_loss: 3.3555 - val_accuracy: 0.5275 - 5s/epoch - 81ms/step
# Epoch 89/300
#
# Epoch 89: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0751 - accuracy: 0.9709 - val_loss: 3.5624 - val_accuracy: 0.5346 - 4s/epoch - 78ms/step
# Epoch 90/300
#
# Epoch 90: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0848 - accuracy: 0.9658 - val_loss: 3.6472 - val_accuracy: 0.5353 - 4s/epoch - 78ms/step
# Epoch 91/300
#
# Epoch 91: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.1007 - accuracy: 0.9534 - val_loss: 3.6102 - val_accuracy: 0.5219 - 4s/epoch - 78ms/step
# Epoch 92/300
#
# Epoch 92: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0755 - accuracy: 0.9703 - val_loss: 3.2839 - val_accuracy: 0.5367 - 4s/epoch - 78ms/step
# Epoch 93/300
#
# Epoch 93: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0815 - accuracy: 0.9669 - val_loss: 3.8067 - val_accuracy: 0.5226 - 4s/epoch - 78ms/step
# Epoch 94/300
#
# Epoch 94: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0801 - accuracy: 0.9684 - val_loss: 3.4684 - val_accuracy: 0.5494 - 4s/epoch - 78ms/step
# Epoch 95/300
#
# Epoch 95: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0939 - accuracy: 0.9610 - val_loss: 3.0047 - val_accuracy: 0.4993 - 4s/epoch - 78ms/step
# Epoch 96/300
#
# Epoch 96: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0751 - accuracy: 0.9720 - val_loss: 3.4204 - val_accuracy: 0.5353 - 4s/epoch - 78ms/step
# Epoch 97/300
#
# Epoch 97: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0840 - accuracy: 0.9664 - val_loss: 3.4727 - val_accuracy: 0.5374 - 4s/epoch - 78ms/step
# Epoch 98/300
#
# Epoch 98: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0768 - accuracy: 0.9726 - val_loss: 3.5098 - val_accuracy: 0.5275 - 4s/epoch - 78ms/step
# Epoch 99/300
#
# Epoch 99: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0939 - accuracy: 0.9653 - val_loss: 3.2929 - val_accuracy: 0.5833 - 4s/epoch - 78ms/step
# Epoch 100/300
#
# Epoch 100: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0822 - accuracy: 0.9641 - val_loss: 3.6388 - val_accuracy: 0.5565 - 4s/epoch - 78ms/step
# Epoch 101/300
#
# Epoch 101: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0917 - accuracy: 0.9644 - val_loss: 4.0172 - val_accuracy: 0.4513 - 4s/epoch - 78ms/step
# Epoch 102/300
#
# Epoch 102: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0777 - accuracy: 0.9712 - val_loss: 3.4251 - val_accuracy: 0.5579 - 4s/epoch - 79ms/step
# Epoch 103/300
#
# Epoch 103: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0853 - accuracy: 0.9669 - val_loss: 3.5133 - val_accuracy: 0.5261 - 4s/epoch - 78ms/step
# Epoch 104/300
#
# Epoch 104: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0903 - accuracy: 0.9647 - val_loss: 3.5973 - val_accuracy: 0.5374 - 4s/epoch - 78ms/step
# Epoch 105/300
#
# Epoch 105: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0829 - accuracy: 0.9661 - val_loss: 3.7081 - val_accuracy: 0.5431 - 4s/epoch - 78ms/step
# Epoch 106/300
#
# Epoch 106: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0732 - accuracy: 0.9720 - val_loss: 4.0209 - val_accuracy: 0.5184 - 4s/epoch - 78ms/step
# Epoch 107/300
#
# Epoch 107: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0771 - accuracy: 0.9658 - val_loss: 3.9475 - val_accuracy: 0.5184 - 4s/epoch - 78ms/step
# Epoch 108/300
#
# Epoch 108: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0791 - accuracy: 0.9664 - val_loss: 2.9476 - val_accuracy: 0.5304 - 4s/epoch - 78ms/step
# Epoch 109/300
#
# Epoch 109: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0764 - accuracy: 0.9689 - val_loss: 3.8054 - val_accuracy: 0.5049 - 4s/epoch - 79ms/step
# Epoch 110/300
#
# Epoch 110: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0711 - accuracy: 0.9729 - val_loss: 4.1107 - val_accuracy: 0.5247 - 4s/epoch - 78ms/step
# Epoch 111/300
#
# Epoch 111: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0692 - accuracy: 0.9712 - val_loss: 3.9527 - val_accuracy: 0.5417 - 4s/epoch - 78ms/step
# Epoch 112/300
#
# Epoch 112: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0725 - accuracy: 0.9723 - val_loss: 3.9627 - val_accuracy: 0.5275 - 4s/epoch - 78ms/step
# Epoch 113/300
#
# Epoch 113: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0797 - accuracy: 0.9695 - val_loss: 3.4610 - val_accuracy: 0.5833 - 4s/epoch - 78ms/step
# Epoch 114/300
#
# Epoch 114: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0731 - accuracy: 0.9729 - val_loss: 3.8804 - val_accuracy: 0.5516 - 4s/epoch - 78ms/step
# Epoch 115/300
#
# Epoch 115: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0734 - accuracy: 0.9732 - val_loss: 3.7292 - val_accuracy: 0.5756 - 4s/epoch - 78ms/step
# Epoch 116/300
#
# Epoch 116: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0679 - accuracy: 0.9760 - val_loss: 4.5900 - val_accuracy: 0.5099 - 4s/epoch - 79ms/step
# Epoch 117/300
#
# Epoch 117: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0699 - accuracy: 0.9737 - val_loss: 3.7881 - val_accuracy: 0.5304 - 4s/epoch - 78ms/step
# Epoch 118/300
#
# Epoch 118: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0628 - accuracy: 0.9777 - val_loss: 3.7780 - val_accuracy: 0.5523 - 4s/epoch - 78ms/step
# Epoch 119/300
#
# Epoch 119: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0622 - accuracy: 0.9754 - val_loss: 3.4815 - val_accuracy: 0.5544 - 4s/epoch - 78ms/step
# Epoch 120/300
#
# Epoch 120: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0828 - accuracy: 0.9678 - val_loss: 4.7733 - val_accuracy: 0.4788 - 4s/epoch - 78ms/step
# Epoch 121/300
#
# Epoch 121: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0737 - accuracy: 0.9723 - val_loss: 3.8317 - val_accuracy: 0.5487 - 4s/epoch - 78ms/step
# Epoch 122/300
#
# Epoch 122: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0806 - accuracy: 0.9669 - val_loss: 3.4621 - val_accuracy: 0.5028 - 4s/epoch - 78ms/step
# Epoch 123/300
#
# Epoch 123: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0707 - accuracy: 0.9754 - val_loss: 3.9413 - val_accuracy: 0.5706 - 4s/epoch - 78ms/step
# Epoch 124/300
#
# Epoch 124: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0707 - accuracy: 0.9729 - val_loss: 4.3079 - val_accuracy: 0.5106 - 4s/epoch - 78ms/step
# Epoch 125/300
#
# Epoch 125: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0695 - accuracy: 0.9732 - val_loss: 4.0083 - val_accuracy: 0.5480 - 4s/epoch - 78ms/step
# Epoch 126/300
#
# Epoch 126: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0740 - accuracy: 0.9678 - val_loss: 4.1193 - val_accuracy: 0.4936 - 4s/epoch - 78ms/step
# Epoch 127/300
#
# Epoch 127: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0903 - accuracy: 0.9638 - val_loss: 4.2255 - val_accuracy: 0.4774 - 4s/epoch - 78ms/step
# Epoch 128/300
#
# Epoch 128: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0797 - accuracy: 0.9703 - val_loss: 3.9093 - val_accuracy: 0.5487 - 4s/epoch - 78ms/step
# Epoch 129/300
#
# Epoch 129: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0681 - accuracy: 0.9740 - val_loss: 4.0153 - val_accuracy: 0.5424 - 4s/epoch - 78ms/step
# Epoch 130/300
#
# Epoch 130: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0748 - accuracy: 0.9698 - val_loss: 3.9857 - val_accuracy: 0.5360 - 4s/epoch - 78ms/step
# Epoch 131/300
#
# Epoch 131: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0653 - accuracy: 0.9734 - val_loss: 4.2456 - val_accuracy: 0.5134 - 4s/epoch - 79ms/step
# Epoch 132/300
#
# Epoch 132: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0569 - accuracy: 0.9788 - val_loss: 4.6867 - val_accuracy: 0.5240 - 4s/epoch - 78ms/step
# Epoch 133/300
#
# Epoch 133: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0632 - accuracy: 0.9751 - val_loss: 4.6441 - val_accuracy: 0.5000 - 4s/epoch - 78ms/step
# Epoch 134/300
#
# Epoch 134: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0791 - accuracy: 0.9720 - val_loss: 4.7615 - val_accuracy: 0.4951 - 4s/epoch - 78ms/step
# Epoch 135/300
#
# Epoch 135: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0697 - accuracy: 0.9718 - val_loss: 3.8973 - val_accuracy: 0.5727 - 4s/epoch - 78ms/step
# Epoch 136/300
#
# Epoch 136: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0582 - accuracy: 0.9763 - val_loss: 4.1107 - val_accuracy: 0.5127 - 4s/epoch - 78ms/step
# Epoch 137/300
#
# Epoch 137: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0561 - accuracy: 0.9816 - val_loss: 3.7164 - val_accuracy: 0.5763 - 4s/epoch - 78ms/step
# Epoch 138/300
#
# Epoch 138: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0638 - accuracy: 0.9760 - val_loss: 4.1226 - val_accuracy: 0.5763 - 4s/epoch - 79ms/step
# Epoch 139/300
#
# Epoch 139: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0586 - accuracy: 0.9774 - val_loss: 3.4737 - val_accuracy: 0.5833 - 4s/epoch - 78ms/step
# Epoch 140/300
#
# Epoch 140: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0654 - accuracy: 0.9732 - val_loss: 4.4938 - val_accuracy: 0.5092 - 4s/epoch - 78ms/step
# Epoch 141/300
#
# Epoch 141: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0603 - accuracy: 0.9814 - val_loss: 3.7911 - val_accuracy: 0.5763 - 4s/epoch - 78ms/step
# Epoch 142/300
#
# Epoch 142: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0718 - accuracy: 0.9715 - val_loss: 4.5148 - val_accuracy: 0.5508 - 4s/epoch - 78ms/step
# Epoch 143/300
#
# Epoch 143: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0682 - accuracy: 0.9749 - val_loss: 4.1788 - val_accuracy: 0.5226 - 4s/epoch - 78ms/step
# Epoch 144/300
#
# Epoch 144: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0591 - accuracy: 0.9771 - val_loss: 4.2652 - val_accuracy: 0.5325 - 4s/epoch - 78ms/step
# Epoch 145/300
#
# Epoch 145: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0873 - accuracy: 0.9678 - val_loss: 5.4657 - val_accuracy: 0.4619 - 4s/epoch - 78ms/step
# Epoch 146/300
#
# Epoch 146: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0737 - accuracy: 0.9729 - val_loss: 4.6390 - val_accuracy: 0.5099 - 4s/epoch - 79ms/step
# Epoch 147/300
#
# Epoch 147: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0611 - accuracy: 0.9763 - val_loss: 4.3990 - val_accuracy: 0.5494 - 4s/epoch - 78ms/step
# Epoch 148/300
#
# Epoch 148: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0681 - accuracy: 0.9757 - val_loss: 4.3283 - val_accuracy: 0.4795 - 4s/epoch - 79ms/step
# Epoch 149/300
#
# Epoch 149: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0658 - accuracy: 0.9754 - val_loss: 4.5705 - val_accuracy: 0.4732 - 4s/epoch - 78ms/step
# Epoch 150/300
#
# Epoch 150: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0600 - accuracy: 0.9794 - val_loss: 4.1493 - val_accuracy: 0.5106 - 4s/epoch - 78ms/step
# Epoch 151/300
#
# Epoch 151: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0600 - accuracy: 0.9774 - val_loss: 4.5971 - val_accuracy: 0.5417 - 4s/epoch - 78ms/step
# Epoch 152/300
#
# Epoch 152: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0652 - accuracy: 0.9766 - val_loss: 4.1808 - val_accuracy: 0.5431 - 4s/epoch - 78ms/step
# Epoch 153/300
#
# Epoch 153: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0651 - accuracy: 0.9746 - val_loss: 4.3128 - val_accuracy: 0.5452 - 4s/epoch - 78ms/step
# Epoch 154/300
#
# Epoch 154: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0518 - accuracy: 0.9799 - val_loss: 4.3505 - val_accuracy: 0.5049 - 4s/epoch - 79ms/step
# Epoch 155/300
#
# Epoch 155: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0571 - accuracy: 0.9751 - val_loss: 4.2919 - val_accuracy: 0.5685 - 4s/epoch - 78ms/step
# Epoch 156/300
#
# Epoch 156: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0637 - accuracy: 0.9797 - val_loss: 4.1249 - val_accuracy: 0.5000 - 4s/epoch - 78ms/step
# Epoch 157/300
#
# Epoch 157: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0681 - accuracy: 0.9715 - val_loss: 3.8575 - val_accuracy: 0.5925 - 4s/epoch - 78ms/step
# Epoch 158/300
#
# Epoch 158: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0695 - accuracy: 0.9754 - val_loss: 3.9475 - val_accuracy: 0.5381 - 4s/epoch - 78ms/step
# Epoch 159/300
#
# Epoch 159: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0601 - accuracy: 0.9757 - val_loss: 4.3031 - val_accuracy: 0.4944 - 4s/epoch - 78ms/step
# Epoch 160/300
#
# Epoch 160: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0616 - accuracy: 0.9749 - val_loss: 4.5188 - val_accuracy: 0.5403 - 4s/epoch - 78ms/step
# Epoch 161/300
#
# Epoch 161: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0600 - accuracy: 0.9797 - val_loss: 4.3818 - val_accuracy: 0.5607 - 4s/epoch - 78ms/step
# Epoch 162/300
#
# Epoch 162: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0618 - accuracy: 0.9760 - val_loss: 4.0342 - val_accuracy: 0.5473 - 4s/epoch - 79ms/step
# Epoch 163/300
#
# Epoch 163: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0505 - accuracy: 0.9833 - val_loss: 4.1819 - val_accuracy: 0.5417 - 4s/epoch - 78ms/step
# Epoch 164/300
#
# Epoch 164: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0565 - accuracy: 0.9780 - val_loss: 4.8104 - val_accuracy: 0.5417 - 4s/epoch - 78ms/step
# Epoch 165/300
#
# Epoch 165: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0617 - accuracy: 0.9799 - val_loss: 3.6974 - val_accuracy: 0.5325 - 4s/epoch - 78ms/step
# Epoch 166/300
#
# Epoch 166: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0548 - accuracy: 0.9831 - val_loss: 5.5351 - val_accuracy: 0.4668 - 4s/epoch - 78ms/step
# Epoch 167/300
#
# Epoch 167: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0590 - accuracy: 0.9763 - val_loss: 4.3836 - val_accuracy: 0.4944 - 4s/epoch - 78ms/step
# Epoch 168/300
#
# Epoch 168: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0672 - accuracy: 0.9729 - val_loss: 3.7917 - val_accuracy: 0.5671 - 4s/epoch - 78ms/step
# Epoch 169/300
#
# Epoch 169: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0565 - accuracy: 0.9782 - val_loss: 4.1388 - val_accuracy: 0.5699 - 4s/epoch - 79ms/step
# Epoch 170/300
#
# Epoch 170: val_loss did not improve from 0.65999
# 56/56 - 5s - loss: 0.0572 - accuracy: 0.9774 - val_loss: 4.4975 - val_accuracy: 0.5395 - 5s/epoch - 80ms/step
# Epoch 171/300
#
# Epoch 171: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0561 - accuracy: 0.9785 - val_loss: 4.0421 - val_accuracy: 0.5311 - 4s/epoch - 79ms/step
# Epoch 172/300
#
# Epoch 172: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0438 - accuracy: 0.9847 - val_loss: 4.2124 - val_accuracy: 0.5360 - 4s/epoch - 79ms/step
# Epoch 173/300
#
# Epoch 173: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0662 - accuracy: 0.9737 - val_loss: 4.8597 - val_accuracy: 0.5643 - 4s/epoch - 79ms/step
# Epoch 174/300
#
# Epoch 174: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0626 - accuracy: 0.9757 - val_loss: 4.3800 - val_accuracy: 0.5240 - 4s/epoch - 78ms/step
# Epoch 175/300
#
# Epoch 175: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0504 - accuracy: 0.9831 - val_loss: 4.6325 - val_accuracy: 0.5431 - 4s/epoch - 78ms/step
# Epoch 176/300
#
# Epoch 176: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0667 - accuracy: 0.9734 - val_loss: 4.4008 - val_accuracy: 0.5148 - 4s/epoch - 78ms/step
# Epoch 177/300
#
# Epoch 177: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0541 - accuracy: 0.9814 - val_loss: 4.3345 - val_accuracy: 0.5438 - 4s/epoch - 78ms/step
# Epoch 178/300
#
# Epoch 178: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0511 - accuracy: 0.9822 - val_loss: 5.1882 - val_accuracy: 0.5311 - 4s/epoch - 79ms/step
# Epoch 179/300
#
# Epoch 179: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0437 - accuracy: 0.9850 - val_loss: 3.9626 - val_accuracy: 0.5417 - 4s/epoch - 78ms/step
# Epoch 180/300
#
# Epoch 180: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0504 - accuracy: 0.9814 - val_loss: 4.4521 - val_accuracy: 0.5692 - 4s/epoch - 79ms/step
# Epoch 181/300
#
# Epoch 181: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0617 - accuracy: 0.9763 - val_loss: 4.3843 - val_accuracy: 0.5346 - 4s/epoch - 78ms/step
# Epoch 182/300
#
# Epoch 182: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0528 - accuracy: 0.9816 - val_loss: 4.8692 - val_accuracy: 0.4597 - 4s/epoch - 78ms/step
# Epoch 183/300
#
# Epoch 183: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0667 - accuracy: 0.9740 - val_loss: 5.4183 - val_accuracy: 0.4576 - 4s/epoch - 78ms/step
# Epoch 184/300
#
# Epoch 184: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0546 - accuracy: 0.9782 - val_loss: 4.7832 - val_accuracy: 0.5586 - 4s/epoch - 78ms/step
# Epoch 185/300
#
# Epoch 185: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0606 - accuracy: 0.9785 - val_loss: 4.3086 - val_accuracy: 0.5452 - 4s/epoch - 78ms/step
# Epoch 186/300
#
# Epoch 186: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0654 - accuracy: 0.9760 - val_loss: 4.9869 - val_accuracy: 0.5572 - 4s/epoch - 79ms/step
# Epoch 187/300
#
# Epoch 187: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0653 - accuracy: 0.9757 - val_loss: 3.5597 - val_accuracy: 0.5290 - 4s/epoch - 78ms/step
# Epoch 188/300
#
# Epoch 188: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0527 - accuracy: 0.9774 - val_loss: 4.1132 - val_accuracy: 0.5332 - 4s/epoch - 78ms/step
# Epoch 189/300
#
# Epoch 189: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0543 - accuracy: 0.9802 - val_loss: 4.5470 - val_accuracy: 0.5798 - 4s/epoch - 78ms/step
# Epoch 190/300
#
# Epoch 190: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0542 - accuracy: 0.9791 - val_loss: 4.3250 - val_accuracy: 0.5438 - 4s/epoch - 78ms/step
# Epoch 191/300
#
# Epoch 191: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0516 - accuracy: 0.9797 - val_loss: 5.3458 - val_accuracy: 0.5205 - 4s/epoch - 78ms/step
# Epoch 192/300
#
# Epoch 192: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0493 - accuracy: 0.9842 - val_loss: 5.7055 - val_accuracy: 0.5360 - 4s/epoch - 79ms/step
# Epoch 193/300
#
# Epoch 193: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0578 - accuracy: 0.9799 - val_loss: 4.6234 - val_accuracy: 0.5000 - 4s/epoch - 78ms/step
# Epoch 194/300
#
# Epoch 194: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0520 - accuracy: 0.9782 - val_loss: 3.1825 - val_accuracy: 0.5000 - 4s/epoch - 79ms/step
# Epoch 195/300
#
# Epoch 195: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0546 - accuracy: 0.9822 - val_loss: 4.6940 - val_accuracy: 0.4944 - 4s/epoch - 78ms/step
# Epoch 196/300
#
# Epoch 196: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0599 - accuracy: 0.9777 - val_loss: 5.4897 - val_accuracy: 0.4901 - 4s/epoch - 78ms/step
# Epoch 197/300
#
# Epoch 197: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0498 - accuracy: 0.9794 - val_loss: 5.9258 - val_accuracy: 0.4216 - 4s/epoch - 78ms/step
# Epoch 198/300
#
# Epoch 198: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0483 - accuracy: 0.9819 - val_loss: 4.0698 - val_accuracy: 0.5056 - 4s/epoch - 78ms/step
# Epoch 199/300
#
# Epoch 199: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0646 - accuracy: 0.9754 - val_loss: 5.1140 - val_accuracy: 0.4852 - 4s/epoch - 78ms/step
# Epoch 200/300
#
# Epoch 200: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0559 - accuracy: 0.9782 - val_loss: 4.4818 - val_accuracy: 0.5247 - 4s/epoch - 78ms/step
# Epoch 201/300
#
# Epoch 201: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0521 - accuracy: 0.9797 - val_loss: 5.1593 - val_accuracy: 0.4809 - 4s/epoch - 79ms/step
# Epoch 202/300
#
# Epoch 202: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0566 - accuracy: 0.9771 - val_loss: 5.0342 - val_accuracy: 0.5155 - 4s/epoch - 79ms/step
# Epoch 203/300
#
# Epoch 203: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0497 - accuracy: 0.9797 - val_loss: 4.2400 - val_accuracy: 0.5812 - 4s/epoch - 78ms/step
# Epoch 204/300
#
# Epoch 204: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0504 - accuracy: 0.9825 - val_loss: 4.2891 - val_accuracy: 0.5367 - 4s/epoch - 78ms/step
# Epoch 205/300
#
# Epoch 205: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0453 - accuracy: 0.9842 - val_loss: 5.7007 - val_accuracy: 0.5586 - 4s/epoch - 78ms/step
# Epoch 206/300
#
# Epoch 206: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0490 - accuracy: 0.9825 - val_loss: 5.4532 - val_accuracy: 0.5000 - 4s/epoch - 78ms/step
# Epoch 207/300
#
# Epoch 207: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0650 - accuracy: 0.9740 - val_loss: 5.5695 - val_accuracy: 0.4951 - 4s/epoch - 78ms/step
# Epoch 208/300
#
# Epoch 208: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0499 - accuracy: 0.9819 - val_loss: 5.0444 - val_accuracy: 0.4866 - 4s/epoch - 78ms/step
# Epoch 209/300
#
# Epoch 209: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0429 - accuracy: 0.9816 - val_loss: 5.6004 - val_accuracy: 0.5403 - 4s/epoch - 78ms/step
# Epoch 210/300
#
# Epoch 210: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0488 - accuracy: 0.9828 - val_loss: 5.3819 - val_accuracy: 0.5106 - 4s/epoch - 78ms/step
# Epoch 211/300
#
# Epoch 211: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0515 - accuracy: 0.9811 - val_loss: 6.2681 - val_accuracy: 0.4061 - 4s/epoch - 79ms/step
# Epoch 212/300
#
# Epoch 212: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0611 - accuracy: 0.9768 - val_loss: 5.8689 - val_accuracy: 0.5219 - 4s/epoch - 78ms/step
# Epoch 213/300
#
# Epoch 213: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0460 - accuracy: 0.9808 - val_loss: 5.5513 - val_accuracy: 0.4774 - 4s/epoch - 78ms/step
# Epoch 214/300
#
# Epoch 214: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0450 - accuracy: 0.9825 - val_loss: 5.6126 - val_accuracy: 0.4901 - 4s/epoch - 79ms/step
# Epoch 215/300
#
# Epoch 215: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0531 - accuracy: 0.9797 - val_loss: 6.0065 - val_accuracy: 0.4647 - 4s/epoch - 79ms/step
# Epoch 216/300
#
# Epoch 216: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0567 - accuracy: 0.9771 - val_loss: 4.5270 - val_accuracy: 0.5000 - 4s/epoch - 78ms/step
# Epoch 217/300
#
# Epoch 217: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0506 - accuracy: 0.9791 - val_loss: 5.3735 - val_accuracy: 0.5360 - 4s/epoch - 78ms/step
# Epoch 218/300
#
# Epoch 218: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0552 - accuracy: 0.9794 - val_loss: 5.7316 - val_accuracy: 0.5339 - 4s/epoch - 78ms/step
# Epoch 219/300
#
# Epoch 219: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0591 - accuracy: 0.9768 - val_loss: 4.6997 - val_accuracy: 0.5205 - 4s/epoch - 79ms/step
# Epoch 220/300
#
# Epoch 220: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0539 - accuracy: 0.9791 - val_loss: 6.0273 - val_accuracy: 0.5558 - 4s/epoch - 78ms/step
# Epoch 221/300
#
# Epoch 221: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0669 - accuracy: 0.9729 - val_loss: 3.3082 - val_accuracy: 0.5226 - 4s/epoch - 78ms/step
# Epoch 222/300
#
# Epoch 222: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0494 - accuracy: 0.9811 - val_loss: 3.6524 - val_accuracy: 0.5819 - 4s/epoch - 78ms/step
# Epoch 223/300
#
# Epoch 223: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0412 - accuracy: 0.9833 - val_loss: 4.5875 - val_accuracy: 0.5833 - 4s/epoch - 78ms/step
# Epoch 224/300
#
# Epoch 224: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0374 - accuracy: 0.9881 - val_loss: 5.0881 - val_accuracy: 0.5078 - 4s/epoch - 78ms/step
# Epoch 225/300
#
# Epoch 225: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0516 - accuracy: 0.9802 - val_loss: 4.9773 - val_accuracy: 0.4929 - 4s/epoch - 78ms/step
# Epoch 226/300
#
# Epoch 226: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0465 - accuracy: 0.9839 - val_loss: 5.2603 - val_accuracy: 0.5847 - 4s/epoch - 79ms/step
# Epoch 227/300
#
# Epoch 227: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0565 - accuracy: 0.9771 - val_loss: 4.2058 - val_accuracy: 0.5417 - 4s/epoch - 80ms/step
# Epoch 228/300
#
# Epoch 228: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0433 - accuracy: 0.9831 - val_loss: 4.4298 - val_accuracy: 0.5141 - 4s/epoch - 76ms/step
# Epoch 229/300
#
# Epoch 229: val_loss did not improve from 0.65999
# 56/56 - 10s - loss: 0.0470 - accuracy: 0.9828 - val_loss: 3.1235 - val_accuracy: 0.5607 - 10s/epoch - 173ms/step
# Epoch 230/300
#
# Epoch 230: val_loss did not improve from 0.65999
# 56/56 - 5s - loss: 0.0511 - accuracy: 0.9808 - val_loss: 5.2594 - val_accuracy: 0.5685 - 5s/epoch - 82ms/step
# Epoch 231/300
#
# Epoch 231: val_loss did not improve from 0.65999
# 56/56 - 5s - loss: 0.0536 - accuracy: 0.9814 - val_loss: 5.5446 - val_accuracy: 0.4760 - 5s/epoch - 82ms/step
# Epoch 232/300
#
# Epoch 232: val_loss did not improve from 0.65999
# 56/56 - 5s - loss: 0.0435 - accuracy: 0.9836 - val_loss: 5.3268 - val_accuracy: 0.4795 - 5s/epoch - 89ms/step
# Epoch 233/300
#
# Epoch 233: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0479 - accuracy: 0.9822 - val_loss: 4.4376 - val_accuracy: 0.6017 - 4s/epoch - 79ms/step
# Epoch 234/300
#
# Epoch 234: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0456 - accuracy: 0.9836 - val_loss: 5.5328 - val_accuracy: 0.5869 - 4s/epoch - 79ms/step
# Epoch 235/300
#
# Epoch 235: val_loss did not improve from 0.65999
# 56/56 - 5s - loss: 0.0406 - accuracy: 0.9845 - val_loss: 5.2951 - val_accuracy: 0.4922 - 5s/epoch - 90ms/step
# Epoch 236/300
#
# Epoch 236: val_loss did not improve from 0.65999
# 56/56 - 5s - loss: 0.0482 - accuracy: 0.9811 - val_loss: 5.1058 - val_accuracy: 0.4965 - 5s/epoch - 81ms/step
# Epoch 237/300
#
# Epoch 237: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0402 - accuracy: 0.9853 - val_loss: 5.5368 - val_accuracy: 0.5685 - 4s/epoch - 80ms/step
# Epoch 238/300
#
# Epoch 238: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0601 - accuracy: 0.9743 - val_loss: 4.0277 - val_accuracy: 0.6603 - 4s/epoch - 80ms/step
# Epoch 239/300
#
# Epoch 239: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0649 - accuracy: 0.9729 - val_loss: 4.1713 - val_accuracy: 0.5742 - 4s/epoch - 80ms/step
# Epoch 240/300
#
# Epoch 240: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0434 - accuracy: 0.9836 - val_loss: 3.9755 - val_accuracy: 0.5798 - 4s/epoch - 80ms/step
# Epoch 241/300
#
# Epoch 241: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0577 - accuracy: 0.9802 - val_loss: 5.2417 - val_accuracy: 0.5007 - 4s/epoch - 80ms/step
# Epoch 242/300
#
# Epoch 242: val_loss did not improve from 0.65999
# 56/56 - 5s - loss: 0.0395 - accuracy: 0.9853 - val_loss: 5.5928 - val_accuracy: 0.5184 - 5s/epoch - 88ms/step
# Epoch 243/300
#
# Epoch 243: val_loss did not improve from 0.65999
# 56/56 - 5s - loss: 0.0438 - accuracy: 0.9836 - val_loss: 5.5204 - val_accuracy: 0.5417 - 5s/epoch - 87ms/step
# Epoch 244/300
#
# Epoch 244: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0479 - accuracy: 0.9811 - val_loss: 4.6954 - val_accuracy: 0.5240 - 4s/epoch - 79ms/step
# Epoch 245/300
#
# Epoch 245: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0417 - accuracy: 0.9853 - val_loss: 4.0784 - val_accuracy: 0.4993 - 4s/epoch - 79ms/step
# Epoch 246/300
#
# Epoch 246: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0412 - accuracy: 0.9833 - val_loss: 4.8374 - val_accuracy: 0.4873 - 4s/epoch - 79ms/step
# Epoch 247/300
#
# Epoch 247: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0483 - accuracy: 0.9814 - val_loss: 6.2731 - val_accuracy: 0.4972 - 4s/epoch - 79ms/step
# Epoch 248/300
#
# Epoch 248: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0483 - accuracy: 0.9791 - val_loss: 5.0398 - val_accuracy: 0.5452 - 4s/epoch - 78ms/step
# Epoch 249/300
#
# Epoch 249: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0512 - accuracy: 0.9788 - val_loss: 5.2388 - val_accuracy: 0.4583 - 4s/epoch - 78ms/step
# Epoch 250/300
#
# Epoch 250: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0532 - accuracy: 0.9814 - val_loss: 6.1602 - val_accuracy: 0.5982 - 4s/epoch - 78ms/step
# Epoch 251/300
#
# Epoch 251: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0417 - accuracy: 0.9833 - val_loss: 5.2705 - val_accuracy: 0.5198 - 4s/epoch - 78ms/step
# Epoch 252/300
#
# Epoch 252: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0430 - accuracy: 0.9833 - val_loss: 5.2833 - val_accuracy: 0.5777 - 4s/epoch - 78ms/step
# Epoch 253/300
#
# Epoch 253: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0445 - accuracy: 0.9825 - val_loss: 4.4720 - val_accuracy: 0.5148 - 4s/epoch - 79ms/step
# Epoch 254/300
#
# Epoch 254: val_loss did not improve from 0.65999
# 56/56 - 5s - loss: 0.0638 - accuracy: 0.9726 - val_loss: 4.3943 - val_accuracy: 0.5833 - 5s/epoch - 84ms/step
# Epoch 255/300
#
# Epoch 255: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0465 - accuracy: 0.9839 - val_loss: 3.9823 - val_accuracy: 0.6278 - 4s/epoch - 79ms/step
# Epoch 256/300
#
# Epoch 256: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0492 - accuracy: 0.9814 - val_loss: 4.9217 - val_accuracy: 0.5833 - 4s/epoch - 79ms/step
# Epoch 257/300
#
# Epoch 257: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0495 - accuracy: 0.9825 - val_loss: 5.4248 - val_accuracy: 0.5833 - 4s/epoch - 78ms/step
# Epoch 258/300
#
# Epoch 258: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0472 - accuracy: 0.9831 - val_loss: 5.1503 - val_accuracy: 0.5127 - 4s/epoch - 78ms/step
# Epoch 259/300
#
# Epoch 259: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0501 - accuracy: 0.9814 - val_loss: 5.1697 - val_accuracy: 0.5650 - 4s/epoch - 78ms/step
# Epoch 260/300
#
# Epoch 260: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0476 - accuracy: 0.9831 - val_loss: 4.9891 - val_accuracy: 0.5198 - 4s/epoch - 78ms/step
# Epoch 261/300
#
# Epoch 261: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0379 - accuracy: 0.9850 - val_loss: 4.9935 - val_accuracy: 0.5332 - 4s/epoch - 78ms/step
# Epoch 262/300
#
# Epoch 262: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0361 - accuracy: 0.9847 - val_loss: 5.0690 - val_accuracy: 0.5014 - 4s/epoch - 78ms/step
# Epoch 263/300
#
# Epoch 263: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0466 - accuracy: 0.9819 - val_loss: 7.0014 - val_accuracy: 0.4442 - 4s/epoch - 78ms/step
# Epoch 264/300
#
# Epoch 264: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0493 - accuracy: 0.9794 - val_loss: 5.8712 - val_accuracy: 0.5671 - 4s/epoch - 79ms/step
# Epoch 265/300
#
# Epoch 265: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0354 - accuracy: 0.9859 - val_loss: 5.1156 - val_accuracy: 0.6208 - 4s/epoch - 78ms/step
# Epoch 266/300
#
# Epoch 266: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0551 - accuracy: 0.9794 - val_loss: 5.3198 - val_accuracy: 0.5763 - 4s/epoch - 78ms/step
# Epoch 267/300
#
# Epoch 267: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0434 - accuracy: 0.9847 - val_loss: 5.3621 - val_accuracy: 0.5353 - 4s/epoch - 78ms/step
# Epoch 268/300
#
# Epoch 268: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0578 - accuracy: 0.9774 - val_loss: 5.5974 - val_accuracy: 0.5791 - 4s/epoch - 78ms/step
# Epoch 269/300
#
# Epoch 269: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0440 - accuracy: 0.9833 - val_loss: 4.1854 - val_accuracy: 0.6363 - 4s/epoch - 78ms/step
# Epoch 270/300
#
# Epoch 270: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0604 - accuracy: 0.9766 - val_loss: 3.8999 - val_accuracy: 0.6271 - 4s/epoch - 78ms/step
# Epoch 271/300
#
# Epoch 271: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0511 - accuracy: 0.9788 - val_loss: 6.6624 - val_accuracy: 0.5565 - 4s/epoch - 79ms/step
# Epoch 272/300
#
# Epoch 272: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0428 - accuracy: 0.9816 - val_loss: 6.6936 - val_accuracy: 0.4153 - 4s/epoch - 78ms/step
# Epoch 273/300
#
# Epoch 273: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0396 - accuracy: 0.9845 - val_loss: 4.3817 - val_accuracy: 0.4965 - 4s/epoch - 78ms/step
# Epoch 274/300
#
# Epoch 274: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0422 - accuracy: 0.9833 - val_loss: 5.6986 - val_accuracy: 0.5537 - 4s/epoch - 78ms/step
# Epoch 275/300
#
# Epoch 275: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0349 - accuracy: 0.9898 - val_loss: 5.2175 - val_accuracy: 0.6215 - 4s/epoch - 78ms/step
# Epoch 276/300
#
# Epoch 276: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0437 - accuracy: 0.9836 - val_loss: 4.2404 - val_accuracy: 0.6335 - 4s/epoch - 78ms/step
# Epoch 277/300
#
# Epoch 277: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0358 - accuracy: 0.9884 - val_loss: 4.1101 - val_accuracy: 0.5452 - 4s/epoch - 78ms/step
# Epoch 278/300
#
# Epoch 278: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0407 - accuracy: 0.9847 - val_loss: 5.2557 - val_accuracy: 0.5968 - 4s/epoch - 79ms/step
# Epoch 279/300
#
# Epoch 279: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0345 - accuracy: 0.9873 - val_loss: 6.0257 - val_accuracy: 0.5459 - 4s/epoch - 78ms/step
# Epoch 280/300
#
# Epoch 280: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0377 - accuracy: 0.9870 - val_loss: 5.7462 - val_accuracy: 0.5579 - 4s/epoch - 78ms/step
# Epoch 281/300
#
# Epoch 281: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0627 - accuracy: 0.9780 - val_loss: 5.5666 - val_accuracy: 0.5113 - 4s/epoch - 78ms/step
# Epoch 282/300
#
# Epoch 282: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0460 - accuracy: 0.9856 - val_loss: 5.5492 - val_accuracy: 0.4583 - 4s/epoch - 78ms/step
# Epoch 283/300
#
# Epoch 283: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0377 - accuracy: 0.9836 - val_loss: 4.4800 - val_accuracy: 0.5833 - 4s/epoch - 78ms/step
# Epoch 284/300
#
# Epoch 284: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0373 - accuracy: 0.9862 - val_loss: 4.6699 - val_accuracy: 0.5417 - 4s/epoch - 78ms/step
# Epoch 285/300
#
# Epoch 285: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0374 - accuracy: 0.9859 - val_loss: 4.6729 - val_accuracy: 0.5494 - 4s/epoch - 78ms/step
# Epoch 286/300
#
# Epoch 286: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0414 - accuracy: 0.9845 - val_loss: 4.5546 - val_accuracy: 0.5438 - 4s/epoch - 78ms/step
# Epoch 287/300
#
# Epoch 287: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0485 - accuracy: 0.9814 - val_loss: 7.0029 - val_accuracy: 0.6116 - 4s/epoch - 79ms/step
# Epoch 288/300
#
# Epoch 288: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0454 - accuracy: 0.9828 - val_loss: 5.9665 - val_accuracy: 0.5523 - 4s/epoch - 78ms/step
# Epoch 289/300
#
# Epoch 289: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0404 - accuracy: 0.9842 - val_loss: 5.5574 - val_accuracy: 0.5233 - 4s/epoch - 78ms/step
# Epoch 290/300
#
# Epoch 290: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0436 - accuracy: 0.9833 - val_loss: 4.8844 - val_accuracy: 0.6081 - 4s/epoch - 78ms/step
# Epoch 291/300
#
# Epoch 291: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0407 - accuracy: 0.9859 - val_loss: 5.4848 - val_accuracy: 0.5812 - 4s/epoch - 78ms/step
# Epoch 292/300
#
# Epoch 292: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0396 - accuracy: 0.9856 - val_loss: 4.7649 - val_accuracy: 0.5833 - 4s/epoch - 78ms/step
# Epoch 293/300
#
# Epoch 293: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0369 - accuracy: 0.9845 - val_loss: 4.2306 - val_accuracy: 0.5671 - 4s/epoch - 78ms/step
# Epoch 294/300
#
# Epoch 294: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0421 - accuracy: 0.9876 - val_loss: 4.8275 - val_accuracy: 0.5339 - 4s/epoch - 78ms/step
# Epoch 295/300
#
# Epoch 295: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0410 - accuracy: 0.9853 - val_loss: 5.3123 - val_accuracy: 0.5346 - 4s/epoch - 79ms/step
# Epoch 296/300
#
# Epoch 296: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0441 - accuracy: 0.9816 - val_loss: 5.6069 - val_accuracy: 0.5042 - 4s/epoch - 78ms/step
# Epoch 297/300
#
# Epoch 297: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0497 - accuracy: 0.9811 - val_loss: 5.2977 - val_accuracy: 0.5516 - 4s/epoch - 79ms/step
# Epoch 298/300
#
# Epoch 298: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0322 - accuracy: 0.9873 - val_loss: 4.8762 - val_accuracy: 0.5254 - 4s/epoch - 78ms/step
# Epoch 299/300
#
# Epoch 299: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0472 - accuracy: 0.9799 - val_loss: 5.2329 - val_accuracy: 0.6229 - 4s/epoch - 78ms/step
# Epoch 300/300
#
# Epoch 300: val_loss did not improve from 0.65999
# 56/56 - 4s - loss: 0.0307 - accuracy: 0.9893 - val_loss: 5.3672 - val_accuracy: 0.5318 - 4s/epoch - 78ms/step
# 45/45 [==============================] - 0s 8ms/step
# Classification accuracy: 0.541667
# /Users/idaandreassen/opt/anaconda3/envs/mne/lib/python3.9/site-packages/pyriemann/utils/viz.py:24: RuntimeWarning: invalid value encountered in true_divide
#   cm = 100 * cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]
