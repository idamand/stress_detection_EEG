# %%
from prepare_data import prepare_data
from classifiers import EEGNet_classifier
# Out:
# c:\Users\Thomas\anaconda3\envs\mne\lib\site-packages\mne_features\utils.py:21: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @nb.jit()

# %%
epoch_duration  = 2
label_type      = 'STAI'
data_type       = 'decomp'

# %%
train_data, test_data, train_labels, test_labels = prepare_data(data_type=data_type, label_type=label_type, epoch_duration=epoch_duration)
# Out:
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# ...

# %%
EEGNet_classifier(train_data=train_data, test_data=test_data, train_labels=train_labels, test_labels=test_labels, epoch_duration=epoch_duration)
# Out:
# Epoch 1/300
#
# Epoch 1: val_loss improved from inf to 0.68668, saving model to /tmp\checkpoint.h5
# 147/147 - 9s - loss: 0.6879 - accuracy: 0.5614 - val_loss: 0.6867 - val_accuracy: 0.5596 - 9s/epoch - 63ms/step
# Epoch 2/300
#
# Epoch 2: val_loss improved from 0.68668 to 0.68644, saving model to /tmp\checkpoint.h5
# 147/147 - 8s - loss: 0.6861 - accuracy: 0.5644 - val_loss: 0.6864 - val_accuracy: 0.5596 - 8s/epoch - 56ms/step
# Epoch 3/300
#
# Epoch 3: val_loss did not improve from 0.68644
# 147/147 - 8s - loss: 0.6764 - accuracy: 0.5904 - val_loss: 0.7022 - val_accuracy: 0.4404 - 8s/epoch - 56ms/step
# Epoch 4/300
#
# Epoch 4: val_loss did not improve from 0.68644
# 147/147 - 8s - loss: 0.6685 - accuracy: 0.6037 - val_loss: 0.6893 - val_accuracy: 0.5631 - 8s/epoch - 56ms/step
# Epoch 5/300
#
# Epoch 5: val_loss did not improve from 0.68644
# 147/147 - 8s - loss: 0.6605 - accuracy: 0.6091 - val_loss: 0.6973 - val_accuracy: 0.5743 - 8s/epoch - 56ms/step
# Epoch 6/300
#
# ...
