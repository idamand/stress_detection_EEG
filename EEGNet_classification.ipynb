# %%
from prepare_data import prepare_data
from classifiers import EEGNet_classifier
# Out:
# c:\Users\Thomas\anaconda3\envs\mne\lib\site-packages\mne_features\utils.py:21: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @nb.jit()

# %%
epoch_duration  = 1
label_type      = 'PSS'
data_type       = 'decomp'

# %%
train_data, test_data, train_labels, test_labels = prepare_data(data_type=data_type, label_type=label_type, epoch_duration=epoch_duration)
# Out:
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# ERROR:root:Failed to read data for recording P006_S002_001
# ERROR:root:Failed to read data for recording P006_S002_002
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74912
#     Range : 0 ... 74911 =      0.000 ...   299.644 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74944
#     Range : 0 ... 74943 =      0.000 ...   299.772 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74912
#     Range : 0 ... 74911 =      0.000 ...   299.644 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74896
#     Range : 0 ... 74895 =      0.000 ...   299.580 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74960
#     Range : 0 ... 74959 =      0.000 ...   299.836 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# ERROR:root:Failed to read data for recording P028_S002_001
# ERROR:root:Failed to read data for recording P028_S002_002
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74912
#     Range : 0 ... 74911 =      0.000 ...   299.644 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74944
#     Range : 0 ... 74943 =      0.000 ...   299.772 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74912
#     Range : 0 ... 74911 =      0.000 ...   299.644 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74896
#     Range : 0 ... 74895 =      0.000 ...   299.580 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74960
#     Range : 0 ... 74959 =      0.000 ...   299.836 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 299 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 299 events and 251 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 299 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 299 events and 251 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 299 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 299 events and 251 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 299 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 299 events and 251 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 299 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 299 events and 251 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 300 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 300 events and 251 original time points ...
# 1 bad epochs dropped
# ---------------- CHOSEN FEATURE TYPE: None----------------
# ----- Shape of train data set: (25116, 8, 251) _________ Shape of train labels set: (25116,) -----
# ----- Shape of test data set:  (7176, 8, 251)  _________ Shape of test labels set:  (7176,)  -----

# %%
EEGNet_classifier(train_data=train_data, test_data=test_data, train_labels=train_labels, test_labels=test_labels, epoch_duration=epoch_duration)
# Out:
# Epoch 1/300
#
# Epoch 1: val_loss improved from inf to 0.68606, saving model to /tmp\checkpoint.h5
# 295/295 - 11s - loss: 0.6877 - accuracy: 0.5577 - val_loss: 0.6861 - val_accuracy: 0.5595 - 11s/epoch - 37ms/step
# Epoch 2/300
#
# Epoch 2: val_loss did not improve from 0.68606
# 295/295 - 10s - loss: 0.6862 - accuracy: 0.5595 - val_loss: 0.6875 - val_accuracy: 0.5593 - 10s/epoch - 33ms/step
# Epoch 3/300
#
# Epoch 3: val_loss did not improve from 0.68606
# 295/295 - 10s - loss: 0.6864 - accuracy: 0.5595 - val_loss: 0.6878 - val_accuracy: 0.5593 - 10s/epoch - 34ms/step
# Epoch 4/300
#
# Epoch 4: val_loss did not improve from 0.68606
# 295/295 - 10s - loss: 0.6863 - accuracy: 0.5595 - val_loss: 0.6881 - val_accuracy: 0.5585 - 10s/epoch - 34ms/step
# Epoch 5/300
#
# Epoch 5: val_loss did not improve from 0.68606
# 295/295 - 10s - loss: 0.6863 - accuracy: 0.5593 - val_loss: 0.6872 - val_accuracy: 0.5592 - 10s/epoch - 34ms/step
# Epoch 6/300
#
# Epoch 6: val_loss did not improve from 0.68606
# 295/295 - 10s - loss: 0.6860 - accuracy: 0.5601 - val_loss: 0.6879 - val_accuracy: 0.5585 - 10s/epoch - 34ms/step
# Epoch 7/300
#
# Epoch 7: val_loss did not improve from 0.68606
# 295/295 - 10s - loss: 0.6853 - accuracy: 0.5609 - val_loss: 0.7117 - val_accuracy: 0.5596 - 10s/epoch - 34ms/step
# Epoch 8/300
#
# Epoch 8: val_loss did not improve from 0.68606
# 295/295 - 10s - loss: 0.6833 - accuracy: 0.5647 - val_loss: 0.6925 - val_accuracy: 0.5593 - 10s/epoch - 34ms/step
# Epoch 9/300
#
# Epoch 9: val_loss did not improve from 0.68606
# 295/295 - 10s - loss: 0.6815 - accuracy: 0.5671 - val_loss: 0.6958 - val_accuracy: 0.5596 - 10s/epoch - 34ms/step
# Epoch 10/300
#
# Epoch 10: val_loss did not improve from 0.68606
# 295/295 - 10s - loss: 0.6816 - accuracy: 0.5661 - val_loss: 0.6891 - val_accuracy: 0.5596 - 10s/epoch - 34ms/step
# Epoch 11/300
#
# Epoch 11: val_loss did not improve from 0.68606
# 295/295 - 10s - loss: 0.6807 - accuracy: 0.5683 - val_loss: 0.7036 - val_accuracy: 0.5600 - 10s/epoch - 34ms/step
# Epoch 12/300
#
# Epoch 12: val_loss did not improve from 0.68606
# 295/295 - 10s - loss: 0.6809 - accuracy: 0.5651 - val_loss: 0.6864 - val_accuracy: 0.5600 - 10s/epoch - 34ms/step
# Epoch 13/300
#
# Epoch 13: val_loss did not improve from 0.68606
# 295/295 - 10s - loss: 0.6802 - accuracy: 0.5702 - val_loss: 0.6910 - val_accuracy: 0.5596 - 10s/epoch - 34ms/step
# Epoch 14/300
#
# Epoch 14: val_loss did not improve from 0.68606
# 295/295 - 10s - loss: 0.6801 - accuracy: 0.5721 - val_loss: 0.6863 - val_accuracy: 0.5592 - 10s/epoch - 34ms/step
# Epoch 15/300
#
# Epoch 15: val_loss did not improve from 0.68606
# 295/295 - 10s - loss: 0.6802 - accuracy: 0.5674 - val_loss: 0.6954 - val_accuracy: 0.5598 - 10s/epoch - 34ms/step
# Epoch 16/300
#
# Epoch 16: val_loss improved from 0.68606 to 0.68588, saving model to /tmp\checkpoint.h5
# 295/295 - 10s - loss: 0.6795 - accuracy: 0.5729 - val_loss: 0.6859 - val_accuracy: 0.5600 - 10s/epoch - 34ms/step
# Epoch 17/300
#
# Epoch 17: val_loss did not improve from 0.68588
# 295/295 - 10s - loss: 0.6788 - accuracy: 0.5733 - val_loss: 0.6875 - val_accuracy: 0.5603 - 10s/epoch - 34ms/step
# Epoch 18/300
#
# Epoch 18: val_loss did not improve from 0.68588
# 295/295 - 10s - loss: 0.6780 - accuracy: 0.5756 - val_loss: 0.6884 - val_accuracy: 0.5600 - 10s/epoch - 34ms/step
# Epoch 19/300
#
# Epoch 19: val_loss improved from 0.68588 to 0.68580, saving model to /tmp\checkpoint.h5
# 295/295 - 10s - loss: 0.6762 - accuracy: 0.5794 - val_loss: 0.6858 - val_accuracy: 0.5600 - 10s/epoch - 34ms/step
# Epoch 20/300
#
# Epoch 20: val_loss did not improve from 0.68580
# 295/295 - 10s - loss: 0.6755 - accuracy: 0.5829 - val_loss: 0.6957 - val_accuracy: 0.5600 - 10s/epoch - 34ms/step
# Epoch 21/300
#
# Epoch 21: val_loss did not improve from 0.68580
# 295/295 - 10s - loss: 0.6730 - accuracy: 0.5925 - val_loss: 0.6937 - val_accuracy: 0.5600 - 10s/epoch - 34ms/step
# Epoch 22/300
#
# Epoch 22: val_loss did not improve from 0.68580
# 295/295 - 10s - loss: 0.6723 - accuracy: 0.5921 - val_loss: 0.7576 - val_accuracy: 0.5596 - 10s/epoch - 34ms/step
# Epoch 23/300
#
# Epoch 23: val_loss did not improve from 0.68580
# 295/295 - 10s - loss: 0.6722 - accuracy: 0.5931 - val_loss: 0.6995 - val_accuracy: 0.5600 - 10s/epoch - 34ms/step
# Epoch 24/300
#
# Epoch 24: val_loss did not improve from 0.68580
# 295/295 - 10s - loss: 0.6678 - accuracy: 0.5994 - val_loss: 0.7044 - val_accuracy: 0.5604 - 10s/epoch - 34ms/step
# Epoch 25/300
#
# Epoch 25: val_loss did not improve from 0.68580
# 295/295 - 10s - loss: 0.6674 - accuracy: 0.5980 - val_loss: 0.7711 - val_accuracy: 0.5596 - 10s/epoch - 34ms/step
# Epoch 26/300
#
# Epoch 26: val_loss did not improve from 0.68580
# 295/295 - 10s - loss: 0.6675 - accuracy: 0.5998 - val_loss: 0.7062 - val_accuracy: 0.5601 - 10s/epoch - 34ms/step
# Epoch 27/300
#
# Epoch 27: val_loss did not improve from 0.68580
# 295/295 - 10s - loss: 0.6659 - accuracy: 0.6029 - val_loss: 0.6906 - val_accuracy: 0.5600 - 10s/epoch - 34ms/step
# Epoch 28/300
#
# Epoch 28: val_loss improved from 0.68580 to 0.68267, saving model to /tmp\checkpoint.h5
# 295/295 - 10s - loss: 0.6655 - accuracy: 0.6033 - val_loss: 0.6827 - val_accuracy: 0.5612 - 10s/epoch - 34ms/step
# Epoch 29/300
#
# Epoch 29: val_loss did not improve from 0.68267
# 295/295 - 10s - loss: 0.6638 - accuracy: 0.6060 - val_loss: 0.8568 - val_accuracy: 0.5600 - 10s/epoch - 34ms/step
# Epoch 30/300
#
# Epoch 30: val_loss did not improve from 0.68267
# 295/295 - 10s - loss: 0.6650 - accuracy: 0.6049 - val_loss: 0.6841 - val_accuracy: 0.5612 - 10s/epoch - 34ms/step
# Epoch 31/300
#
# Epoch 31: val_loss did not improve from 0.68267
# 295/295 - 10s - loss: 0.6650 - accuracy: 0.6055 - val_loss: 0.7458 - val_accuracy: 0.5600 - 10s/epoch - 34ms/step
# Epoch 32/300
#
# Epoch 32: val_loss did not improve from 0.68267
# 295/295 - 10s - loss: 0.6643 - accuracy: 0.6087 - val_loss: 0.7788 - val_accuracy: 0.5598 - 10s/epoch - 34ms/step
# Epoch 33/300
#
# Epoch 33: val_loss did not improve from 0.68267
# 295/295 - 10s - loss: 0.6612 - accuracy: 0.6100 - val_loss: 0.7183 - val_accuracy: 0.5603 - 10s/epoch - 34ms/step
# Epoch 34/300
#
# Epoch 34: val_loss improved from 0.68267 to 0.68158, saving model to /tmp\checkpoint.h5
# 295/295 - 10s - loss: 0.6624 - accuracy: 0.6108 - val_loss: 0.6816 - val_accuracy: 0.5655 - 10s/epoch - 34ms/step
# Epoch 35/300
#
# Epoch 35: val_loss did not improve from 0.68158
# 295/295 - 10s - loss: 0.6626 - accuracy: 0.6091 - val_loss: 0.6977 - val_accuracy: 0.5609 - 10s/epoch - 34ms/step
# Epoch 36/300
#
# Epoch 36: val_loss improved from 0.68158 to 0.68130, saving model to /tmp\checkpoint.h5
# 295/295 - 10s - loss: 0.6619 - accuracy: 0.6102 - val_loss: 0.6813 - val_accuracy: 0.5622 - 10s/epoch - 34ms/step
# Epoch 37/300
#
# Epoch 37: val_loss did not improve from 0.68130
# 295/295 - 10s - loss: 0.6615 - accuracy: 0.6105 - val_loss: 0.6817 - val_accuracy: 0.5647 - 10s/epoch - 34ms/step
# Epoch 38/300
#
# Epoch 38: val_loss did not improve from 0.68130
# 295/295 - 10s - loss: 0.6622 - accuracy: 0.6061 - val_loss: 0.6971 - val_accuracy: 0.5601 - 10s/epoch - 34ms/step
# Epoch 39/300
#
# Epoch 39: val_loss did not improve from 0.68130
# 295/295 - 10s - loss: 0.6609 - accuracy: 0.6068 - val_loss: 0.7222 - val_accuracy: 0.5600 - 10s/epoch - 34ms/step
# Epoch 40/300
#
# Epoch 40: val_loss did not improve from 0.68130
# 295/295 - 10s - loss: 0.6604 - accuracy: 0.6125 - val_loss: 0.7076 - val_accuracy: 0.5598 - 10s/epoch - 34ms/step
# Epoch 41/300
#
# Epoch 41: val_loss did not improve from 0.68130
# 295/295 - 10s - loss: 0.6610 - accuracy: 0.6056 - val_loss: 0.7151 - val_accuracy: 0.5604 - 10s/epoch - 34ms/step
# Epoch 42/300
#
# Epoch 42: val_loss did not improve from 0.68130
# 295/295 - 10s - loss: 0.6605 - accuracy: 0.6126 - val_loss: 0.7033 - val_accuracy: 0.5603 - 10s/epoch - 34ms/step
# Epoch 43/300
#
# Epoch 43: val_loss did not improve from 0.68130
# 295/295 - 10s - loss: 0.6599 - accuracy: 0.6128 - val_loss: 0.7273 - val_accuracy: 0.5600 - 10s/epoch - 34ms/step
# Epoch 44/300
#
# Epoch 44: val_loss did not improve from 0.68130
# 295/295 - 10s - loss: 0.6582 - accuracy: 0.6142 - val_loss: 0.7091 - val_accuracy: 0.5600 - 10s/epoch - 34ms/step
# Epoch 45/300
#
# Epoch 45: val_loss did not improve from 0.68130
# 295/295 - 10s - loss: 0.6586 - accuracy: 0.6118 - val_loss: 0.6950 - val_accuracy: 0.5606 - 10s/epoch - 34ms/step
# Epoch 46/300
#
# Epoch 46: val_loss did not improve from 0.68130
# 295/295 - 10s - loss: 0.6572 - accuracy: 0.6166 - val_loss: 0.7102 - val_accuracy: 0.5601 - 10s/epoch - 34ms/step
# Epoch 47/300
#
# Epoch 47: val_loss did not improve from 0.68130
# 295/295 - 10s - loss: 0.6582 - accuracy: 0.6132 - val_loss: 0.7120 - val_accuracy: 0.5603 - 10s/epoch - 34ms/step
# Epoch 48/300
#
# Epoch 48: val_loss did not improve from 0.68130
# 295/295 - 10s - loss: 0.6588 - accuracy: 0.6123 - val_loss: 0.7877 - val_accuracy: 0.5600 - 10s/epoch - 34ms/step
# Epoch 49/300
#
# Epoch 49: val_loss did not improve from 0.68130
# 295/295 - 10s - loss: 0.6583 - accuracy: 0.6132 - val_loss: 0.7769 - val_accuracy: 0.5600 - 10s/epoch - 34ms/step
# Epoch 50/300
#
# Epoch 50: val_loss did not improve from 0.68130
# 295/295 - 10s - loss: 0.6582 - accuracy: 0.6176 - val_loss: 0.6816 - val_accuracy: 0.5651 - 10s/epoch - 34ms/step
# Epoch 51/300
#
# Epoch 51: val_loss improved from 0.68130 to 0.68059, saving model to /tmp\checkpoint.h5
# 295/295 - 10s - loss: 0.6575 - accuracy: 0.6150 - val_loss: 0.6806 - val_accuracy: 0.5819 - 10s/epoch - 34ms/step
# Epoch 52/300
#
# Epoch 52: val_loss did not improve from 0.68059
# 295/295 - 10s - loss: 0.6555 - accuracy: 0.6160 - val_loss: 0.7502 - val_accuracy: 0.5603 - 10s/epoch - 34ms/step
# Epoch 53/300
#
# Epoch 53: val_loss did not improve from 0.68059
# 295/295 - 10s - loss: 0.6573 - accuracy: 0.6137 - val_loss: 0.9062 - val_accuracy: 0.5600 - 10s/epoch - 34ms/step
# Epoch 54/300
#
# Epoch 54: val_loss did not improve from 0.68059
# 295/295 - 10s - loss: 0.6568 - accuracy: 0.6152 - val_loss: 0.7097 - val_accuracy: 0.5603 - 10s/epoch - 34ms/step
# Epoch 55/300
#
# Epoch 55: val_loss did not improve from 0.68059
# 295/295 - 10s - loss: 0.6562 - accuracy: 0.6154 - val_loss: 0.7308 - val_accuracy: 0.4572 - 10s/epoch - 34ms/step
# Epoch 56/300
#
# Epoch 56: val_loss did not improve from 0.68059
# 295/295 - 10s - loss: 0.6564 - accuracy: 0.6183 - val_loss: 0.6914 - val_accuracy: 0.5614 - 10s/epoch - 34ms/step
# Epoch 57/300
#
# Epoch 57: val_loss did not improve from 0.68059
# 295/295 - 10s - loss: 0.6578 - accuracy: 0.6143 - val_loss: 0.7116 - val_accuracy: 0.5603 - 10s/epoch - 34ms/step
# Epoch 58/300
#
# Epoch 58: val_loss did not improve from 0.68059
# 295/295 - 10s - loss: 0.6556 - accuracy: 0.6164 - val_loss: 0.7446 - val_accuracy: 0.5603 - 10s/epoch - 34ms/step
# Epoch 59/300
#
# Epoch 59: val_loss did not improve from 0.68059
# 295/295 - 10s - loss: 0.6562 - accuracy: 0.6161 - val_loss: 0.6871 - val_accuracy: 0.5611 - 10s/epoch - 34ms/step
# Epoch 60/300
#
# Epoch 60: val_loss did not improve from 0.68059
# 295/295 - 10s - loss: 0.6538 - accuracy: 0.6187 - val_loss: 0.7512 - val_accuracy: 0.5608 - 10s/epoch - 34ms/step
# Epoch 61/300
#
# Epoch 61: val_loss did not improve from 0.68059
# 295/295 - 10s - loss: 0.6580 - accuracy: 0.6116 - val_loss: 0.6809 - val_accuracy: 0.5689 - 10s/epoch - 34ms/step
# Epoch 62/300
#
# Epoch 62: val_loss did not improve from 0.68059
# 295/295 - 10s - loss: 0.6547 - accuracy: 0.6195 - val_loss: 0.6899 - val_accuracy: 0.5639 - 10s/epoch - 34ms/step
# Epoch 63/300
#
# Epoch 63: val_loss did not improve from 0.68059
# 295/295 - 10s - loss: 0.6564 - accuracy: 0.6182 - val_loss: 0.7414 - val_accuracy: 0.5609 - 10s/epoch - 34ms/step
# Epoch 64/300
#
# Epoch 64: val_loss did not improve from 0.68059
# 295/295 - 10s - loss: 0.6548 - accuracy: 0.6188 - val_loss: 0.6900 - val_accuracy: 0.5631 - 10s/epoch - 34ms/step
# Epoch 65/300
#
# Epoch 65: val_loss did not improve from 0.68059
# 295/295 - 10s - loss: 0.6537 - accuracy: 0.6169 - val_loss: 0.6899 - val_accuracy: 0.5625 - 10s/epoch - 34ms/step
# Epoch 66/300
#
# Epoch 66: val_loss did not improve from 0.68059
# 295/295 - 10s - loss: 0.6550 - accuracy: 0.6179 - val_loss: 0.7070 - val_accuracy: 0.5614 - 10s/epoch - 34ms/step
# Epoch 67/300
#
# Epoch 67: val_loss improved from 0.68059 to 0.67897, saving model to /tmp\checkpoint.h5
# 295/295 - 10s - loss: 0.6535 - accuracy: 0.6222 - val_loss: 0.6790 - val_accuracy: 0.5662 - 10s/epoch - 34ms/step
# Epoch 68/300
#
# Epoch 68: val_loss did not improve from 0.67897
# 295/295 - 10s - loss: 0.6530 - accuracy: 0.6212 - val_loss: 0.6800 - val_accuracy: 0.5682 - 10s/epoch - 34ms/step
# Epoch 69/300
#
# Epoch 69: val_loss did not improve from 0.67897
# 295/295 - 10s - loss: 0.6512 - accuracy: 0.6201 - val_loss: 0.6815 - val_accuracy: 0.5947 - 10s/epoch - 34ms/step
# Epoch 70/300
#
# Epoch 70: val_loss improved from 0.67897 to 0.67848, saving model to /tmp\checkpoint.h5
# 295/295 - 10s - loss: 0.6506 - accuracy: 0.6227 - val_loss: 0.6785 - val_accuracy: 0.5748 - 10s/epoch - 34ms/step
# Epoch 71/300
#
# Epoch 71: val_loss did not improve from 0.67848
# 295/295 - 10s - loss: 0.6513 - accuracy: 0.6233 - val_loss: 0.6870 - val_accuracy: 0.5396 - 10s/epoch - 34ms/step
# Epoch 72/300
#
# Epoch 72: val_loss did not improve from 0.67848
# 295/295 - 10s - loss: 0.6502 - accuracy: 0.6212 - val_loss: 0.6804 - val_accuracy: 0.5796 - 10s/epoch - 34ms/step
# Epoch 73/300
#
# Epoch 73: val_loss did not improve from 0.67848
# 295/295 - 10s - loss: 0.6516 - accuracy: 0.6214 - val_loss: 0.7105 - val_accuracy: 0.5630 - 10s/epoch - 34ms/step
# Epoch 74/300
#
# Epoch 74: val_loss did not improve from 0.67848
# 295/295 - 10s - loss: 0.6520 - accuracy: 0.6243 - val_loss: 0.6935 - val_accuracy: 0.5635 - 10s/epoch - 34ms/step
# Epoch 75/300
#
# Epoch 75: val_loss did not improve from 0.67848
# 295/295 - 10s - loss: 0.6506 - accuracy: 0.6259 - val_loss: 0.6872 - val_accuracy: 0.5518 - 10s/epoch - 34ms/step
# Epoch 76/300
#
# Epoch 76: val_loss did not improve from 0.67848
# 295/295 - 10s - loss: 0.6500 - accuracy: 0.6229 - val_loss: 0.7293 - val_accuracy: 0.5625 - 10s/epoch - 34ms/step
# Epoch 77/300
#
# Epoch 77: val_loss did not improve from 0.67848
# 295/295 - 10s - loss: 0.6498 - accuracy: 0.6270 - val_loss: 0.7016 - val_accuracy: 0.5624 - 10s/epoch - 34ms/step
# Epoch 78/300
#
# Epoch 78: val_loss did not improve from 0.67848
# 295/295 - 10s - loss: 0.6501 - accuracy: 0.6259 - val_loss: 0.6811 - val_accuracy: 0.5667 - 10s/epoch - 34ms/step
# Epoch 79/300
#
# Epoch 79: val_loss did not improve from 0.67848
# 295/295 - 10s - loss: 0.6513 - accuracy: 0.6252 - val_loss: 0.7098 - val_accuracy: 0.5609 - 10s/epoch - 34ms/step
# Epoch 80/300
#
# Epoch 80: val_loss did not improve from 0.67848
# 295/295 - 10s - loss: 0.6496 - accuracy: 0.6232 - val_loss: 0.7071 - val_accuracy: 0.5616 - 10s/epoch - 34ms/step
# Epoch 81/300
#
# Epoch 81: val_loss did not improve from 0.67848
# 295/295 - 10s - loss: 0.6501 - accuracy: 0.6288 - val_loss: 0.7602 - val_accuracy: 0.5617 - 10s/epoch - 34ms/step
# Epoch 82/300
#
# Epoch 82: val_loss did not improve from 0.67848
# 295/295 - 10s - loss: 0.6490 - accuracy: 0.6284 - val_loss: 0.6785 - val_accuracy: 0.5713 - 10s/epoch - 34ms/step
# Epoch 83/300
#
# Epoch 83: val_loss did not improve from 0.67848
# 295/295 - 10s - loss: 0.6507 - accuracy: 0.6259 - val_loss: 0.7012 - val_accuracy: 0.5627 - 10s/epoch - 34ms/step
# Epoch 84/300
#
# Epoch 84: val_loss did not improve from 0.67848
# 295/295 - 10s - loss: 0.6497 - accuracy: 0.6249 - val_loss: 0.6799 - val_accuracy: 0.5702 - 10s/epoch - 34ms/step
# Epoch 85/300
#
# Epoch 85: val_loss did not improve from 0.67848
# 295/295 - 10s - loss: 0.6494 - accuracy: 0.6253 - val_loss: 0.6806 - val_accuracy: 0.5692 - 10s/epoch - 34ms/step
# Epoch 86/300
#
# Epoch 86: val_loss did not improve from 0.67848
# 295/295 - 10s - loss: 0.6482 - accuracy: 0.6278 - val_loss: 0.6856 - val_accuracy: 0.5682 - 10s/epoch - 34ms/step
# Epoch 87/300
#
# Epoch 87: val_loss did not improve from 0.67848
# 295/295 - 10s - loss: 0.6492 - accuracy: 0.6235 - val_loss: 0.6833 - val_accuracy: 0.5993 - 10s/epoch - 34ms/step
# Epoch 88/300
#
# Epoch 88: val_loss improved from 0.67848 to 0.67612, saving model to /tmp\checkpoint.h5
# 295/295 - 10s - loss: 0.6487 - accuracy: 0.6261 - val_loss: 0.6761 - val_accuracy: 0.5829 - 10s/epoch - 34ms/step
# Epoch 89/300
#
# Epoch 89: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6506 - accuracy: 0.6218 - val_loss: 0.7341 - val_accuracy: 0.5617 - 10s/epoch - 34ms/step
# Epoch 90/300
#
# Epoch 90: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6492 - accuracy: 0.6272 - val_loss: 0.6789 - val_accuracy: 0.5821 - 10s/epoch - 34ms/step
# Epoch 91/300
#
# Epoch 91: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6494 - accuracy: 0.6251 - val_loss: 0.7206 - val_accuracy: 0.5635 - 10s/epoch - 34ms/step
# Epoch 92/300
#
# Epoch 92: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6480 - accuracy: 0.6299 - val_loss: 0.6821 - val_accuracy: 0.5684 - 10s/epoch - 34ms/step
# Epoch 93/300
#
# Epoch 93: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6511 - accuracy: 0.6213 - val_loss: 0.6798 - val_accuracy: 0.5684 - 10s/epoch - 34ms/step
# Epoch 94/300
#
# Epoch 94: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6494 - accuracy: 0.6244 - val_loss: 0.6826 - val_accuracy: 0.5716 - 10s/epoch - 34ms/step
# Epoch 95/300
#
# Epoch 95: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6491 - accuracy: 0.6255 - val_loss: 0.7586 - val_accuracy: 0.5608 - 10s/epoch - 34ms/step
# Epoch 96/300
#
# Epoch 96: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6492 - accuracy: 0.6257 - val_loss: 0.6763 - val_accuracy: 0.5767 - 10s/epoch - 34ms/step
# Epoch 97/300
#
# Epoch 97: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6489 - accuracy: 0.6246 - val_loss: 0.6773 - val_accuracy: 0.5692 - 10s/epoch - 34ms/step
# Epoch 98/300
#
# Epoch 98: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6492 - accuracy: 0.6275 - val_loss: 0.7303 - val_accuracy: 0.5627 - 10s/epoch - 34ms/step
# Epoch 99/300
#
# Epoch 99: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6483 - accuracy: 0.6261 - val_loss: 0.7890 - val_accuracy: 0.5617 - 10s/epoch - 34ms/step
# Epoch 100/300
#
# Epoch 100: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6505 - accuracy: 0.6210 - val_loss: 0.7019 - val_accuracy: 0.4437 - 10s/epoch - 34ms/step
# Epoch 101/300
#
# Epoch 101: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6499 - accuracy: 0.6279 - val_loss: 0.7546 - val_accuracy: 0.5624 - 10s/epoch - 34ms/step
# Epoch 102/300
#
# Epoch 102: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6476 - accuracy: 0.6294 - val_loss: 0.6796 - val_accuracy: 0.5729 - 10s/epoch - 34ms/step
# Epoch 103/300
#
# Epoch 103: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6501 - accuracy: 0.6262 - val_loss: 0.6940 - val_accuracy: 0.5203 - 10s/epoch - 34ms/step
# Epoch 104/300
#
# Epoch 104: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6468 - accuracy: 0.6290 - val_loss: 0.6773 - val_accuracy: 0.5756 - 10s/epoch - 34ms/step
# Epoch 105/300
#
# Epoch 105: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6486 - accuracy: 0.6269 - val_loss: 0.6818 - val_accuracy: 0.5870 - 10s/epoch - 34ms/step
# Epoch 106/300
#
# Epoch 106: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6483 - accuracy: 0.6279 - val_loss: 0.6982 - val_accuracy: 0.5655 - 10s/epoch - 34ms/step
# Epoch 107/300
#
# Epoch 107: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6490 - accuracy: 0.6274 - val_loss: 0.6875 - val_accuracy: 0.5639 - 10s/epoch - 34ms/step
# Epoch 108/300
#
# Epoch 108: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6475 - accuracy: 0.6302 - val_loss: 0.6800 - val_accuracy: 0.5733 - 10s/epoch - 34ms/step
# Epoch 109/300
#
# Epoch 109: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6462 - accuracy: 0.6318 - val_loss: 0.7081 - val_accuracy: 0.5644 - 10s/epoch - 34ms/step
# Epoch 110/300
#
# Epoch 110: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6480 - accuracy: 0.6248 - val_loss: 0.6786 - val_accuracy: 0.5733 - 10s/epoch - 34ms/step
# Epoch 111/300
#
# Epoch 111: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6461 - accuracy: 0.6281 - val_loss: 0.7244 - val_accuracy: 0.5657 - 10s/epoch - 34ms/step
# Epoch 112/300
#
# Epoch 112: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6491 - accuracy: 0.6299 - val_loss: 0.6783 - val_accuracy: 0.5754 - 10s/epoch - 34ms/step
# Epoch 113/300
#
# Epoch 113: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6470 - accuracy: 0.6246 - val_loss: 0.6937 - val_accuracy: 0.5686 - 10s/epoch - 34ms/step
# Epoch 114/300
#
# Epoch 114: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6502 - accuracy: 0.6257 - val_loss: 0.6783 - val_accuracy: 0.5708 - 10s/epoch - 34ms/step
# Epoch 115/300
#
# Epoch 115: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6484 - accuracy: 0.6247 - val_loss: 0.6782 - val_accuracy: 0.5859 - 10s/epoch - 34ms/step
# Epoch 116/300
#
# Epoch 116: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6500 - accuracy: 0.6267 - val_loss: 0.6791 - val_accuracy: 0.5708 - 10s/epoch - 34ms/step
# Epoch 117/300
#
# Epoch 117: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6477 - accuracy: 0.6278 - val_loss: 0.6837 - val_accuracy: 0.5748 - 10s/epoch - 34ms/step
# Epoch 118/300
#
# Epoch 118: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6483 - accuracy: 0.6291 - val_loss: 0.7152 - val_accuracy: 0.5654 - 10s/epoch - 34ms/step
# Epoch 119/300
#
# Epoch 119: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6480 - accuracy: 0.6269 - val_loss: 0.6785 - val_accuracy: 0.5861 - 10s/epoch - 34ms/step
# Epoch 120/300
#
# Epoch 120: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6478 - accuracy: 0.6255 - val_loss: 0.6793 - val_accuracy: 0.5832 - 10s/epoch - 34ms/step
# Epoch 121/300
#
# Epoch 121: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6491 - accuracy: 0.6270 - val_loss: 0.6967 - val_accuracy: 0.5667 - 10s/epoch - 34ms/step
# Epoch 122/300
#
# Epoch 122: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6482 - accuracy: 0.6268 - val_loss: 0.6781 - val_accuracy: 0.5839 - 10s/epoch - 34ms/step
# Epoch 123/300
#
# Epoch 123: val_loss did not improve from 0.67612
# 295/295 - 10s - loss: 0.6486 - accuracy: 0.6252 - val_loss: 0.6767 - val_accuracy: 0.6036 - 10s/epoch - 34ms/step
# Epoch 124/300
#
# Epoch 124: val_loss improved from 0.67612 to 0.67488, saving model to /tmp\checkpoint.h5
# 295/295 - 10s - loss: 0.6471 - accuracy: 0.6264 - val_loss: 0.6749 - val_accuracy: 0.5791 - 10s/epoch - 34ms/step
# Epoch 125/300
#
# Epoch 125: val_loss did not improve from 0.67488
# 295/295 - 10s - loss: 0.6494 - accuracy: 0.6245 - val_loss: 0.6778 - val_accuracy: 0.5772 - 10s/epoch - 34ms/step
# Epoch 126/300
#
# Epoch 126: val_loss did not improve from 0.67488
# 295/295 - 10s - loss: 0.6456 - accuracy: 0.6279 - val_loss: 0.7552 - val_accuracy: 0.5625 - 10s/epoch - 34ms/step
# Epoch 127/300
#
# Epoch 127: val_loss did not improve from 0.67488
# 295/295 - 10s - loss: 0.6484 - accuracy: 0.6309 - val_loss: 0.6762 - val_accuracy: 0.5775 - 10s/epoch - 34ms/step
# Epoch 128/300
#
# Epoch 128: val_loss did not improve from 0.67488
# 295/295 - 10s - loss: 0.6471 - accuracy: 0.6298 - val_loss: 0.7062 - val_accuracy: 0.5644 - 10s/epoch - 34ms/step
# Epoch 129/300
#
# Epoch 129: val_loss did not improve from 0.67488
# 295/295 - 10s - loss: 0.6468 - accuracy: 0.6309 - val_loss: 0.6779 - val_accuracy: 0.5754 - 10s/epoch - 34ms/step
# Epoch 130/300
#
# Epoch 130: val_loss did not improve from 0.67488
# 295/295 - 10s - loss: 0.6474 - accuracy: 0.6285 - val_loss: 0.7779 - val_accuracy: 0.5633 - 10s/epoch - 34ms/step
# Epoch 131/300
#
# Epoch 131: val_loss did not improve from 0.67488
# 295/295 - 10s - loss: 0.6470 - accuracy: 0.6307 - val_loss: 0.6768 - val_accuracy: 0.5743 - 10s/epoch - 34ms/step
# Epoch 132/300
#
# Epoch 132: val_loss did not improve from 0.67488
# 295/295 - 10s - loss: 0.6451 - accuracy: 0.6306 - val_loss: 0.7097 - val_accuracy: 0.5660 - 10s/epoch - 34ms/step
# Epoch 133/300
#
# Epoch 133: val_loss did not improve from 0.67488
# 295/295 - 10s - loss: 0.6468 - accuracy: 0.6293 - val_loss: 0.6821 - val_accuracy: 0.5776 - 10s/epoch - 34ms/step
# Epoch 134/300
#
# Epoch 134: val_loss did not improve from 0.67488
# 295/295 - 10s - loss: 0.6471 - accuracy: 0.6288 - val_loss: 0.6790 - val_accuracy: 0.5819 - 10s/epoch - 34ms/step
# Epoch 135/300
#
# Epoch 135: val_loss did not improve from 0.67488
# 295/295 - 10s - loss: 0.6474 - accuracy: 0.6264 - val_loss: 0.6872 - val_accuracy: 0.5753 - 10s/epoch - 34ms/step
# Epoch 136/300
#
# Epoch 136: val_loss did not improve from 0.67488
# 295/295 - 10s - loss: 0.6483 - accuracy: 0.6270 - val_loss: 0.6785 - val_accuracy: 0.5765 - 10s/epoch - 34ms/step
# Epoch 137/300
#
# Epoch 137: val_loss did not improve from 0.67488
# 295/295 - 10s - loss: 0.6460 - accuracy: 0.6301 - val_loss: 0.6776 - val_accuracy: 0.5743 - 10s/epoch - 34ms/step
# Epoch 138/300
#
# Epoch 138: val_loss did not improve from 0.67488
# 295/295 - 10s - loss: 0.6503 - accuracy: 0.6254 - val_loss: 0.6967 - val_accuracy: 0.5694 - 10s/epoch - 34ms/step
# Epoch 139/300
#
# Epoch 139: val_loss did not improve from 0.67488
# 295/295 - 10s - loss: 0.6459 - accuracy: 0.6317 - val_loss: 0.6818 - val_accuracy: 0.5711 - 10s/epoch - 34ms/step
# Epoch 140/300
#
# Epoch 140: val_loss did not improve from 0.67488
# 295/295 - 10s - loss: 0.6459 - accuracy: 0.6288 - val_loss: 0.6775 - val_accuracy: 0.5778 - 10s/epoch - 34ms/step
# Epoch 141/300
#
# Epoch 141: val_loss did not improve from 0.67488
# 295/295 - 10s - loss: 0.6461 - accuracy: 0.6291 - val_loss: 0.6900 - val_accuracy: 0.5313 - 10s/epoch - 34ms/step
# Epoch 142/300
#
# Epoch 142: val_loss did not improve from 0.67488
# 295/295 - 10s - loss: 0.6472 - accuracy: 0.6308 - val_loss: 0.6986 - val_accuracy: 0.5679 - 10s/epoch - 34ms/step
# Epoch 143/300
#
# Epoch 143: val_loss did not improve from 0.67488
# 295/295 - 10s - loss: 0.6491 - accuracy: 0.6275 - val_loss: 0.6767 - val_accuracy: 0.5831 - 10s/epoch - 34ms/step
# Epoch 144/300
#
# Epoch 144: val_loss did not improve from 0.67488
# 295/295 - 10s - loss: 0.6456 - accuracy: 0.6337 - val_loss: 0.6802 - val_accuracy: 0.5746 - 10s/epoch - 34ms/step
# Epoch 145/300
#
# Epoch 145: val_loss did not improve from 0.67488
# 295/295 - 10s - loss: 0.6480 - accuracy: 0.6300 - val_loss: 0.6900 - val_accuracy: 0.5694 - 10s/epoch - 34ms/step
# Epoch 146/300
#
# Epoch 146: val_loss did not improve from 0.67488
# 295/295 - 10s - loss: 0.6478 - accuracy: 0.6279 - val_loss: 0.6898 - val_accuracy: 0.5717 - 10s/epoch - 34ms/step
# Epoch 147/300
#
# Epoch 147: val_loss did not improve from 0.67488
# 295/295 - 10s - loss: 0.6472 - accuracy: 0.6258 - val_loss: 0.6782 - val_accuracy: 0.5749 - 10s/epoch - 34ms/step
# Epoch 148/300
#
# Epoch 148: val_loss improved from 0.67488 to 0.67452, saving model to /tmp\checkpoint.h5
# 295/295 - 10s - loss: 0.6443 - accuracy: 0.6294 - val_loss: 0.6745 - val_accuracy: 0.5756 - 10s/epoch - 34ms/step
# Epoch 149/300
#
# Epoch 149: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6462 - accuracy: 0.6289 - val_loss: 0.6756 - val_accuracy: 0.5759 - 10s/epoch - 34ms/step
# Epoch 150/300
#
# Epoch 150: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6445 - accuracy: 0.6324 - val_loss: 0.6896 - val_accuracy: 0.5716 - 10s/epoch - 34ms/step
# Epoch 151/300
#
# Epoch 151: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6456 - accuracy: 0.6313 - val_loss: 0.6748 - val_accuracy: 0.5786 - 10s/epoch - 34ms/step
# Epoch 152/300
#
# Epoch 152: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6468 - accuracy: 0.6313 - val_loss: 0.6778 - val_accuracy: 0.5751 - 10s/epoch - 34ms/step
# Epoch 153/300
#
# Epoch 153: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6467 - accuracy: 0.6261 - val_loss: 0.6813 - val_accuracy: 0.5897 - 10s/epoch - 34ms/step
# Epoch 154/300
#
# Epoch 154: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6454 - accuracy: 0.6305 - val_loss: 0.7654 - val_accuracy: 0.5633 - 10s/epoch - 34ms/step
# Epoch 155/300
#
# Epoch 155: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6462 - accuracy: 0.6309 - val_loss: 0.7074 - val_accuracy: 0.4445 - 10s/epoch - 34ms/step
# Epoch 156/300
#
# Epoch 156: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6434 - accuracy: 0.6327 - val_loss: 0.7363 - val_accuracy: 0.5660 - 10s/epoch - 34ms/step
# Epoch 157/300
#
# Epoch 157: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6450 - accuracy: 0.6283 - val_loss: 0.6790 - val_accuracy: 0.5815 - 10s/epoch - 34ms/step
# Epoch 158/300
#
# Epoch 158: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6447 - accuracy: 0.6336 - val_loss: 0.6832 - val_accuracy: 0.5746 - 10s/epoch - 34ms/step
# Epoch 159/300
#
# Epoch 159: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6456 - accuracy: 0.6326 - val_loss: 0.6776 - val_accuracy: 0.5811 - 10s/epoch - 34ms/step
# Epoch 160/300
#
# Epoch 160: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6450 - accuracy: 0.6304 - val_loss: 0.6767 - val_accuracy: 0.5848 - 10s/epoch - 34ms/step
# Epoch 161/300
#
# Epoch 161: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6457 - accuracy: 0.6315 - val_loss: 0.6786 - val_accuracy: 0.5745 - 10s/epoch - 34ms/step
# Epoch 162/300
#
# Epoch 162: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6486 - accuracy: 0.6297 - val_loss: 0.6897 - val_accuracy: 0.5518 - 10s/epoch - 34ms/step
# Epoch 163/300
#
# Epoch 163: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6419 - accuracy: 0.6362 - val_loss: 0.6771 - val_accuracy: 0.5805 - 10s/epoch - 34ms/step
# Epoch 164/300
#
# Epoch 164: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6421 - accuracy: 0.6350 - val_loss: 0.7205 - val_accuracy: 0.4456 - 10s/epoch - 34ms/step
# Epoch 165/300
#
# Epoch 165: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6437 - accuracy: 0.6329 - val_loss: 0.6890 - val_accuracy: 0.5461 - 10s/epoch - 34ms/step
# Epoch 166/300
#
# Epoch 166: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6412 - accuracy: 0.6297 - val_loss: 0.6841 - val_accuracy: 0.5839 - 10s/epoch - 34ms/step
# Epoch 167/300
#
# Epoch 167: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6449 - accuracy: 0.6335 - val_loss: 0.7689 - val_accuracy: 0.4421 - 10s/epoch - 34ms/step
# Epoch 168/300
#
# Epoch 168: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6428 - accuracy: 0.6320 - val_loss: 0.6762 - val_accuracy: 0.5926 - 10s/epoch - 34ms/step
# Epoch 169/300
#
# Epoch 169: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6427 - accuracy: 0.6288 - val_loss: 0.7375 - val_accuracy: 0.5614 - 10s/epoch - 34ms/step
# Epoch 170/300
#
# Epoch 170: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6422 - accuracy: 0.6336 - val_loss: 0.6812 - val_accuracy: 0.5732 - 10s/epoch - 34ms/step
# Epoch 171/300
#
# Epoch 171: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6465 - accuracy: 0.6272 - val_loss: 0.6950 - val_accuracy: 0.5676 - 10s/epoch - 34ms/step
# Epoch 172/300
#
# Epoch 172: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6429 - accuracy: 0.6326 - val_loss: 0.6815 - val_accuracy: 0.5754 - 10s/epoch - 34ms/step
# Epoch 173/300
#
# Epoch 173: val_loss did not improve from 0.67452
# 295/295 - 10s - loss: 0.6444 - accuracy: 0.6313 - val_loss: 0.6749 - val_accuracy: 0.5851 - 10s/epoch - 33ms/step
# Epoch 174/300
#
# Epoch 174: val_loss improved from 0.67452 to 0.67166, saving model to /tmp\checkpoint.h5
# 295/295 - 10s - loss: 0.6425 - accuracy: 0.6297 - val_loss: 0.6717 - val_accuracy: 0.5893 - 10s/epoch - 34ms/step
# Epoch 175/300
#
# Epoch 175: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6460 - accuracy: 0.6301 - val_loss: 0.6795 - val_accuracy: 0.5745 - 10s/epoch - 34ms/step
# Epoch 176/300
#
# Epoch 176: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6441 - accuracy: 0.6297 - val_loss: 0.6858 - val_accuracy: 0.5692 - 10s/epoch - 34ms/step
# Epoch 177/300
#
# Epoch 177: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6424 - accuracy: 0.6331 - val_loss: 0.8179 - val_accuracy: 0.5601 - 10s/epoch - 34ms/step
# Epoch 178/300
#
# Epoch 178: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6422 - accuracy: 0.6347 - val_loss: 0.6951 - val_accuracy: 0.5673 - 10s/epoch - 34ms/step
# Epoch 179/300
#
# Epoch 179: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6446 - accuracy: 0.6312 - val_loss: 0.6802 - val_accuracy: 0.5977 - 10s/epoch - 33ms/step
# Epoch 180/300
#
# Epoch 180: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6428 - accuracy: 0.6319 - val_loss: 0.7065 - val_accuracy: 0.5643 - 10s/epoch - 33ms/step
# Epoch 181/300
#
# Epoch 181: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6442 - accuracy: 0.6300 - val_loss: 0.7012 - val_accuracy: 0.5647 - 10s/epoch - 34ms/step
# Epoch 182/300
#
# Epoch 182: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6442 - accuracy: 0.6286 - val_loss: 0.7022 - val_accuracy: 0.4407 - 10s/epoch - 34ms/step
# Epoch 183/300
#
# Epoch 183: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6418 - accuracy: 0.6342 - val_loss: 0.6751 - val_accuracy: 0.5751 - 10s/epoch - 33ms/step
# Epoch 184/300
#
# Epoch 184: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6442 - accuracy: 0.6291 - val_loss: 0.6788 - val_accuracy: 0.5713 - 10s/epoch - 34ms/step
# Epoch 185/300
#
# Epoch 185: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6416 - accuracy: 0.6324 - val_loss: 0.7052 - val_accuracy: 0.5655 - 10s/epoch - 34ms/step
# Epoch 186/300
#
# Epoch 186: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6416 - accuracy: 0.6382 - val_loss: 0.6815 - val_accuracy: 0.5818 - 10s/epoch - 34ms/step
# Epoch 187/300
#
# Epoch 187: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6427 - accuracy: 0.6325 - val_loss: 0.7027 - val_accuracy: 0.4421 - 10s/epoch - 34ms/step
# Epoch 188/300
#
# Epoch 188: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6425 - accuracy: 0.6337 - val_loss: 0.7452 - val_accuracy: 0.5606 - 10s/epoch - 33ms/step
# Epoch 189/300
#
# Epoch 189: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6427 - accuracy: 0.6343 - val_loss: 0.6765 - val_accuracy: 0.5783 - 10s/epoch - 34ms/step
# Epoch 190/300
#
# Epoch 190: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6397 - accuracy: 0.6348 - val_loss: 0.6837 - val_accuracy: 0.5710 - 10s/epoch - 34ms/step
# Epoch 191/300
#
# Epoch 191: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6425 - accuracy: 0.6332 - val_loss: 0.7230 - val_accuracy: 0.5622 - 10s/epoch - 34ms/step
# Epoch 192/300
#
# Epoch 192: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6422 - accuracy: 0.6315 - val_loss: 0.6856 - val_accuracy: 0.5807 - 10s/epoch - 34ms/step
# Epoch 193/300
#
# Epoch 193: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6422 - accuracy: 0.6313 - val_loss: 0.7092 - val_accuracy: 0.5635 - 10s/epoch - 34ms/step
# Epoch 194/300
#
# Epoch 194: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6419 - accuracy: 0.6343 - val_loss: 0.6893 - val_accuracy: 0.5679 - 10s/epoch - 34ms/step
# Epoch 195/300
#
# Epoch 195: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6406 - accuracy: 0.6343 - val_loss: 0.6863 - val_accuracy: 0.5673 - 10s/epoch - 34ms/step
# Epoch 196/300
#
# Epoch 196: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6431 - accuracy: 0.6304 - val_loss: 0.7459 - val_accuracy: 0.5619 - 10s/epoch - 33ms/step
# Epoch 197/300
#
# Epoch 197: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6426 - accuracy: 0.6319 - val_loss: 0.7392 - val_accuracy: 0.5630 - 10s/epoch - 34ms/step
# Epoch 198/300
#
# Epoch 198: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6404 - accuracy: 0.6373 - val_loss: 0.6859 - val_accuracy: 0.5479 - 10s/epoch - 34ms/step
# Epoch 199/300
#
# Epoch 199: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6421 - accuracy: 0.6339 - val_loss: 0.8837 - val_accuracy: 0.5598 - 10s/epoch - 34ms/step
# Epoch 200/300
#
# Epoch 200: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6403 - accuracy: 0.6325 - val_loss: 0.6953 - val_accuracy: 0.5660 - 10s/epoch - 34ms/step
# Epoch 201/300
#
# Epoch 201: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6431 - accuracy: 0.6318 - val_loss: 0.6775 - val_accuracy: 0.5764 - 10s/epoch - 34ms/step
# Epoch 202/300
#
# Epoch 202: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6412 - accuracy: 0.6355 - val_loss: 0.6774 - val_accuracy: 0.5760 - 10s/epoch - 34ms/step
# Epoch 203/300
#
# Epoch 203: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6410 - accuracy: 0.6349 - val_loss: 0.7597 - val_accuracy: 0.5619 - 10s/epoch - 34ms/step
# Epoch 204/300
#
# Epoch 204: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6422 - accuracy: 0.6352 - val_loss: 0.7020 - val_accuracy: 0.4442 - 10s/epoch - 34ms/step
# Epoch 205/300
#
# Epoch 205: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6403 - accuracy: 0.6370 - val_loss: 0.6818 - val_accuracy: 0.5724 - 10s/epoch - 34ms/step
# Epoch 206/300
#
# Epoch 206: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6422 - accuracy: 0.6337 - val_loss: 0.6798 - val_accuracy: 0.5735 - 10s/epoch - 34ms/step
# Epoch 207/300
#
# Epoch 207: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6417 - accuracy: 0.6343 - val_loss: 0.6812 - val_accuracy: 0.5897 - 10s/epoch - 34ms/step
# Epoch 208/300
#
# Epoch 208: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6418 - accuracy: 0.6332 - val_loss: 0.6844 - val_accuracy: 0.5768 - 10s/epoch - 34ms/step
# Epoch 209/300
#
# Epoch 209: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6416 - accuracy: 0.6360 - val_loss: 0.6840 - val_accuracy: 0.5668 - 10s/epoch - 34ms/step
# Epoch 210/300
#
# Epoch 210: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6407 - accuracy: 0.6338 - val_loss: 0.6962 - val_accuracy: 0.5641 - 10s/epoch - 34ms/step
# Epoch 211/300
#
# Epoch 211: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6396 - accuracy: 0.6341 - val_loss: 0.6845 - val_accuracy: 0.5706 - 10s/epoch - 34ms/step
# Epoch 212/300
#
# Epoch 212: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6407 - accuracy: 0.6341 - val_loss: 0.6847 - val_accuracy: 0.5694 - 10s/epoch - 34ms/step
# Epoch 213/300
#
# Epoch 213: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6408 - accuracy: 0.6351 - val_loss: 0.7877 - val_accuracy: 0.5606 - 10s/epoch - 34ms/step
# Epoch 214/300
#
# Epoch 214: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6414 - accuracy: 0.6319 - val_loss: 0.6748 - val_accuracy: 0.5759 - 10s/epoch - 34ms/step
# Epoch 215/300
#
# Epoch 215: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6422 - accuracy: 0.6365 - val_loss: 0.6831 - val_accuracy: 0.5657 - 10s/epoch - 34ms/step
# Epoch 216/300
#
# Epoch 216: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6394 - accuracy: 0.6347 - val_loss: 0.6770 - val_accuracy: 0.5856 - 10s/epoch - 34ms/step
# Epoch 217/300
#
# Epoch 217: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6378 - accuracy: 0.6376 - val_loss: 0.7337 - val_accuracy: 0.5628 - 10s/epoch - 34ms/step
# Epoch 218/300
#
# Epoch 218: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6409 - accuracy: 0.6347 - val_loss: 0.6842 - val_accuracy: 0.5794 - 10s/epoch - 34ms/step
# Epoch 219/300
#
# Epoch 219: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6402 - accuracy: 0.6335 - val_loss: 0.6807 - val_accuracy: 0.5791 - 10s/epoch - 34ms/step
# Epoch 220/300
#
# Epoch 220: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6402 - accuracy: 0.6338 - val_loss: 0.6762 - val_accuracy: 0.5802 - 10s/epoch - 34ms/step
# Epoch 221/300
#
# Epoch 221: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6409 - accuracy: 0.6350 - val_loss: 0.7228 - val_accuracy: 0.5630 - 10s/epoch - 34ms/step
# Epoch 222/300
#
# Epoch 222: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6381 - accuracy: 0.6362 - val_loss: 0.6859 - val_accuracy: 0.5681 - 10s/epoch - 34ms/step
# Epoch 223/300
#
# Epoch 223: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6415 - accuracy: 0.6324 - val_loss: 0.6772 - val_accuracy: 0.5741 - 10s/epoch - 34ms/step
# Epoch 224/300
#
# Epoch 224: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6395 - accuracy: 0.6336 - val_loss: 0.7061 - val_accuracy: 0.5644 - 10s/epoch - 34ms/step
# Epoch 225/300
#
# Epoch 225: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6408 - accuracy: 0.6334 - val_loss: 0.7129 - val_accuracy: 0.5639 - 10s/epoch - 34ms/step
# Epoch 226/300
#
# Epoch 226: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6396 - accuracy: 0.6348 - val_loss: 0.6865 - val_accuracy: 0.5689 - 10s/epoch - 34ms/step
# Epoch 227/300
#
# Epoch 227: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6415 - accuracy: 0.6343 - val_loss: 0.6741 - val_accuracy: 0.5915 - 10s/epoch - 34ms/step
# Epoch 228/300
#
# Epoch 228: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6405 - accuracy: 0.6301 - val_loss: 0.6772 - val_accuracy: 0.5754 - 10s/epoch - 34ms/step
# Epoch 229/300
#
# Epoch 229: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6401 - accuracy: 0.6349 - val_loss: 0.6988 - val_accuracy: 0.5631 - 10s/epoch - 34ms/step
# Epoch 230/300
#
# Epoch 230: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6399 - accuracy: 0.6331 - val_loss: 0.6892 - val_accuracy: 0.5275 - 10s/epoch - 34ms/step
# Epoch 231/300
#
# Epoch 231: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6388 - accuracy: 0.6361 - val_loss: 0.8459 - val_accuracy: 0.5608 - 10s/epoch - 34ms/step
# Epoch 232/300
#
# Epoch 232: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6399 - accuracy: 0.6349 - val_loss: 0.6802 - val_accuracy: 0.5823 - 10s/epoch - 34ms/step
# Epoch 233/300
#
# Epoch 233: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6410 - accuracy: 0.6368 - val_loss: 0.7210 - val_accuracy: 0.5625 - 10s/epoch - 34ms/step
# Epoch 234/300
#
# Epoch 234: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6415 - accuracy: 0.6345 - val_loss: 0.6905 - val_accuracy: 0.5651 - 10s/epoch - 34ms/step
# Epoch 235/300
#
# Epoch 235: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6411 - accuracy: 0.6340 - val_loss: 0.7020 - val_accuracy: 0.5646 - 10s/epoch - 34ms/step
# Epoch 236/300
#
# Epoch 236: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6416 - accuracy: 0.6321 - val_loss: 0.6843 - val_accuracy: 0.5625 - 10s/epoch - 34ms/step
# Epoch 237/300
#
# Epoch 237: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6413 - accuracy: 0.6352 - val_loss: 0.7057 - val_accuracy: 0.5630 - 10s/epoch - 34ms/step
# Epoch 238/300
#
# Epoch 238: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6380 - accuracy: 0.6377 - val_loss: 0.7901 - val_accuracy: 0.5603 - 10s/epoch - 34ms/step
# Epoch 239/300
#
# Epoch 239: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6426 - accuracy: 0.6323 - val_loss: 0.6775 - val_accuracy: 0.5753 - 10s/epoch - 34ms/step
# Epoch 240/300
#
# Epoch 240: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6411 - accuracy: 0.6352 - val_loss: 0.7584 - val_accuracy: 0.4419 - 10s/epoch - 34ms/step
# Epoch 241/300
#
# Epoch 241: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6409 - accuracy: 0.6362 - val_loss: 0.7697 - val_accuracy: 0.5616 - 10s/epoch - 34ms/step
# Epoch 242/300
#
# Epoch 242: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6395 - accuracy: 0.6391 - val_loss: 0.6766 - val_accuracy: 0.5765 - 10s/epoch - 34ms/step
# Epoch 243/300
#
# Epoch 243: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6376 - accuracy: 0.6394 - val_loss: 0.7618 - val_accuracy: 0.4412 - 10s/epoch - 34ms/step
# Epoch 244/300
#
# Epoch 244: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6408 - accuracy: 0.6356 - val_loss: 0.7011 - val_accuracy: 0.5611 - 10s/epoch - 34ms/step
# Epoch 245/300
#
# Epoch 245: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6384 - accuracy: 0.6388 - val_loss: 0.6785 - val_accuracy: 0.5823 - 10s/epoch - 34ms/step
# Epoch 246/300
#
# Epoch 246: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6400 - accuracy: 0.6330 - val_loss: 0.8315 - val_accuracy: 0.4407 - 10s/epoch - 34ms/step
# Epoch 247/300
#
# Epoch 247: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6381 - accuracy: 0.6382 - val_loss: 0.7038 - val_accuracy: 0.5651 - 10s/epoch - 34ms/step
# Epoch 248/300
#
# Epoch 248: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6402 - accuracy: 0.6352 - val_loss: 0.7209 - val_accuracy: 0.5622 - 10s/epoch - 34ms/step
# Epoch 249/300
#
# Epoch 249: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6369 - accuracy: 0.6383 - val_loss: 0.8559 - val_accuracy: 0.4416 - 10s/epoch - 34ms/step
# Epoch 250/300
#
# Epoch 250: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6394 - accuracy: 0.6374 - val_loss: 0.8537 - val_accuracy: 0.4408 - 10s/epoch - 34ms/step
# Epoch 251/300
#
# Epoch 251: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6395 - accuracy: 0.6331 - val_loss: 0.6864 - val_accuracy: 0.5655 - 10s/epoch - 34ms/step
# Epoch 252/300
#
# Epoch 252: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6416 - accuracy: 0.6396 - val_loss: 0.7134 - val_accuracy: 0.5647 - 10s/epoch - 33ms/step
# Epoch 253/300
#
# Epoch 253: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6420 - accuracy: 0.6352 - val_loss: 0.6828 - val_accuracy: 0.5698 - 10s/epoch - 34ms/step
# Epoch 254/300
#
# Epoch 254: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6389 - accuracy: 0.6381 - val_loss: 0.7366 - val_accuracy: 0.4475 - 10s/epoch - 34ms/step
# Epoch 255/300
#
# Epoch 255: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6419 - accuracy: 0.6357 - val_loss: 0.6831 - val_accuracy: 0.5839 - 10s/epoch - 33ms/step
# Epoch 256/300
#
# Epoch 256: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6380 - accuracy: 0.6408 - val_loss: 0.6813 - val_accuracy: 0.5639 - 10s/epoch - 33ms/step
# Epoch 257/300
#
# Epoch 257: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6401 - accuracy: 0.6341 - val_loss: 0.7851 - val_accuracy: 0.4490 - 10s/epoch - 33ms/step
# Epoch 258/300
#
# Epoch 258: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6404 - accuracy: 0.6321 - val_loss: 0.7336 - val_accuracy: 0.5622 - 10s/epoch - 34ms/step
# Epoch 259/300
#
# Epoch 259: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6374 - accuracy: 0.6399 - val_loss: 0.6845 - val_accuracy: 0.5655 - 10s/epoch - 33ms/step
# Epoch 260/300
#
# Epoch 260: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6392 - accuracy: 0.6336 - val_loss: 0.7153 - val_accuracy: 0.5644 - 10s/epoch - 34ms/step
# Epoch 261/300
#
# Epoch 261: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6373 - accuracy: 0.6383 - val_loss: 0.6775 - val_accuracy: 0.5832 - 10s/epoch - 33ms/step
# Epoch 262/300
#
# Epoch 262: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6389 - accuracy: 0.6364 - val_loss: 0.6900 - val_accuracy: 0.5391 - 10s/epoch - 34ms/step
# Epoch 263/300
#
# Epoch 263: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6354 - accuracy: 0.6357 - val_loss: 0.6888 - val_accuracy: 0.5663 - 10s/epoch - 34ms/step
# Epoch 264/300
#
# Epoch 264: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6361 - accuracy: 0.6380 - val_loss: 0.7009 - val_accuracy: 0.5628 - 10s/epoch - 34ms/step
# Epoch 265/300
#
# Epoch 265: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6387 - accuracy: 0.6370 - val_loss: 0.7180 - val_accuracy: 0.5619 - 10s/epoch - 34ms/step
# Epoch 266/300
#
# Epoch 266: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6381 - accuracy: 0.6389 - val_loss: 0.6759 - val_accuracy: 0.5882 - 10s/epoch - 34ms/step
# Epoch 267/300
#
# Epoch 267: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6375 - accuracy: 0.6343 - val_loss: 0.6988 - val_accuracy: 0.5635 - 10s/epoch - 34ms/step
# Epoch 268/300
#
# Epoch 268: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6391 - accuracy: 0.6392 - val_loss: 0.7499 - val_accuracy: 0.5601 - 10s/epoch - 34ms/step
# Epoch 269/300
#
# Epoch 269: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6396 - accuracy: 0.6335 - val_loss: 0.6877 - val_accuracy: 0.5631 - 10s/epoch - 34ms/step
# Epoch 270/300
#
# Epoch 270: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6374 - accuracy: 0.6349 - val_loss: 0.6764 - val_accuracy: 0.5939 - 10s/epoch - 34ms/step
# Epoch 271/300
#
# Epoch 271: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6369 - accuracy: 0.6397 - val_loss: 0.6984 - val_accuracy: 0.4552 - 10s/epoch - 34ms/step
# Epoch 272/300
#
# Epoch 272: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6397 - accuracy: 0.6343 - val_loss: 0.7557 - val_accuracy: 0.4455 - 10s/epoch - 34ms/step
# Epoch 273/300
#
# Epoch 273: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6379 - accuracy: 0.6385 - val_loss: 0.6874 - val_accuracy: 0.5609 - 10s/epoch - 33ms/step
# Epoch 274/300
#
# Epoch 274: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6401 - accuracy: 0.6373 - val_loss: 0.6926 - val_accuracy: 0.5095 - 10s/epoch - 33ms/step
# Epoch 275/300
#
# Epoch 275: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6377 - accuracy: 0.6399 - val_loss: 0.6729 - val_accuracy: 0.5813 - 10s/epoch - 34ms/step
# Epoch 276/300
#
# Epoch 276: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6374 - accuracy: 0.6378 - val_loss: 0.7187 - val_accuracy: 0.5663 - 10s/epoch - 33ms/step
# Epoch 277/300
#
# Epoch 277: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6386 - accuracy: 0.6369 - val_loss: 0.6945 - val_accuracy: 0.5694 - 10s/epoch - 33ms/step
# Epoch 278/300
#
# Epoch 278: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6392 - accuracy: 0.6367 - val_loss: 0.7532 - val_accuracy: 0.5631 - 10s/epoch - 34ms/step
# Epoch 279/300
#
# Epoch 279: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6364 - accuracy: 0.6374 - val_loss: 0.6801 - val_accuracy: 0.5667 - 10s/epoch - 33ms/step
# Epoch 280/300
#
# Epoch 280: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6372 - accuracy: 0.6391 - val_loss: 0.7120 - val_accuracy: 0.4521 - 10s/epoch - 33ms/step
# Epoch 281/300
#
# Epoch 281: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6377 - accuracy: 0.6379 - val_loss: 0.6864 - val_accuracy: 0.5600 - 10s/epoch - 33ms/step
# Epoch 282/300
#
# Epoch 282: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6375 - accuracy: 0.6402 - val_loss: 1.1322 - val_accuracy: 0.4410 - 10s/epoch - 34ms/step
# Epoch 283/300
#
# Epoch 283: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6369 - accuracy: 0.6399 - val_loss: 0.6891 - val_accuracy: 0.5627 - 10s/epoch - 34ms/step
# Epoch 284/300
#
# Epoch 284: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6372 - accuracy: 0.6405 - val_loss: 0.7091 - val_accuracy: 0.5624 - 10s/epoch - 34ms/step
# Epoch 285/300
#
# Epoch 285: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6385 - accuracy: 0.6402 - val_loss: 0.7155 - val_accuracy: 0.4469 - 10s/epoch - 33ms/step
# Epoch 286/300
#
# Epoch 286: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6394 - accuracy: 0.6362 - val_loss: 0.6755 - val_accuracy: 0.5717 - 10s/epoch - 34ms/step
# Epoch 287/300
#
# Epoch 287: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6374 - accuracy: 0.6391 - val_loss: 0.7649 - val_accuracy: 0.4466 - 10s/epoch - 34ms/step
# Epoch 288/300
#
# Epoch 288: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6378 - accuracy: 0.6358 - val_loss: 0.7056 - val_accuracy: 0.5619 - 10s/epoch - 33ms/step
# Epoch 289/300
#
# Epoch 289: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6378 - accuracy: 0.6386 - val_loss: 0.6960 - val_accuracy: 0.5687 - 10s/epoch - 34ms/step
# Epoch 290/300
#
# Epoch 290: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6352 - accuracy: 0.6417 - val_loss: 0.7858 - val_accuracy: 0.4421 - 10s/epoch - 34ms/step
# Epoch 291/300
#
# Epoch 291: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6381 - accuracy: 0.6356 - val_loss: 0.6902 - val_accuracy: 0.5399 - 10s/epoch - 34ms/step
# Epoch 292/300
#
# Epoch 292: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6370 - accuracy: 0.6376 - val_loss: 0.6838 - val_accuracy: 0.5636 - 10s/epoch - 34ms/step
# Epoch 293/300
#
# Epoch 293: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6378 - accuracy: 0.6371 - val_loss: 0.6814 - val_accuracy: 0.5835 - 10s/epoch - 34ms/step
# Epoch 294/300
#
# Epoch 294: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6366 - accuracy: 0.6402 - val_loss: 0.6801 - val_accuracy: 0.5671 - 10s/epoch - 34ms/step
# Epoch 295/300
#
# Epoch 295: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6372 - accuracy: 0.6382 - val_loss: 0.6807 - val_accuracy: 0.5722 - 10s/epoch - 34ms/step
# Epoch 296/300
#
# Epoch 296: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6378 - accuracy: 0.6361 - val_loss: 0.6878 - val_accuracy: 0.5534 - 10s/epoch - 34ms/step
# Epoch 297/300
#
# Epoch 297: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6371 - accuracy: 0.6388 - val_loss: 0.7124 - val_accuracy: 0.5643 - 10s/epoch - 34ms/step
# Epoch 298/300
#
# Epoch 298: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6383 - accuracy: 0.6391 - val_loss: 0.6881 - val_accuracy: 0.5684 - 10s/epoch - 34ms/step
# Epoch 299/300
#
# Epoch 299: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6389 - accuracy: 0.6364 - val_loss: 0.8437 - val_accuracy: 0.4435 - 10s/epoch - 34ms/step
# Epoch 300/300
#
# Epoch 300: val_loss did not improve from 0.67166
# 295/295 - 10s - loss: 0.6357 - accuracy: 0.6391 - val_loss: 0.7671 - val_accuracy: 0.5612 - 10s/epoch - 34ms/step
# 225/225 [==============================] - 1s 5ms/step
# Classification accuracy: 0.624721
# array([[0.5370611 , 0.4629389 ],
#        [0.5222498 , 0.47775018],
#        [0.5568737 , 0.44312635],
#        ...,
#        [0.5078952 , 0.4921048 ],
#        [0.49337924, 0.50662076],
#        [0.5075688 , 0.49243122]], dtype=float32)
