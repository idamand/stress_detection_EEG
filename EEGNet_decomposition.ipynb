# %%
from utils.valid_recordings import get_valid_recordings
from utils.data_processing import extract_eeg_data, segment_data, train_test_val_split, dict_to_arr
from pre_processing import filter_EEG, decompose_EEG, init_filter
from classifiers import EEGNet_classifier
from utils.labels import get_stai_labels, get_pss_labels
import numpy as np

# %%
valid_recordings = get_valid_recordings('raw')
non_decomposed_data = extract_eeg_data(valid_recordings=valid_recordings, data_type='raw')
labels = get_stai_labels(valid_recordings=valid_recordings, cutoff=40)
# Out:
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# ERROR:root:Failed to read data for recording P006_S002_001
# ERROR:root:Failed to read data for recording P006_S002_002
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74912
#     Range : 0 ... 74911 =      0.000 ...   299.644 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74944
#     Range : 0 ... 74943 =      0.000 ...   299.772 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74912
#     Range : 0 ... 74911 =      0.000 ...   299.644 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74896
#     Range : 0 ... 74895 =      0.000 ...   299.580 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74960
#     Range : 0 ... 74959 =      0.000 ...   299.836 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# ERROR:root:Failed to read data for recording P028_S002_001
# ERROR:root:Failed to read data for recording P028_S002_002
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74912
#     Range : 0 ... 74911 =      0.000 ...   299.644 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74944
#     Range : 0 ... 74943 =      0.000 ...   299.772 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74912
#     Range : 0 ... 74911 =      0.000 ...   299.644 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74896
#     Range : 0 ... 74895 =      0.000 ...   299.580 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74960
#     Range : 0 ... 74959 =      0.000 ...   299.836 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.

# %%
initial = init_filter(non_decomposed_data)
filtered_data = filter_EEG(initial, low_freq=30, high_freq=None)
# Out:
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=74912
#     Range : 0 ... 74911 =      0.000 ...   299.644 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 825 samples (3.300 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# ...
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=74896
#     Range : 0 ... 74895 =      0.000 ...   299.580 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=74960
#     Range : 0 ... 74959 =      0.000 ...   299.836 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# IIR filter parameters
# ---------------------
# Butterworth highpass zero-phase (two-pass forward and reverse) non-causal filter:
# - Filter order 8 (effective, after forward-backward)
# - Cutoff at 30.00 Hz: -6.02 dB
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.

# %%
# %matplotlib qt
non_decomposed_data['P001_S001_001'].plot()
initial['P001_S001_001'].plot()
filtered_data['P001_S001_001'].plot()
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 1600x1584 with 4 Axes>

# %%
segmented_data, segmented_labels = segment_data(filtered_data, labels, epoch_duration=5)
# Out:
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 59 events and 1251 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 59 events and 1251 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 59 events and 1251 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 59 events and 1251 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 59 events and 1251 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped

# %%
train_data_dict, train_labels_dict, test_data_dict, test_labels_dict, val_data_dict, val_labels_dict = train_test_val_split(segmented_data, segmented_labels)
    
train_data      = dict_to_arr(train_data_dict)
test_data       = dict_to_arr(test_data_dict)
val_data        = dict_to_arr(val_data_dict)

train_labels    = np.reshape(np.array(list(train_labels_dict.values())), (len(train_data_dict),1))
test_labels     = np.reshape(np.array(list(test_labels_dict.values())), (len(test_data_dict),1))
val_labels      = np.reshape(np.array(list(val_labels_dict.values())), (len(val_data_dict),1))

print(f"Shape of train data set: {train_data.shape}")
print(f"Shape of train labels set: {train_labels.shape}")

print(f"Shape of test data set: {test_data.shape}")
print(f"Shape of test labels set: {test_labels.shape}")

print(f"Shape of validation data set: {val_data.shape}")
print(f"Shape of validation labels set: {val_labels.shape}")
# Out:
# Subjects test:  ['P011', 'P020', 'P015', 'P014', 'P008', 'P009']
#  Subjects train:  ['P016', 'P006', 'P019', 'P022', 'P018', 'P002', 'P013', 'P027', 'P004', 'P028', 'P003', 'P024', 'P007', 'P017', 'P026', 'P023']
#  Subjects val:  ['P021', 'P005', 'P025', 'P010', 'P001', 'P012']
# Shape of train data set: (3540, 8, 1251)
# Shape of train labels set: (3540, 1)
# Shape of test data set: (1416, 8, 1251)
# Shape of test labels set: (1416, 1)
# Shape of validation data set: (1416, 8, 1251)
# Shape of validation labels set: (1416, 1)

# %%
probs_eeg = EEGNet_classifier(train_data, test_data, val_data, train_labels, test_labels, val_labels)
# Out:
# Epoch 1/300
#
# Epoch 1: val_loss improved from inf to 0.68485, saving model to /tmp/checkpoint.h5
# 56/56 - 8s - loss: 0.6919 - accuracy: 0.5226 - val_loss: 0.6848 - val_accuracy: 0.6250 - 8s/epoch - 146ms/step
# Epoch 2/300
#
# Epoch 2: val_loss improved from 0.68485 to 0.67609, saving model to /tmp/checkpoint.h5
# 56/56 - 7s - loss: 0.6773 - accuracy: 0.5297 - val_loss: 0.6761 - val_accuracy: 0.6250 - 7s/epoch - 133ms/step
# Epoch 3/300
#
# Epoch 3: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.6696 - accuracy: 0.5201 - val_loss: 0.6797 - val_accuracy: 0.6250 - 7s/epoch - 132ms/step
# Epoch 4/300
#
# Epoch 4: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.6609 - accuracy: 0.5455 - val_loss: 0.6950 - val_accuracy: 0.3750 - 7s/epoch - 132ms/step
# Epoch 5/300
#
# Epoch 5: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.6540 - accuracy: 0.5746 - val_loss: 0.7181 - val_accuracy: 0.3750 - 7s/epoch - 132ms/step
# Epoch 6/300
#
# Epoch 6: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.6447 - accuracy: 0.5932 - val_loss: 0.8728 - val_accuracy: 0.3750 - 7s/epoch - 133ms/step
# Epoch 7/300
#
# Epoch 7: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.6259 - accuracy: 0.6274 - val_loss: 1.0297 - val_accuracy: 0.3750 - 7s/epoch - 132ms/step
# Epoch 8/300
#
# Epoch 8: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.5926 - accuracy: 0.6500 - val_loss: 1.7031 - val_accuracy: 0.3750 - 7s/epoch - 132ms/step
# Epoch 9/300
#
# Epoch 9: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.5442 - accuracy: 0.7107 - val_loss: 1.4732 - val_accuracy: 0.6250 - 7s/epoch - 133ms/step
# Epoch 10/300
#
# Epoch 10: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.5101 - accuracy: 0.7565 - val_loss: 0.7517 - val_accuracy: 0.6250 - 7s/epoch - 132ms/step
# Epoch 11/300
#
# Epoch 11: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.4860 - accuracy: 0.7692 - val_loss: 0.8143 - val_accuracy: 0.6243 - 7s/epoch - 132ms/step
# Epoch 12/300
#
# Epoch 12: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.4736 - accuracy: 0.7602 - val_loss: 2.2469 - val_accuracy: 0.6250 - 7s/epoch - 133ms/step
# Epoch 13/300
#
# Epoch 13: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.4702 - accuracy: 0.7664 - val_loss: 1.7781 - val_accuracy: 0.6250 - 7s/epoch - 132ms/step
# Epoch 14/300
#
# Epoch 14: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.4605 - accuracy: 0.7624 - val_loss: 3.2791 - val_accuracy: 0.6250 - 7s/epoch - 132ms/step
# Epoch 15/300
#
# Epoch 15: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.4536 - accuracy: 0.7760 - val_loss: 1.1316 - val_accuracy: 0.5572 - 7s/epoch - 132ms/step
# Epoch 16/300
#
# Epoch 16: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.4469 - accuracy: 0.7593 - val_loss: 9.0134 - val_accuracy: 0.3750 - 7s/epoch - 132ms/step
# Epoch 17/300
#
# Epoch 17: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.4349 - accuracy: 0.7732 - val_loss: 1.6136 - val_accuracy: 0.5417 - 7s/epoch - 132ms/step
# Epoch 18/300
#
# Epoch 18: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.4408 - accuracy: 0.7729 - val_loss: 1.5485 - val_accuracy: 0.4845 - 7s/epoch - 133ms/step
# Epoch 19/300
#
# Epoch 19: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.4328 - accuracy: 0.7887 - val_loss: 2.3370 - val_accuracy: 0.6186 - 7s/epoch - 132ms/step
# Epoch 20/300
#
# Epoch 20: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.4235 - accuracy: 0.7904 - val_loss: 1.3182 - val_accuracy: 0.4647 - 7s/epoch - 133ms/step
# Epoch 21/300
#
# Epoch 21: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.4142 - accuracy: 0.7929 - val_loss: 10.0077 - val_accuracy: 0.3750 - 7s/epoch - 133ms/step
# Epoch 22/300
#
# Epoch 22: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.4062 - accuracy: 0.8034 - val_loss: 2.2074 - val_accuracy: 0.4583 - 7s/epoch - 132ms/step
# Epoch 23/300
#
# Epoch 23: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.4058 - accuracy: 0.8034 - val_loss: 1.6436 - val_accuracy: 0.4174 - 7s/epoch - 132ms/step
# Epoch 24/300
#
# Epoch 24: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.4001 - accuracy: 0.8040 - val_loss: 2.7031 - val_accuracy: 0.5968 - 7s/epoch - 133ms/step
# Epoch 25/300
#
# Epoch 25: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.3844 - accuracy: 0.8076 - val_loss: 1.3923 - val_accuracy: 0.5247 - 7s/epoch - 132ms/step
# Epoch 26/300
#
# Epoch 26: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.3842 - accuracy: 0.8065 - val_loss: 3.2048 - val_accuracy: 0.6250 - 7s/epoch - 132ms/step
# Epoch 27/300
#
# Epoch 27: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.3786 - accuracy: 0.8105 - val_loss: 1.6264 - val_accuracy: 0.5092 - 7s/epoch - 132ms/step
# Epoch 28/300
#
# Epoch 28: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.3706 - accuracy: 0.8062 - val_loss: 2.1252 - val_accuracy: 0.6024 - 7s/epoch - 133ms/step
# Epoch 29/300
#
# Epoch 29: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.3697 - accuracy: 0.8133 - val_loss: 4.1605 - val_accuracy: 0.3750 - 7s/epoch - 132ms/step
# Epoch 30/300
#
# Epoch 30: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.3644 - accuracy: 0.8093 - val_loss: 8.7642 - val_accuracy: 0.3750 - 7s/epoch - 132ms/step
# Epoch 31/300
#
# Epoch 31: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.3546 - accuracy: 0.8251 - val_loss: 24.8436 - val_accuracy: 0.3750 - 7s/epoch - 132ms/step
# Epoch 32/300
#
# Epoch 32: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.3440 - accuracy: 0.8331 - val_loss: 11.7244 - val_accuracy: 0.3750 - 7s/epoch - 133ms/step
# Epoch 33/300
#
# Epoch 33: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.3415 - accuracy: 0.8342 - val_loss: 2.1611 - val_accuracy: 0.5629 - 7s/epoch - 132ms/step
# Epoch 34/300
#
# Epoch 34: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.3471 - accuracy: 0.8232 - val_loss: 2.7682 - val_accuracy: 0.5268 - 7s/epoch - 132ms/step
# Epoch 35/300
#
# Epoch 35: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.3359 - accuracy: 0.8305 - val_loss: 5.4920 - val_accuracy: 0.3750 - 7s/epoch - 133ms/step
# Epoch 36/300
#
# Epoch 36: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.3451 - accuracy: 0.8249 - val_loss: 10.9160 - val_accuracy: 0.3750 - 7s/epoch - 132ms/step
# Epoch 37/300
#
# Epoch 37: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.3351 - accuracy: 0.8339 - val_loss: 11.7859 - val_accuracy: 0.3750 - 7s/epoch - 132ms/step
# Epoch 38/300
#
# Epoch 38: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.3315 - accuracy: 0.8398 - val_loss: 6.5682 - val_accuracy: 0.3750 - 7s/epoch - 133ms/step
# Epoch 39/300
#
# Epoch 39: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.3234 - accuracy: 0.8435 - val_loss: 12.7458 - val_accuracy: 0.3750 - 7s/epoch - 133ms/step
# Epoch 40/300
#
# Epoch 40: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.3279 - accuracy: 0.8367 - val_loss: 2.9632 - val_accuracy: 0.5417 - 7s/epoch - 133ms/step
# Epoch 41/300
#
# Epoch 41: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.3160 - accuracy: 0.8548 - val_loss: 4.1125 - val_accuracy: 0.5833 - 7s/epoch - 133ms/step
# Epoch 42/300
#
# Epoch 42: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.3202 - accuracy: 0.8407 - val_loss: 3.6016 - val_accuracy: 0.5417 - 7s/epoch - 132ms/step
# Epoch 43/300
#
# Epoch 43: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.3085 - accuracy: 0.8528 - val_loss: 2.5296 - val_accuracy: 0.5000 - 7s/epoch - 132ms/step
# Epoch 44/300
#
# Epoch 44: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.3079 - accuracy: 0.8503 - val_loss: 4.7962 - val_accuracy: 0.5042 - 7s/epoch - 133ms/step
# Epoch 45/300
#
# Epoch 45: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.3056 - accuracy: 0.8559 - val_loss: 9.8298 - val_accuracy: 0.6250 - 7s/epoch - 132ms/step
# Epoch 46/300
#
# Epoch 46: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.3077 - accuracy: 0.8494 - val_loss: 6.4654 - val_accuracy: 0.5424 - 7s/epoch - 132ms/step
# Epoch 47/300
#
# Epoch 47: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.3057 - accuracy: 0.8554 - val_loss: 5.5561 - val_accuracy: 0.5417 - 7s/epoch - 132ms/step
# Epoch 48/300
#
# Epoch 48: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2967 - accuracy: 0.8565 - val_loss: 4.5009 - val_accuracy: 0.5445 - 7s/epoch - 132ms/step
# Epoch 49/300
#
# Epoch 49: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2905 - accuracy: 0.8678 - val_loss: 3.0696 - val_accuracy: 0.5169 - 7s/epoch - 132ms/step
# Epoch 50/300
#
# Epoch 50: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2948 - accuracy: 0.8599 - val_loss: 5.1110 - val_accuracy: 0.5417 - 7s/epoch - 133ms/step
# Epoch 51/300
#
# Epoch 51: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2879 - accuracy: 0.8658 - val_loss: 6.2894 - val_accuracy: 0.5417 - 7s/epoch - 132ms/step
# Epoch 52/300
#
# Epoch 52: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2989 - accuracy: 0.8582 - val_loss: 5.6055 - val_accuracy: 0.5417 - 7s/epoch - 130ms/step
# Epoch 53/300
#
# Epoch 53: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2985 - accuracy: 0.8627 - val_loss: 9.6933 - val_accuracy: 0.4456 - 7s/epoch - 131ms/step
# Epoch 54/300
#
# Epoch 54: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2908 - accuracy: 0.8647 - val_loss: 4.1522 - val_accuracy: 0.5014 - 7s/epoch - 130ms/step
# Epoch 55/300
#
# Epoch 55: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2846 - accuracy: 0.8686 - val_loss: 8.5560 - val_accuracy: 0.4583 - 7s/epoch - 130ms/step
# Epoch 56/300
#
# Epoch 56: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2832 - accuracy: 0.8678 - val_loss: 7.2359 - val_accuracy: 0.4583 - 7s/epoch - 130ms/step
# Epoch 57/300
#
# Epoch 57: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2851 - accuracy: 0.8650 - val_loss: 9.1447 - val_accuracy: 0.4583 - 7s/epoch - 131ms/step
# Epoch 58/300
#
# Epoch 58: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2744 - accuracy: 0.8723 - val_loss: 13.9684 - val_accuracy: 0.4520 - 8s/epoch - 141ms/step
# Epoch 59/300
#
# Epoch 59: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2684 - accuracy: 0.8791 - val_loss: 3.3111 - val_accuracy: 0.4597 - 8s/epoch - 145ms/step
# Epoch 60/300
#
# Epoch 60: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2746 - accuracy: 0.8732 - val_loss: 8.3051 - val_accuracy: 0.4583 - 8s/epoch - 147ms/step
# Epoch 61/300
#
# Epoch 61: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2697 - accuracy: 0.8771 - val_loss: 2.7323 - val_accuracy: 0.4901 - 8s/epoch - 138ms/step
# Epoch 62/300
#
# Epoch 62: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2756 - accuracy: 0.8788 - val_loss: 2.6103 - val_accuracy: 0.5939 - 8s/epoch - 135ms/step
# Epoch 63/300
#
# Epoch 63: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2797 - accuracy: 0.8661 - val_loss: 8.5478 - val_accuracy: 0.4583 - 8s/epoch - 148ms/step
# Epoch 64/300
#
# Epoch 64: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2766 - accuracy: 0.8771 - val_loss: 16.1965 - val_accuracy: 0.4534 - 8s/epoch - 139ms/step
# Epoch 65/300
#
# Epoch 65: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2738 - accuracy: 0.8782 - val_loss: 8.4238 - val_accuracy: 0.4153 - 7s/epoch - 133ms/step
# Epoch 66/300
#
# Epoch 66: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2665 - accuracy: 0.8802 - val_loss: 2.9140 - val_accuracy: 0.4689 - 7s/epoch - 134ms/step
# Epoch 67/300
#
# Epoch 67: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2631 - accuracy: 0.8802 - val_loss: 3.0895 - val_accuracy: 0.3439 - 7s/epoch - 133ms/step
# Epoch 68/300
#
# Epoch 68: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2691 - accuracy: 0.8746 - val_loss: 4.0580 - val_accuracy: 0.4583 - 7s/epoch - 132ms/step
# Epoch 69/300
#
# Epoch 69: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2669 - accuracy: 0.8836 - val_loss: 12.0754 - val_accuracy: 0.4583 - 8s/epoch - 136ms/step
# Epoch 70/300
#
# Epoch 70: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2721 - accuracy: 0.8768 - val_loss: 4.0931 - val_accuracy: 0.4739 - 8s/epoch - 134ms/step
# Epoch 71/300
#
# Epoch 71: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2702 - accuracy: 0.8723 - val_loss: 5.9239 - val_accuracy: 0.5417 - 8s/epoch - 135ms/step
# Epoch 72/300
#
# Epoch 72: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2652 - accuracy: 0.8853 - val_loss: 4.4990 - val_accuracy: 0.3312 - 7s/epoch - 134ms/step
# Epoch 73/300
#
# Epoch 73: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2498 - accuracy: 0.8879 - val_loss: 4.2334 - val_accuracy: 0.4965 - 7s/epoch - 134ms/step
# Epoch 74/300
#
# Epoch 74: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2584 - accuracy: 0.8828 - val_loss: 2.7767 - val_accuracy: 0.4583 - 8s/epoch - 137ms/step
# Epoch 75/300
#
# Epoch 75: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2581 - accuracy: 0.8862 - val_loss: 3.4898 - val_accuracy: 0.5304 - 8s/epoch - 134ms/step
# Epoch 76/300
#
# Epoch 76: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2597 - accuracy: 0.8918 - val_loss: 4.5257 - val_accuracy: 0.5085 - 8s/epoch - 138ms/step
# Epoch 77/300
#
# Epoch 77: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2535 - accuracy: 0.8924 - val_loss: 9.4510 - val_accuracy: 0.4583 - 7s/epoch - 132ms/step
# Epoch 78/300
#
# Epoch 78: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2481 - accuracy: 0.8958 - val_loss: 4.0364 - val_accuracy: 0.4329 - 8s/epoch - 145ms/step
# Epoch 79/300
#
# Epoch 79: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2504 - accuracy: 0.8946 - val_loss: 8.9480 - val_accuracy: 0.4583 - 8s/epoch - 134ms/step
# Epoch 80/300
#
# Epoch 80: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2393 - accuracy: 0.9040 - val_loss: 21.7369 - val_accuracy: 0.3962 - 7s/epoch - 131ms/step
# Epoch 81/300
#
# Epoch 81: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2441 - accuracy: 0.8929 - val_loss: 13.7156 - val_accuracy: 0.4583 - 7s/epoch - 132ms/step
# Epoch 82/300
#
# Epoch 82: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2454 - accuracy: 0.8980 - val_loss: 5.2983 - val_accuracy: 0.4894 - 8s/epoch - 134ms/step
# Epoch 83/300
#
# Epoch 83: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2551 - accuracy: 0.8862 - val_loss: 6.7191 - val_accuracy: 0.5417 - 8s/epoch - 135ms/step
# Epoch 84/300
#
# Epoch 84: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2423 - accuracy: 0.8941 - val_loss: 10.6365 - val_accuracy: 0.5833 - 8s/epoch - 142ms/step
# Epoch 85/300
#
# Epoch 85: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2448 - accuracy: 0.8941 - val_loss: 9.8662 - val_accuracy: 0.6144 - 8s/epoch - 149ms/step
# Epoch 86/300
#
# Epoch 86: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2312 - accuracy: 0.9110 - val_loss: 14.9999 - val_accuracy: 0.6250 - 8s/epoch - 139ms/step
# Epoch 87/300
#
# Epoch 87: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2310 - accuracy: 0.9073 - val_loss: 8.6751 - val_accuracy: 0.5869 - 8s/epoch - 139ms/step
# Epoch 88/300
#
# Epoch 88: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2432 - accuracy: 0.8960 - val_loss: 8.5128 - val_accuracy: 0.5501 - 8s/epoch - 146ms/step
# Epoch 89/300
#
# Epoch 89: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2401 - accuracy: 0.9023 - val_loss: 4.0778 - val_accuracy: 0.4583 - 8s/epoch - 145ms/step
# Epoch 90/300
#
# Epoch 90: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2300 - accuracy: 0.9082 - val_loss: 9.1558 - val_accuracy: 0.5833 - 8s/epoch - 136ms/step
# Epoch 91/300
#
# Epoch 91: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2312 - accuracy: 0.9158 - val_loss: 4.3358 - val_accuracy: 0.3355 - 8s/epoch - 138ms/step
# Epoch 92/300
#
# Epoch 92: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2370 - accuracy: 0.9014 - val_loss: 5.7151 - val_accuracy: 0.4583 - 8s/epoch - 144ms/step
# Epoch 93/300
#
# Epoch 93: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2294 - accuracy: 0.9025 - val_loss: 7.4943 - val_accuracy: 0.4421 - 8s/epoch - 137ms/step
# Epoch 94/300
#
# Epoch 94: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2332 - accuracy: 0.9082 - val_loss: 4.7077 - val_accuracy: 0.3552 - 8s/epoch - 143ms/step
# Epoch 95/300
#
# Epoch 95: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2238 - accuracy: 0.9147 - val_loss: 5.6690 - val_accuracy: 0.4732 - 8s/epoch - 144ms/step
# Epoch 96/300
#
# Epoch 96: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2311 - accuracy: 0.9088 - val_loss: 22.3001 - val_accuracy: 0.4583 - 7s/epoch - 132ms/step
# Epoch 97/300
#
# Epoch 97: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2336 - accuracy: 0.9020 - val_loss: 10.9976 - val_accuracy: 0.4583 - 7s/epoch - 133ms/step
# Epoch 98/300
#
# Epoch 98: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2258 - accuracy: 0.9184 - val_loss: 7.2037 - val_accuracy: 0.4364 - 8s/epoch - 139ms/step
# Epoch 99/300
#
# Epoch 99: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2295 - accuracy: 0.9042 - val_loss: 5.6744 - val_accuracy: 0.4654 - 8s/epoch - 139ms/step
# Epoch 100/300
#
# Epoch 100: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2206 - accuracy: 0.9150 - val_loss: 9.9133 - val_accuracy: 0.4640 - 7s/epoch - 134ms/step
# Epoch 101/300
#
# Epoch 101: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2214 - accuracy: 0.9116 - val_loss: 8.7342 - val_accuracy: 0.4816 - 8s/epoch - 146ms/step
# Epoch 102/300
#
# Epoch 102: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2275 - accuracy: 0.9133 - val_loss: 3.6390 - val_accuracy: 0.5417 - 8s/epoch - 138ms/step
# Epoch 103/300
#
# Epoch 103: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2229 - accuracy: 0.9116 - val_loss: 4.5223 - val_accuracy: 0.5056 - 7s/epoch - 131ms/step
# Epoch 104/300
#
# Epoch 104: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2127 - accuracy: 0.9240 - val_loss: 7.3090 - val_accuracy: 0.5417 - 8s/epoch - 135ms/step
# Epoch 105/300
#
# Epoch 105: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2198 - accuracy: 0.9234 - val_loss: 5.9135 - val_accuracy: 0.4562 - 7s/epoch - 132ms/step
# Epoch 106/300
#
# Epoch 106: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2239 - accuracy: 0.9147 - val_loss: 9.7427 - val_accuracy: 0.5417 - 7s/epoch - 133ms/step
# Epoch 107/300
#
# Epoch 107: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2151 - accuracy: 0.9220 - val_loss: 10.3206 - val_accuracy: 0.5918 - 7s/epoch - 132ms/step
# Epoch 108/300
#
# Epoch 108: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2107 - accuracy: 0.9260 - val_loss: 10.3259 - val_accuracy: 0.5833 - 7s/epoch - 130ms/step
# Epoch 109/300
#
# Epoch 109: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2164 - accuracy: 0.9164 - val_loss: 4.9936 - val_accuracy: 0.4979 - 8s/epoch - 135ms/step
# Epoch 110/300
#
# Epoch 110: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2207 - accuracy: 0.9110 - val_loss: 6.6805 - val_accuracy: 0.5417 - 7s/epoch - 131ms/step
# Epoch 111/300
#
# Epoch 111: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2172 - accuracy: 0.9144 - val_loss: 6.6681 - val_accuracy: 0.5417 - 7s/epoch - 132ms/step
# Epoch 112/300
#
# Epoch 112: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2140 - accuracy: 0.9220 - val_loss: 3.9016 - val_accuracy: 0.4583 - 8s/epoch - 135ms/step
# Epoch 113/300
#
# Epoch 113: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2062 - accuracy: 0.9260 - val_loss: 6.6258 - val_accuracy: 0.4569 - 8s/epoch - 139ms/step
# Epoch 114/300
#
# Epoch 114: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2150 - accuracy: 0.9212 - val_loss: 7.2658 - val_accuracy: 0.4809 - 8s/epoch - 139ms/step
# Epoch 115/300
#
# Epoch 115: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2125 - accuracy: 0.9215 - val_loss: 6.7240 - val_accuracy: 0.5417 - 7s/epoch - 134ms/step
# Epoch 116/300
#
# Epoch 116: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2065 - accuracy: 0.9175 - val_loss: 3.7333 - val_accuracy: 0.4456 - 8s/epoch - 140ms/step
# Epoch 117/300
#
# Epoch 117: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2044 - accuracy: 0.9339 - val_loss: 4.6039 - val_accuracy: 0.3919 - 8s/epoch - 142ms/step
# Epoch 118/300
#
# Epoch 118: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2089 - accuracy: 0.9251 - val_loss: 6.9105 - val_accuracy: 0.5417 - 8s/epoch - 137ms/step
# Epoch 119/300
#
# Epoch 119: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2034 - accuracy: 0.9254 - val_loss: 15.1016 - val_accuracy: 0.6250 - 8s/epoch - 134ms/step
# Epoch 120/300
#
# Epoch 120: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2082 - accuracy: 0.9271 - val_loss: 21.2076 - val_accuracy: 0.6250 - 8s/epoch - 149ms/step
# Epoch 121/300
#
# Epoch 121: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2056 - accuracy: 0.9240 - val_loss: 21.1591 - val_accuracy: 0.6250 - 7s/epoch - 131ms/step
# Epoch 122/300
#
# Epoch 122: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2035 - accuracy: 0.9311 - val_loss: 8.6908 - val_accuracy: 0.5417 - 7s/epoch - 132ms/step
# Epoch 123/300
#
# Epoch 123: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1945 - accuracy: 0.9319 - val_loss: 6.6725 - val_accuracy: 0.4668 - 8s/epoch - 146ms/step
# Epoch 124/300
#
# Epoch 124: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2058 - accuracy: 0.9314 - val_loss: 17.7025 - val_accuracy: 0.6250 - 7s/epoch - 132ms/step
# Epoch 125/300
#
# Epoch 125: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1978 - accuracy: 0.9350 - val_loss: 9.0500 - val_accuracy: 0.5417 - 8s/epoch - 138ms/step
# Epoch 126/300
#
# Epoch 126: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2018 - accuracy: 0.9297 - val_loss: 10.4633 - val_accuracy: 0.4576 - 7s/epoch - 133ms/step
# Epoch 127/300
#
# Epoch 127: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2107 - accuracy: 0.9237 - val_loss: 10.6487 - val_accuracy: 0.4809 - 7s/epoch - 134ms/step
# Epoch 128/300
#
# Epoch 128: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2204 - accuracy: 0.9107 - val_loss: 5.5767 - val_accuracy: 0.4583 - 8s/epoch - 135ms/step
# Epoch 129/300
#
# Epoch 129: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2050 - accuracy: 0.9319 - val_loss: 4.2200 - val_accuracy: 0.5056 - 8s/epoch - 147ms/step
# Epoch 130/300
#
# Epoch 130: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2022 - accuracy: 0.9263 - val_loss: 6.4125 - val_accuracy: 0.4887 - 8s/epoch - 139ms/step
# Epoch 131/300
#
# Epoch 131: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2052 - accuracy: 0.9198 - val_loss: 4.6476 - val_accuracy: 0.5290 - 8s/epoch - 139ms/step
# Epoch 132/300
#
# Epoch 132: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2067 - accuracy: 0.9277 - val_loss: 6.6959 - val_accuracy: 0.4880 - 8s/epoch - 137ms/step
# Epoch 133/300
#
# Epoch 133: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2100 - accuracy: 0.9209 - val_loss: 5.6048 - val_accuracy: 0.5028 - 7s/epoch - 133ms/step
# Epoch 134/300
#
# Epoch 134: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1921 - accuracy: 0.9390 - val_loss: 6.6819 - val_accuracy: 0.5000 - 8s/epoch - 136ms/step
# Epoch 135/300
#
# Epoch 135: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2027 - accuracy: 0.9308 - val_loss: 10.4008 - val_accuracy: 0.5092 - 7s/epoch - 132ms/step
# Epoch 136/300
#
# Epoch 136: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1943 - accuracy: 0.9381 - val_loss: 11.4743 - val_accuracy: 0.4788 - 8s/epoch - 138ms/step
# Epoch 137/300
#
# Epoch 137: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1922 - accuracy: 0.9282 - val_loss: 5.8559 - val_accuracy: 0.4153 - 8s/epoch - 138ms/step
# Epoch 138/300
#
# Epoch 138: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1922 - accuracy: 0.9379 - val_loss: 6.4693 - val_accuracy: 0.4555 - 8s/epoch - 135ms/step
# Epoch 139/300
#
# Epoch 139: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1898 - accuracy: 0.9353 - val_loss: 5.0052 - val_accuracy: 0.4145 - 7s/epoch - 133ms/step
# Epoch 140/300
#
# Epoch 140: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2048 - accuracy: 0.9302 - val_loss: 5.6628 - val_accuracy: 0.4936 - 8s/epoch - 134ms/step
# Epoch 141/300
#
# Epoch 141: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1883 - accuracy: 0.9379 - val_loss: 5.3699 - val_accuracy: 0.5198 - 8s/epoch - 134ms/step
# Epoch 142/300
#
# Epoch 142: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1916 - accuracy: 0.9367 - val_loss: 5.2662 - val_accuracy: 0.5290 - 7s/epoch - 133ms/step
# Epoch 143/300
#
# Epoch 143: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1923 - accuracy: 0.9359 - val_loss: 16.6558 - val_accuracy: 0.6179 - 8s/epoch - 140ms/step
# Epoch 144/300
#
# Epoch 144: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.2040 - accuracy: 0.9215 - val_loss: 18.2377 - val_accuracy: 0.6250 - 7s/epoch - 131ms/step
# Epoch 145/300
#
# Epoch 145: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1987 - accuracy: 0.9294 - val_loss: 11.6114 - val_accuracy: 0.5417 - 8s/epoch - 135ms/step
# Epoch 146/300
#
# Epoch 146: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.2108 - accuracy: 0.9345 - val_loss: 9.0774 - val_accuracy: 0.5417 - 8s/epoch - 135ms/step
# Epoch 147/300
#
# Epoch 147: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1902 - accuracy: 0.9316 - val_loss: 4.7816 - val_accuracy: 0.5650 - 8s/epoch - 136ms/step
# Epoch 148/300
#
# Epoch 148: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1849 - accuracy: 0.9381 - val_loss: 4.5675 - val_accuracy: 0.5424 - 7s/epoch - 133ms/step
# Epoch 149/300
#
# Epoch 149: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1808 - accuracy: 0.9412 - val_loss: 4.4741 - val_accuracy: 0.6144 - 8s/epoch - 145ms/step
# Epoch 150/300
#
# Epoch 150: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1808 - accuracy: 0.9424 - val_loss: 4.0697 - val_accuracy: 0.5332 - 8s/epoch - 143ms/step
# Epoch 151/300
#
# Epoch 151: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1896 - accuracy: 0.9376 - val_loss: 6.7833 - val_accuracy: 0.4908 - 8s/epoch - 139ms/step
# Epoch 152/300
#
# Epoch 152: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1760 - accuracy: 0.9446 - val_loss: 10.3280 - val_accuracy: 0.4831 - 8s/epoch - 141ms/step
# Epoch 153/300
#
# Epoch 153: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1800 - accuracy: 0.9407 - val_loss: 13.1249 - val_accuracy: 0.4583 - 8s/epoch - 142ms/step
# Epoch 154/300
#
# Epoch 154: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1954 - accuracy: 0.9364 - val_loss: 5.1792 - val_accuracy: 0.5890 - 8s/epoch - 143ms/step
# Epoch 155/300
#
# Epoch 155: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1878 - accuracy: 0.9359 - val_loss: 5.1471 - val_accuracy: 0.5000 - 8s/epoch - 149ms/step
# Epoch 156/300
#
# Epoch 156: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1807 - accuracy: 0.9418 - val_loss: 4.7107 - val_accuracy: 0.5297 - 8s/epoch - 142ms/step
# Epoch 157/300
#
# Epoch 157: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1854 - accuracy: 0.9412 - val_loss: 9.0556 - val_accuracy: 0.5417 - 8s/epoch - 137ms/step
# Epoch 158/300
#
# Epoch 158: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1885 - accuracy: 0.9336 - val_loss: 4.1197 - val_accuracy: 0.5007 - 8s/epoch - 138ms/step
# Epoch 159/300
#
# Epoch 159: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1866 - accuracy: 0.9390 - val_loss: 6.5297 - val_accuracy: 0.4718 - 8s/epoch - 138ms/step
# Epoch 160/300
#
# Epoch 160: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1751 - accuracy: 0.9466 - val_loss: 6.8564 - val_accuracy: 0.4569 - 8s/epoch - 143ms/step
# Epoch 161/300
#
# Epoch 161: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1830 - accuracy: 0.9395 - val_loss: 5.8777 - val_accuracy: 0.5261 - 8s/epoch - 137ms/step
# Epoch 162/300
#
# Epoch 162: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1763 - accuracy: 0.9458 - val_loss: 5.1082 - val_accuracy: 0.6179 - 8s/epoch - 134ms/step
# Epoch 163/300
#
# Epoch 163: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1878 - accuracy: 0.9441 - val_loss: 5.3636 - val_accuracy: 0.6095 - 8s/epoch - 135ms/step
# Epoch 164/300
#
# Epoch 164: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1807 - accuracy: 0.9364 - val_loss: 4.9254 - val_accuracy: 0.5254 - 8s/epoch - 141ms/step
# Epoch 165/300
#
# Epoch 165: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1834 - accuracy: 0.9342 - val_loss: 5.8829 - val_accuracy: 0.5290 - 8s/epoch - 140ms/step
# Epoch 166/300
#
# Epoch 166: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1749 - accuracy: 0.9466 - val_loss: 10.7163 - val_accuracy: 0.5417 - 8s/epoch - 143ms/step
# Epoch 167/300
#
# Epoch 167: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1763 - accuracy: 0.9444 - val_loss: 19.3545 - val_accuracy: 0.6073 - 7s/epoch - 132ms/step
# Epoch 168/300
#
# Epoch 168: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1828 - accuracy: 0.9381 - val_loss: 12.3996 - val_accuracy: 0.5417 - 7s/epoch - 133ms/step
# Epoch 169/300
#
# Epoch 169: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1771 - accuracy: 0.9500 - val_loss: 8.1670 - val_accuracy: 0.5417 - 7s/epoch - 132ms/step
# Epoch 170/300
#
# Epoch 170: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1755 - accuracy: 0.9435 - val_loss: 9.6306 - val_accuracy: 0.5417 - 8s/epoch - 139ms/step
# Epoch 171/300
#
# Epoch 171: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1723 - accuracy: 0.9418 - val_loss: 6.5774 - val_accuracy: 0.5106 - 7s/epoch - 132ms/step
# Epoch 172/300
#
# Epoch 172: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1737 - accuracy: 0.9412 - val_loss: 6.6877 - val_accuracy: 0.3566 - 7s/epoch - 133ms/step
# Epoch 173/300
#
# Epoch 173: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1889 - accuracy: 0.9331 - val_loss: 5.7120 - val_accuracy: 0.4230 - 8s/epoch - 137ms/step
# Epoch 174/300
#
# Epoch 174: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1845 - accuracy: 0.9373 - val_loss: 6.5795 - val_accuracy: 0.4576 - 8s/epoch - 134ms/step
# Epoch 175/300
#
# Epoch 175: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1706 - accuracy: 0.9460 - val_loss: 6.4174 - val_accuracy: 0.4230 - 7s/epoch - 134ms/step
# Epoch 176/300
#
# Epoch 176: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1797 - accuracy: 0.9410 - val_loss: 5.6367 - val_accuracy: 0.5106 - 8s/epoch - 135ms/step
# Epoch 177/300
#
# Epoch 177: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1762 - accuracy: 0.9444 - val_loss: 18.6114 - val_accuracy: 0.6243 - 8s/epoch - 134ms/step
# Epoch 178/300
#
# Epoch 178: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1712 - accuracy: 0.9438 - val_loss: 9.0356 - val_accuracy: 0.5417 - 8s/epoch - 137ms/step
# Epoch 179/300
#
# Epoch 179: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1762 - accuracy: 0.9376 - val_loss: 6.0602 - val_accuracy: 0.4887 - 8s/epoch - 147ms/step
# Epoch 180/300
#
# Epoch 180: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1794 - accuracy: 0.9418 - val_loss: 20.5223 - val_accuracy: 0.5847 - 8s/epoch - 137ms/step
# Epoch 181/300
#
# Epoch 181: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1670 - accuracy: 0.9503 - val_loss: 6.4106 - val_accuracy: 0.5021 - 8s/epoch - 135ms/step
# Epoch 182/300
#
# Epoch 182: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1617 - accuracy: 0.9534 - val_loss: 12.6482 - val_accuracy: 0.5417 - 8s/epoch - 148ms/step
# Epoch 183/300
#
# Epoch 183: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1705 - accuracy: 0.9463 - val_loss: 5.5435 - val_accuracy: 0.5508 - 7s/epoch - 132ms/step
# Epoch 184/300
#
# Epoch 184: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1777 - accuracy: 0.9418 - val_loss: 6.5852 - val_accuracy: 0.5141 - 7s/epoch - 133ms/step
# Epoch 185/300
#
# Epoch 185: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1693 - accuracy: 0.9517 - val_loss: 8.4001 - val_accuracy: 0.4718 - 7s/epoch - 133ms/step
# Epoch 186/300
#
# Epoch 186: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1677 - accuracy: 0.9494 - val_loss: 10.4518 - val_accuracy: 0.5169 - 7s/epoch - 132ms/step
# Epoch 187/300
#
# Epoch 187: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1663 - accuracy: 0.9455 - val_loss: 7.9854 - val_accuracy: 0.5035 - 7s/epoch - 133ms/step
# Epoch 188/300
#
# Epoch 188: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1716 - accuracy: 0.9444 - val_loss: 10.6408 - val_accuracy: 0.5000 - 7s/epoch - 132ms/step
# Epoch 189/300
#
# Epoch 189: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1802 - accuracy: 0.9373 - val_loss: 6.4940 - val_accuracy: 0.5975 - 7s/epoch - 132ms/step
# Epoch 190/300
#
# Epoch 190: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1602 - accuracy: 0.9537 - val_loss: 6.2840 - val_accuracy: 0.5049 - 7s/epoch - 133ms/step
# Epoch 191/300
#
# Epoch 191: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1663 - accuracy: 0.9458 - val_loss: 6.3412 - val_accuracy: 0.5141 - 7s/epoch - 132ms/step
# Epoch 192/300
#
# Epoch 192: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1701 - accuracy: 0.9460 - val_loss: 5.2112 - val_accuracy: 0.6073 - 7s/epoch - 132ms/step
# Epoch 193/300
#
# Epoch 193: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1662 - accuracy: 0.9466 - val_loss: 7.0423 - val_accuracy: 0.5007 - 7s/epoch - 133ms/step
# Epoch 194/300
#
# Epoch 194: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1666 - accuracy: 0.9517 - val_loss: 6.6203 - val_accuracy: 0.4329 - 7s/epoch - 132ms/step
# Epoch 195/300
#
# Epoch 195: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1629 - accuracy: 0.9511 - val_loss: 6.8292 - val_accuracy: 0.3658 - 7s/epoch - 132ms/step
# Epoch 196/300
#
# Epoch 196: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1592 - accuracy: 0.9568 - val_loss: 6.4906 - val_accuracy: 0.5141 - 7s/epoch - 133ms/step
# Epoch 197/300
#
# Epoch 197: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1801 - accuracy: 0.9390 - val_loss: 6.7952 - val_accuracy: 0.4774 - 7s/epoch - 133ms/step
# Epoch 198/300
#
# Epoch 198: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1723 - accuracy: 0.9404 - val_loss: 9.2734 - val_accuracy: 0.5417 - 7s/epoch - 132ms/step
# Epoch 199/300
#
# Epoch 199: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1592 - accuracy: 0.9506 - val_loss: 6.3319 - val_accuracy: 0.4562 - 7s/epoch - 133ms/step
# Epoch 200/300
#
# Epoch 200: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1707 - accuracy: 0.9497 - val_loss: 9.4636 - val_accuracy: 0.5417 - 7s/epoch - 134ms/step
# Epoch 201/300
#
# Epoch 201: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1637 - accuracy: 0.9528 - val_loss: 8.3648 - val_accuracy: 0.5417 - 7s/epoch - 132ms/step
# Epoch 202/300
#
# Epoch 202: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1635 - accuracy: 0.9514 - val_loss: 10.8300 - val_accuracy: 0.4951 - 7s/epoch - 131ms/step
# Epoch 203/300
#
# Epoch 203: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1707 - accuracy: 0.9469 - val_loss: 7.8837 - val_accuracy: 0.5155 - 7s/epoch - 131ms/step
# Epoch 204/300
#
# Epoch 204: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1673 - accuracy: 0.9483 - val_loss: 9.4121 - val_accuracy: 0.5035 - 7s/epoch - 131ms/step
# Epoch 205/300
#
# Epoch 205: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1752 - accuracy: 0.9390 - val_loss: 7.6874 - val_accuracy: 0.4915 - 7s/epoch - 131ms/step
# Epoch 206/300
#
# Epoch 206: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1812 - accuracy: 0.9381 - val_loss: 15.8722 - val_accuracy: 0.5833 - 7s/epoch - 131ms/step
# Epoch 207/300
#
# Epoch 207: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1503 - accuracy: 0.9565 - val_loss: 17.9510 - val_accuracy: 0.5869 - 7s/epoch - 130ms/step
# Epoch 208/300
#
# Epoch 208: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1522 - accuracy: 0.9565 - val_loss: 7.9200 - val_accuracy: 0.5417 - 7s/epoch - 130ms/step
# Epoch 209/300
#
# Epoch 209: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1648 - accuracy: 0.9477 - val_loss: 5.7818 - val_accuracy: 0.5219 - 7s/epoch - 131ms/step
# Epoch 210/300
#
# Epoch 210: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1660 - accuracy: 0.9520 - val_loss: 8.3370 - val_accuracy: 0.5417 - 7s/epoch - 132ms/step
# Epoch 211/300
#
# Epoch 211: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1548 - accuracy: 0.9545 - val_loss: 9.2574 - val_accuracy: 0.5417 - 7s/epoch - 130ms/step
# Epoch 212/300
#
# Epoch 212: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1546 - accuracy: 0.9494 - val_loss: 5.8595 - val_accuracy: 0.5261 - 7s/epoch - 130ms/step
# Epoch 213/300
#
# Epoch 213: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1556 - accuracy: 0.9540 - val_loss: 6.1670 - val_accuracy: 0.5600 - 7s/epoch - 131ms/step
# Epoch 214/300
#
# Epoch 214: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1555 - accuracy: 0.9514 - val_loss: 6.0858 - val_accuracy: 0.5607 - 7s/epoch - 131ms/step
# Epoch 215/300
#
# Epoch 215: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1643 - accuracy: 0.9489 - val_loss: 9.5608 - val_accuracy: 0.5035 - 7s/epoch - 131ms/step
# Epoch 216/300
#
# Epoch 216: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1599 - accuracy: 0.9511 - val_loss: 6.2021 - val_accuracy: 0.4230 - 7s/epoch - 131ms/step
# Epoch 217/300
#
# Epoch 217: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1602 - accuracy: 0.9477 - val_loss: 7.0629 - val_accuracy: 0.5339 - 7s/epoch - 132ms/step
# Epoch 218/300
#
# Epoch 218: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1517 - accuracy: 0.9520 - val_loss: 9.6532 - val_accuracy: 0.5417 - 7s/epoch - 131ms/step
# Epoch 219/300
#
# Epoch 219: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1569 - accuracy: 0.9508 - val_loss: 9.9478 - val_accuracy: 0.5417 - 8s/epoch - 134ms/step
# Epoch 220/300
#
# Epoch 220: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1559 - accuracy: 0.9517 - val_loss: 12.6930 - val_accuracy: 0.5417 - 7s/epoch - 134ms/step
# Epoch 221/300
#
# Epoch 221: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1635 - accuracy: 0.9480 - val_loss: 9.3831 - val_accuracy: 0.5417 - 7s/epoch - 131ms/step
# Epoch 222/300
#
# Epoch 222: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1528 - accuracy: 0.9548 - val_loss: 7.5933 - val_accuracy: 0.3482 - 7s/epoch - 132ms/step
# Epoch 223/300
#
# Epoch 223: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1583 - accuracy: 0.9511 - val_loss: 11.4415 - val_accuracy: 0.5049 - 7s/epoch - 130ms/step
# Epoch 224/300
#
# Epoch 224: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1592 - accuracy: 0.9537 - val_loss: 9.9483 - val_accuracy: 0.5184 - 7s/epoch - 131ms/step
# Epoch 225/300
#
# Epoch 225: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1499 - accuracy: 0.9540 - val_loss: 10.9767 - val_accuracy: 0.5035 - 7s/epoch - 132ms/step
# Epoch 226/300
#
# Epoch 226: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1513 - accuracy: 0.9520 - val_loss: 13.0526 - val_accuracy: 0.5417 - 7s/epoch - 131ms/step
# Epoch 227/300
#
# Epoch 227: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1610 - accuracy: 0.9424 - val_loss: 6.9415 - val_accuracy: 0.5226 - 7s/epoch - 131ms/step
# Epoch 228/300
#
# Epoch 228: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1476 - accuracy: 0.9562 - val_loss: 7.1779 - val_accuracy: 0.5085 - 7s/epoch - 130ms/step
# Epoch 229/300
#
# Epoch 229: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1512 - accuracy: 0.9492 - val_loss: 12.2959 - val_accuracy: 0.5417 - 7s/epoch - 130ms/step
# Epoch 230/300
#
# Epoch 230: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1570 - accuracy: 0.9449 - val_loss: 7.7760 - val_accuracy: 0.6010 - 7s/epoch - 131ms/step
# Epoch 231/300
#
# Epoch 231: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1509 - accuracy: 0.9537 - val_loss: 6.9009 - val_accuracy: 0.5953 - 7s/epoch - 130ms/step
# Epoch 232/300
#
# Epoch 232: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1431 - accuracy: 0.9593 - val_loss: 9.5848 - val_accuracy: 0.5120 - 7s/epoch - 131ms/step
# Epoch 233/300
#
# Epoch 233: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1590 - accuracy: 0.9497 - val_loss: 7.4088 - val_accuracy: 0.4873 - 7s/epoch - 131ms/step
# Epoch 234/300
#
# Epoch 234: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1600 - accuracy: 0.9483 - val_loss: 6.3512 - val_accuracy: 0.3919 - 7s/epoch - 131ms/step
# Epoch 235/300
#
# Epoch 235: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1493 - accuracy: 0.9582 - val_loss: 8.4766 - val_accuracy: 0.4583 - 7s/epoch - 131ms/step
# Epoch 236/300
#
# Epoch 236: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1643 - accuracy: 0.9455 - val_loss: 6.6086 - val_accuracy: 0.5127 - 7s/epoch - 131ms/step
# Epoch 237/300
#
# Epoch 237: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1487 - accuracy: 0.9551 - val_loss: 6.2620 - val_accuracy: 0.5169 - 7s/epoch - 132ms/step
# Epoch 238/300
#
# Epoch 238: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1493 - accuracy: 0.9531 - val_loss: 6.6601 - val_accuracy: 0.5000 - 7s/epoch - 131ms/step
# Epoch 239/300
#
# Epoch 239: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1491 - accuracy: 0.9588 - val_loss: 6.6413 - val_accuracy: 0.5643 - 7s/epoch - 132ms/step
# Epoch 240/300
#
# Epoch 240: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1466 - accuracy: 0.9531 - val_loss: 6.0436 - val_accuracy: 0.5290 - 7s/epoch - 131ms/step
# Epoch 241/300
#
# Epoch 241: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1447 - accuracy: 0.9551 - val_loss: 6.4100 - val_accuracy: 0.5212 - 7s/epoch - 131ms/step
# Epoch 242/300
#
# Epoch 242: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1454 - accuracy: 0.9525 - val_loss: 6.7335 - val_accuracy: 0.5064 - 7s/epoch - 133ms/step
# Epoch 243/300
#
# Epoch 243: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1642 - accuracy: 0.9435 - val_loss: 6.2193 - val_accuracy: 0.5544 - 7s/epoch - 133ms/step
# Epoch 244/300
#
# Epoch 244: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1564 - accuracy: 0.9497 - val_loss: 10.1813 - val_accuracy: 0.5417 - 7s/epoch - 131ms/step
# Epoch 245/300
#
# Epoch 245: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1618 - accuracy: 0.9497 - val_loss: 7.2132 - val_accuracy: 0.5021 - 7s/epoch - 131ms/step
# Epoch 246/300
#
# Epoch 246: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1622 - accuracy: 0.9525 - val_loss: 12.0396 - val_accuracy: 0.5417 - 7s/epoch - 133ms/step
# Epoch 247/300
#
# Epoch 247: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1566 - accuracy: 0.9540 - val_loss: 15.5643 - val_accuracy: 0.5417 - 7s/epoch - 132ms/step
# Epoch 248/300
#
# Epoch 248: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1403 - accuracy: 0.9562 - val_loss: 9.7495 - val_accuracy: 0.5417 - 7s/epoch - 134ms/step
# Epoch 249/300
#
# Epoch 249: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1505 - accuracy: 0.9523 - val_loss: 13.9996 - val_accuracy: 0.5417 - 7s/epoch - 130ms/step
# Epoch 250/300
#
# Epoch 250: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1424 - accuracy: 0.9585 - val_loss: 14.4171 - val_accuracy: 0.5417 - 7s/epoch - 131ms/step
# Epoch 251/300
#
# Epoch 251: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1511 - accuracy: 0.9551 - val_loss: 5.7892 - val_accuracy: 0.5275 - 7s/epoch - 130ms/step
# Epoch 252/300
#
# Epoch 252: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1458 - accuracy: 0.9548 - val_loss: 15.9733 - val_accuracy: 0.5417 - 7s/epoch - 133ms/step
# Epoch 253/300
#
# Epoch 253: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1395 - accuracy: 0.9573 - val_loss: 13.2444 - val_accuracy: 0.5417 - 7s/epoch - 131ms/step
# Epoch 254/300
#
# Epoch 254: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1500 - accuracy: 0.9514 - val_loss: 6.5779 - val_accuracy: 0.5049 - 7s/epoch - 130ms/step
# Epoch 255/300
#
# Epoch 255: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1460 - accuracy: 0.9548 - val_loss: 5.9097 - val_accuracy: 0.5480 - 7s/epoch - 132ms/step
# Epoch 256/300
#
# Epoch 256: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1678 - accuracy: 0.9421 - val_loss: 9.9405 - val_accuracy: 0.5417 - 7s/epoch - 131ms/step
# Epoch 257/300
#
# Epoch 257: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1557 - accuracy: 0.9545 - val_loss: 8.8694 - val_accuracy: 0.5417 - 7s/epoch - 131ms/step
# Epoch 258/300
#
# Epoch 258: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1439 - accuracy: 0.9576 - val_loss: 7.3383 - val_accuracy: 0.3630 - 7s/epoch - 132ms/step
# Epoch 259/300
#
# Epoch 259: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1456 - accuracy: 0.9545 - val_loss: 5.9623 - val_accuracy: 0.4499 - 7s/epoch - 130ms/step
# Epoch 260/300
#
# Epoch 260: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1511 - accuracy: 0.9525 - val_loss: 17.4467 - val_accuracy: 0.5833 - 7s/epoch - 131ms/step
# Epoch 261/300
#
# Epoch 261: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1563 - accuracy: 0.9506 - val_loss: 6.8423 - val_accuracy: 0.3404 - 7s/epoch - 130ms/step
# Epoch 262/300
#
# Epoch 262: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1431 - accuracy: 0.9562 - val_loss: 6.5982 - val_accuracy: 0.6285 - 7s/epoch - 133ms/step
# Epoch 263/300
#
# Epoch 263: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1598 - accuracy: 0.9500 - val_loss: 6.5679 - val_accuracy: 0.5134 - 7s/epoch - 130ms/step
# Epoch 264/300
#
# Epoch 264: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1475 - accuracy: 0.9497 - val_loss: 16.5627 - val_accuracy: 0.5791 - 7s/epoch - 131ms/step
# Epoch 265/300
#
# Epoch 265: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1442 - accuracy: 0.9483 - val_loss: 16.1540 - val_accuracy: 0.5586 - 7s/epoch - 130ms/step
# Epoch 266/300
#
# Epoch 266: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1466 - accuracy: 0.9576 - val_loss: 12.1022 - val_accuracy: 0.5417 - 7s/epoch - 131ms/step
# Epoch 267/300
#
# Epoch 267: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1402 - accuracy: 0.9624 - val_loss: 10.7637 - val_accuracy: 0.5417 - 7s/epoch - 130ms/step
# Epoch 268/300
#
# Epoch 268: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1453 - accuracy: 0.9542 - val_loss: 8.7659 - val_accuracy: 0.5417 - 7s/epoch - 131ms/step
# Epoch 269/300
#
# Epoch 269: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1485 - accuracy: 0.9551 - val_loss: 6.9389 - val_accuracy: 0.3545 - 7s/epoch - 132ms/step
# Epoch 270/300
#
# Epoch 270: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1475 - accuracy: 0.9520 - val_loss: 6.4443 - val_accuracy: 0.3545 - 7s/epoch - 132ms/step
# Epoch 271/300
#
# Epoch 271: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1547 - accuracy: 0.9497 - val_loss: 6.7779 - val_accuracy: 0.3376 - 7s/epoch - 133ms/step
# Epoch 272/300
#
# Epoch 272: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1507 - accuracy: 0.9540 - val_loss: 5.8945 - val_accuracy: 0.5311 - 7s/epoch - 132ms/step
# Epoch 273/300
#
# Epoch 273: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1428 - accuracy: 0.9559 - val_loss: 5.3736 - val_accuracy: 0.4442 - 7s/epoch - 132ms/step
# Epoch 274/300
#
# Epoch 274: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1454 - accuracy: 0.9511 - val_loss: 9.8329 - val_accuracy: 0.5417 - 7s/epoch - 131ms/step
# Epoch 275/300
#
# Epoch 275: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1470 - accuracy: 0.9489 - val_loss: 9.9958 - val_accuracy: 0.5417 - 7s/epoch - 130ms/step
# Epoch 276/300
#
# Epoch 276: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1491 - accuracy: 0.9506 - val_loss: 21.0367 - val_accuracy: 0.5840 - 7s/epoch - 131ms/step
# Epoch 277/300
#
# Epoch 277: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1496 - accuracy: 0.9556 - val_loss: 9.2351 - val_accuracy: 0.5417 - 7s/epoch - 131ms/step
# Epoch 278/300
#
# Epoch 278: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1488 - accuracy: 0.9525 - val_loss: 10.0895 - val_accuracy: 0.5417 - 7s/epoch - 133ms/step
# Epoch 279/300
#
# Epoch 279: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1351 - accuracy: 0.9579 - val_loss: 8.0526 - val_accuracy: 0.5056 - 7s/epoch - 131ms/step
# Epoch 280/300
#
# Epoch 280: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1438 - accuracy: 0.9528 - val_loss: 11.6688 - val_accuracy: 0.5417 - 7s/epoch - 130ms/step
# Epoch 281/300
#
# Epoch 281: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1308 - accuracy: 0.9596 - val_loss: 8.1709 - val_accuracy: 0.4986 - 7s/epoch - 130ms/step
# Epoch 282/300
#
# Epoch 282: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1421 - accuracy: 0.9540 - val_loss: 14.5769 - val_accuracy: 0.5417 - 7s/epoch - 131ms/step
# Epoch 283/300
#
# Epoch 283: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1407 - accuracy: 0.9582 - val_loss: 16.4884 - val_accuracy: 0.5565 - 7s/epoch - 131ms/step
# Epoch 284/300
#
# Epoch 284: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1336 - accuracy: 0.9582 - val_loss: 10.8165 - val_accuracy: 0.5417 - 7s/epoch - 130ms/step
# Epoch 285/300
#
# Epoch 285: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1393 - accuracy: 0.9559 - val_loss: 11.9720 - val_accuracy: 0.5417 - 7s/epoch - 131ms/step
# Epoch 286/300
#
# Epoch 286: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1456 - accuracy: 0.9525 - val_loss: 6.0236 - val_accuracy: 0.5925 - 8s/epoch - 136ms/step
# Epoch 287/300
#
# Epoch 287: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1464 - accuracy: 0.9534 - val_loss: 5.6913 - val_accuracy: 0.5960 - 8s/epoch - 138ms/step
# Epoch 288/300
#
# Epoch 288: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1373 - accuracy: 0.9585 - val_loss: 5.8644 - val_accuracy: 0.3460 - 8s/epoch - 139ms/step
# Epoch 289/300
#
# Epoch 289: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1384 - accuracy: 0.9576 - val_loss: 5.1800 - val_accuracy: 0.5120 - 7s/epoch - 131ms/step
# Epoch 290/300
#
# Epoch 290: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1510 - accuracy: 0.9477 - val_loss: 5.7491 - val_accuracy: 0.5791 - 7s/epoch - 132ms/step
# Epoch 291/300
#
# Epoch 291: val_loss did not improve from 0.67609
# 56/56 - 8s - loss: 0.1371 - accuracy: 0.9596 - val_loss: 6.4468 - val_accuracy: 0.5169 - 8s/epoch - 143ms/step
# Epoch 292/300
#
# Epoch 292: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1359 - accuracy: 0.9605 - val_loss: 7.0784 - val_accuracy: 0.3376 - 7s/epoch - 131ms/step
# Epoch 293/300
#
# Epoch 293: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1343 - accuracy: 0.9548 - val_loss: 6.7575 - val_accuracy: 0.5162 - 7s/epoch - 130ms/step
# Epoch 294/300
#
# Epoch 294: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1514 - accuracy: 0.9520 - val_loss: 6.1812 - val_accuracy: 0.5021 - 7s/epoch - 132ms/step
# Epoch 295/300
#
# Epoch 295: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1396 - accuracy: 0.9571 - val_loss: 7.5066 - val_accuracy: 0.4894 - 7s/epoch - 131ms/step
# Epoch 296/300
#
# Epoch 296: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1348 - accuracy: 0.9613 - val_loss: 7.0350 - val_accuracy: 0.5247 - 7s/epoch - 132ms/step
# Epoch 297/300
#
# Epoch 297: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1306 - accuracy: 0.9571 - val_loss: 6.5317 - val_accuracy: 0.5643 - 7s/epoch - 131ms/step
# Epoch 298/300
#
# Epoch 298: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1436 - accuracy: 0.9542 - val_loss: 6.0659 - val_accuracy: 0.6448 - 7s/epoch - 131ms/step
# Epoch 299/300
#
# Epoch 299: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1332 - accuracy: 0.9582 - val_loss: 6.3108 - val_accuracy: 0.6321 - 7s/epoch - 130ms/step
# Epoch 300/300
#
# Epoch 300: val_loss did not improve from 0.67609
# 56/56 - 7s - loss: 0.1519 - accuracy: 0.9480 - val_loss: 6.3600 - val_accuracy: 0.5939 - 7s/epoch - 130ms/step
# 45/45 [==============================] - 1s 10ms/step
# Classification accuracy: 0.541667
# /Users/idaandreassen/opt/anaconda3/envs/mne/lib/python3.9/site-packages/pyriemann/utils/viz.py:24: RuntimeWarning: invalid value encountered in true_divide
#   cm = 100 * cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]

# %%
from metrics import compute_metrics
pred = probs_eeg.argmax(axis = -1)
metrics = compute_metrics(test_labels, pred)
