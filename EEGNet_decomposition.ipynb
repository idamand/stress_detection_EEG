# %%
from utils.valid_recordings import get_valid_recordings
from utils.data_processing import extract_eeg_data, segment_data, train_test_val_split, dict_to_arr
from pre_processing import filter_EEG
from classifiers import EEGNet_classifier
from utils.labels import get_stai_labels, get_pss_labels
import numpy as np

# %%
valid_recordings = get_valid_recordings('raw')
non_decomposed_data = extract_eeg_data(valid_recordings=valid_recordings, data_type='raw')
labels = get_stai_labels(valid_recordings=valid_recordings, cutoff=40)
# Out:
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# ERROR:root:Failed to read data for recording P006_S002_001
# ERROR:root:Failed to read data for recording P006_S002_002
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74912
#     Range : 0 ... 74911 =      0.000 ...   299.644 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74944
#     Range : 0 ... 74943 =      0.000 ...   299.772 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74912
#     Range : 0 ... 74911 =      0.000 ...   299.644 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74896
#     Range : 0 ... 74895 =      0.000 ...   299.580 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74960
#     Range : 0 ... 74959 =      0.000 ...   299.836 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# ERROR:root:Failed to read data for recording P028_S002_001
# ERROR:root:Failed to read data for recording P028_S002_002
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74912
#     Range : 0 ... 74911 =      0.000 ...   299.644 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74944
#     Range : 0 ... 74943 =      0.000 ...   299.772 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74912
#     Range : 0 ... 74911 =      0.000 ...   299.644 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74896
#     Range : 0 ... 74895 =      0.000 ...   299.580 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=74960
#     Range : 0 ... 74959 =      0.000 ...   299.836 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.

# %%
filtered_data = filter_EEG(non_decomposed_data, low_freq=30, high_freq=None)
# Out:
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=74912
#     Range : 0 ... 74911 =      0.000 ...   299.644 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=74944
#     Range : 0 ... 74943 =      0.000 ...   299.772 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=74912
#     Range : 0 ... 74911 =      0.000 ...   299.644 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ...
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Setting up high-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal highpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 30.00
# - Lower transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 26.25 Hz)
# - Filter length: 111 samples (0.444 sec)
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished

# %%
segmented_data, segmented_labels = segment_data(filtered_data, labels, epoch_duration=5)
# Out:
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 59 events and 1251 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 59 events and 1251 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 59 events and 1251 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 59 events and 1251 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 59 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 59 events and 1251 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped
# Not setting metadata
# 60 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 60 events and 1251 original time points ...
# 1 bad epochs dropped

# %%
train_data_dict, train_labels_dict, test_data_dict, test_labels_dict, val_data_dict, val_labels_dict = train_test_val_split(segmented_data, segmented_labels)
    
train_data      = dict_to_arr(train_data_dict)
test_data       = dict_to_arr(test_data_dict)
val_data        = dict_to_arr(val_data_dict)

train_labels    = np.reshape(np.array(list(train_labels_dict.values())), (len(train_data_dict),1))
test_labels     = np.reshape(np.array(list(test_labels_dict.values())), (len(test_data_dict),1))
val_labels      = np.reshape(np.array(list(val_labels_dict.values())), (len(val_data_dict),1))

print(f"Shape of train data set: {train_data.shape}")
print(f"Shape of train labels set: {train_labels.shape}")

print(f"Shape of test data set: {test_data.shape}")
print(f"Shape of test labels set: {test_labels.shape}")

print(f"Shape of validation data set: {val_data.shape}")
print(f"Shape of validation labels set: {val_labels.shape}")
# Out:
# Subjects test:  ['P011', 'P020', 'P015', 'P014', 'P008', 'P009']
#  Subjects train:  ['P016', 'P006', 'P019', 'P022', 'P018', 'P002', 'P013', 'P027', 'P004', 'P028', 'P003', 'P024', 'P007', 'P017', 'P026', 'P023']
#  Subjects val:  ['P021', 'P005', 'P025', 'P010', 'P001', 'P012']
# Shape of train data set: (3540, 8, 1251)
# Shape of train labels set: (3540, 1)
# Shape of test data set: (1416, 8, 1251)
# Shape of test labels set: (1416, 1)
# Shape of validation data set: (1416, 8, 1251)
# Shape of validation labels set: (1416, 1)

# %%
probs_eeg = EEGNet_classifier(train_data, test_data, val_data, train_labels, test_labels, val_labels)
# Out:
# Epoch 1/300
#
# Epoch 1: val_loss improved from inf to 0.67571, saving model to /tmp/checkpoint.h5
# 56/56 - 5s - loss: 0.6745 - accuracy: 0.5291 - val_loss: 0.6757 - val_accuracy: 0.6250 - 5s/epoch - 95ms/step
# Epoch 2/300
#
# Epoch 2: val_loss did not improve from 0.67571
# 56/56 - 4s - loss: 0.6612 - accuracy: 0.5554 - val_loss: 0.6812 - val_accuracy: 0.6250 - 4s/epoch - 79ms/step
# Epoch 3/300
#
# Epoch 3: val_loss did not improve from 0.67571
# 56/56 - 4s - loss: 0.6308 - accuracy: 0.5873 - val_loss: 0.6855 - val_accuracy: 0.6250 - 4s/epoch - 78ms/step
# Epoch 4/300
#
# Epoch 4: val_loss did not improve from 0.67571
# 56/56 - 4s - loss: 0.5902 - accuracy: 0.6435 - val_loss: 0.7462 - val_accuracy: 0.3750 - 4s/epoch - 79ms/step
# Epoch 5/300
#
# Epoch 5: val_loss did not improve from 0.67571
# 56/56 - 4s - loss: 0.5284 - accuracy: 0.7017 - val_loss: 0.7105 - val_accuracy: 0.3750 - 4s/epoch - 79ms/step
# Epoch 6/300
#
# Epoch 6: val_loss improved from 0.67571 to 0.66236, saving model to /tmp/checkpoint.h5
# 56/56 - 4s - loss: 0.4907 - accuracy: 0.7141 - val_loss: 0.6624 - val_accuracy: 0.6250 - 4s/epoch - 79ms/step
# Epoch 7/300
#
# Epoch 7: val_loss did not improve from 0.66236
# 56/56 - 5s - loss: 0.4658 - accuracy: 0.7246 - val_loss: 1.0847 - val_accuracy: 0.3750 - 5s/epoch - 88ms/step
# Epoch 8/300
#
# Epoch 8: val_loss did not improve from 0.66236
# 56/56 - 6s - loss: 0.4616 - accuracy: 0.7367 - val_loss: 2.3959 - val_accuracy: 0.3750 - 6s/epoch - 107ms/step
# Epoch 9/300
#
# Epoch 9: val_loss did not improve from 0.66236
# 56/56 - 5s - loss: 0.4335 - accuracy: 0.7540 - val_loss: 3.5295 - val_accuracy: 0.3750 - 5s/epoch - 95ms/step
# Epoch 10/300
#
# Epoch 10: val_loss did not improve from 0.66236
# 56/56 - 5s - loss: 0.4317 - accuracy: 0.7596 - val_loss: 4.4899 - val_accuracy: 0.3750 - 5s/epoch - 90ms/step
# Epoch 11/300
#
# Epoch 11: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.4224 - accuracy: 0.7678 - val_loss: 3.2669 - val_accuracy: 0.3750 - 4s/epoch - 79ms/step
# Epoch 12/300
#
# Epoch 12: val_loss did not improve from 0.66236
# 56/56 - 5s - loss: 0.4218 - accuracy: 0.7720 - val_loss: 0.9499 - val_accuracy: 0.6377 - 5s/epoch - 85ms/step
# Epoch 13/300
#
# Epoch 13: val_loss did not improve from 0.66236
# 56/56 - 5s - loss: 0.3970 - accuracy: 0.7864 - val_loss: 0.7949 - val_accuracy: 0.5473 - 5s/epoch - 83ms/step
# Epoch 14/300
#
# Epoch 14: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3827 - accuracy: 0.7975 - val_loss: 1.6422 - val_accuracy: 0.6123 - 4s/epoch - 80ms/step
# Epoch 15/300
#
# Epoch 15: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3948 - accuracy: 0.7969 - val_loss: 2.2377 - val_accuracy: 0.6038 - 4s/epoch - 80ms/step
# Epoch 16/300
#
# Epoch 16: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.4042 - accuracy: 0.7862 - val_loss: 1.0540 - val_accuracy: 0.6123 - 4s/epoch - 80ms/step
# Epoch 17/300
#
# Epoch 17: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3949 - accuracy: 0.7921 - val_loss: 2.0717 - val_accuracy: 0.5127 - 4s/epoch - 80ms/step
# Epoch 18/300
#
# Epoch 18: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3881 - accuracy: 0.7870 - val_loss: 1.2992 - val_accuracy: 0.6123 - 4s/epoch - 80ms/step
# Epoch 19/300
#
# Epoch 19: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3973 - accuracy: 0.7873 - val_loss: 1.3317 - val_accuracy: 0.6109 - 4s/epoch - 80ms/step
# Epoch 20/300
#
# Epoch 20: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3853 - accuracy: 0.7977 - val_loss: 1.7721 - val_accuracy: 0.6095 - 4s/epoch - 80ms/step
# Epoch 21/300
#
# Epoch 21: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3873 - accuracy: 0.7924 - val_loss: 4.8513 - val_accuracy: 0.6398 - 4s/epoch - 80ms/step
# Epoch 22/300
#
# Epoch 22: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3758 - accuracy: 0.8110 - val_loss: 3.3695 - val_accuracy: 0.6681 - 4s/epoch - 80ms/step
# Epoch 23/300
#
# Epoch 23: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3909 - accuracy: 0.7966 - val_loss: 5.0464 - val_accuracy: 0.6264 - 4s/epoch - 79ms/step
# Epoch 24/300
#
# Epoch 24: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3687 - accuracy: 0.8147 - val_loss: 1.5393 - val_accuracy: 0.6250 - 4s/epoch - 79ms/step
# Epoch 25/300
#
# Epoch 25: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3596 - accuracy: 0.8189 - val_loss: 2.0709 - val_accuracy: 0.4831 - 4s/epoch - 79ms/step
# Epoch 26/300
#
# Epoch 26: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3527 - accuracy: 0.8212 - val_loss: 1.3233 - val_accuracy: 0.5862 - 4s/epoch - 79ms/step
# Epoch 27/300
#
# Epoch 27: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3553 - accuracy: 0.8189 - val_loss: 6.8457 - val_accuracy: 0.3750 - 4s/epoch - 79ms/step
# Epoch 28/300
#
# Epoch 28: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3638 - accuracy: 0.8158 - val_loss: 4.4135 - val_accuracy: 0.6766 - 4s/epoch - 79ms/step
# Epoch 29/300
#
# Epoch 29: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3586 - accuracy: 0.8082 - val_loss: 2.0085 - val_accuracy: 0.4753 - 4s/epoch - 79ms/step
# Epoch 30/300
#
# Epoch 30: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3664 - accuracy: 0.8138 - val_loss: 4.0159 - val_accuracy: 0.4583 - 4s/epoch - 78ms/step
# Epoch 31/300
#
# Epoch 31: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3559 - accuracy: 0.8192 - val_loss: 1.4780 - val_accuracy: 0.5516 - 4s/epoch - 79ms/step
# Epoch 32/300
#
# Epoch 32: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3395 - accuracy: 0.8305 - val_loss: 5.7112 - val_accuracy: 0.6441 - 4s/epoch - 79ms/step
# Epoch 33/300
#
# Epoch 33: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3648 - accuracy: 0.8184 - val_loss: 7.5071 - val_accuracy: 0.6250 - 4s/epoch - 78ms/step
# Epoch 34/300
#
# Epoch 34: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3491 - accuracy: 0.8223 - val_loss: 2.2827 - val_accuracy: 0.6165 - 4s/epoch - 78ms/step
# Epoch 35/300
#
# Epoch 35: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3387 - accuracy: 0.8246 - val_loss: 9.6815 - val_accuracy: 0.3750 - 4s/epoch - 78ms/step
# Epoch 36/300
#
# Epoch 36: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3382 - accuracy: 0.8299 - val_loss: 8.1662 - val_accuracy: 0.3750 - 4s/epoch - 78ms/step
# Epoch 37/300
#
# Epoch 37: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3428 - accuracy: 0.8316 - val_loss: 7.2299 - val_accuracy: 0.3750 - 4s/epoch - 78ms/step
# Epoch 38/300
#
# Epoch 38: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3238 - accuracy: 0.8342 - val_loss: 6.7703 - val_accuracy: 0.3750 - 4s/epoch - 79ms/step
# Epoch 39/300
#
# Epoch 39: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3234 - accuracy: 0.8331 - val_loss: 11.1496 - val_accuracy: 0.3750 - 4s/epoch - 79ms/step
# Epoch 40/300
#
# Epoch 40: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3475 - accuracy: 0.8206 - val_loss: 8.8859 - val_accuracy: 0.3750 - 4s/epoch - 78ms/step
# Epoch 41/300
#
# Epoch 41: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3224 - accuracy: 0.8376 - val_loss: 12.2640 - val_accuracy: 0.3750 - 4s/epoch - 79ms/step
# Epoch 42/300
#
# Epoch 42: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3262 - accuracy: 0.8322 - val_loss: 5.7005 - val_accuracy: 0.3842 - 4s/epoch - 78ms/step
# Epoch 43/300
#
# Epoch 43: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3159 - accuracy: 0.8387 - val_loss: 9.7991 - val_accuracy: 0.3750 - 4s/epoch - 78ms/step
# Epoch 44/300
#
# Epoch 44: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3180 - accuracy: 0.8331 - val_loss: 8.1958 - val_accuracy: 0.3750 - 4s/epoch - 78ms/step
# Epoch 45/300
#
# Epoch 45: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3183 - accuracy: 0.8376 - val_loss: 2.8377 - val_accuracy: 0.5410 - 4s/epoch - 79ms/step
# Epoch 46/300
#
# Epoch 46: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3138 - accuracy: 0.8381 - val_loss: 12.9928 - val_accuracy: 0.3750 - 4s/epoch - 78ms/step
# Epoch 47/300
#
# Epoch 47: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3228 - accuracy: 0.8299 - val_loss: 13.2599 - val_accuracy: 0.3750 - 4s/epoch - 79ms/step
# Epoch 48/300
#
# Epoch 48: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3156 - accuracy: 0.8339 - val_loss: 10.0962 - val_accuracy: 0.3750 - 4s/epoch - 78ms/step
# Epoch 49/300
#
# Epoch 49: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3072 - accuracy: 0.8390 - val_loss: 8.4075 - val_accuracy: 0.3750 - 4s/epoch - 79ms/step
# Epoch 50/300
#
# Epoch 50: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3133 - accuracy: 0.8373 - val_loss: 12.4505 - val_accuracy: 0.3750 - 4s/epoch - 79ms/step
# Epoch 51/300
#
# Epoch 51: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3126 - accuracy: 0.8381 - val_loss: 8.0829 - val_accuracy: 0.3750 - 4s/epoch - 78ms/step
# Epoch 52/300
#
# Epoch 52: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3110 - accuracy: 0.8390 - val_loss: 2.0003 - val_accuracy: 0.5388 - 4s/epoch - 78ms/step
# Epoch 53/300
#
# Epoch 53: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3113 - accuracy: 0.8339 - val_loss: 10.0073 - val_accuracy: 0.3750 - 4s/epoch - 79ms/step
# Epoch 54/300
#
# Epoch 54: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3065 - accuracy: 0.8460 - val_loss: 3.6864 - val_accuracy: 0.5318 - 4s/epoch - 79ms/step
# Epoch 55/300
#
# Epoch 55: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3027 - accuracy: 0.8379 - val_loss: 3.5750 - val_accuracy: 0.5325 - 4s/epoch - 79ms/step
# Epoch 56/300
#
# Epoch 56: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2976 - accuracy: 0.8398 - val_loss: 7.3716 - val_accuracy: 0.6250 - 4s/epoch - 78ms/step
# Epoch 57/300
#
# Epoch 57: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2969 - accuracy: 0.8412 - val_loss: 7.6111 - val_accuracy: 0.6250 - 4s/epoch - 78ms/step
# Epoch 58/300
#
# Epoch 58: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2948 - accuracy: 0.8523 - val_loss: 6.7497 - val_accuracy: 0.6250 - 4s/epoch - 79ms/step
# Epoch 59/300
#
# Epoch 59: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3084 - accuracy: 0.8373 - val_loss: 7.9109 - val_accuracy: 0.6250 - 4s/epoch - 79ms/step
# Epoch 60/300
#
# Epoch 60: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2931 - accuracy: 0.8475 - val_loss: 3.0111 - val_accuracy: 0.4590 - 4s/epoch - 79ms/step
# Epoch 61/300
#
# Epoch 61: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2884 - accuracy: 0.8506 - val_loss: 5.0456 - val_accuracy: 0.4583 - 4s/epoch - 78ms/step
# Epoch 62/300
#
# Epoch 62: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3046 - accuracy: 0.8359 - val_loss: 3.4266 - val_accuracy: 0.5092 - 4s/epoch - 79ms/step
# Epoch 63/300
#
# Epoch 63: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2823 - accuracy: 0.8593 - val_loss: 3.8880 - val_accuracy: 0.4859 - 4s/epoch - 79ms/step
# Epoch 64/300
#
# Epoch 64: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.3029 - accuracy: 0.8449 - val_loss: 6.7580 - val_accuracy: 0.6250 - 4s/epoch - 78ms/step
# Epoch 65/300
#
# Epoch 65: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2922 - accuracy: 0.8500 - val_loss: 2.9369 - val_accuracy: 0.5106 - 4s/epoch - 78ms/step
# Epoch 66/300
#
# Epoch 66: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2930 - accuracy: 0.8427 - val_loss: 5.0384 - val_accuracy: 0.6095 - 4s/epoch - 78ms/step
# Epoch 67/300
#
# Epoch 67: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2876 - accuracy: 0.8531 - val_loss: 7.3958 - val_accuracy: 0.6250 - 4s/epoch - 78ms/step
# Epoch 68/300
#
# Epoch 68: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2914 - accuracy: 0.8514 - val_loss: 5.6818 - val_accuracy: 0.4583 - 4s/epoch - 79ms/step
# Epoch 69/300
#
# Epoch 69: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2861 - accuracy: 0.8562 - val_loss: 7.7668 - val_accuracy: 0.4583 - 4s/epoch - 78ms/step
# Epoch 70/300
#
# Epoch 70: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2892 - accuracy: 0.8556 - val_loss: 6.3542 - val_accuracy: 0.4583 - 4s/epoch - 78ms/step
# Epoch 71/300
#
# Epoch 71: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2898 - accuracy: 0.8506 - val_loss: 9.7314 - val_accuracy: 0.4583 - 4s/epoch - 78ms/step
# Epoch 72/300
#
# Epoch 72: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2876 - accuracy: 0.8460 - val_loss: 5.4401 - val_accuracy: 0.4583 - 4s/epoch - 78ms/step
# Epoch 73/300
#
# Epoch 73: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2871 - accuracy: 0.8531 - val_loss: 4.9066 - val_accuracy: 0.4583 - 4s/epoch - 78ms/step
# Epoch 74/300
#
# Epoch 74: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2902 - accuracy: 0.8472 - val_loss: 7.7964 - val_accuracy: 0.4583 - 4s/epoch - 78ms/step
# Epoch 75/300
#
# Epoch 75: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2918 - accuracy: 0.8438 - val_loss: 6.7535 - val_accuracy: 0.4583 - 4s/epoch - 78ms/step
# Epoch 76/300
#
# Epoch 76: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2872 - accuracy: 0.8525 - val_loss: 10.6307 - val_accuracy: 0.4400 - 4s/epoch - 79ms/step
# Epoch 77/300
#
# Epoch 77: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2884 - accuracy: 0.8452 - val_loss: 6.7700 - val_accuracy: 0.4583 - 4s/epoch - 79ms/step
# Epoch 78/300
#
# Epoch 78: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2714 - accuracy: 0.8669 - val_loss: 3.2267 - val_accuracy: 0.4661 - 4s/epoch - 78ms/step
# Epoch 79/300
#
# Epoch 79: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2774 - accuracy: 0.8489 - val_loss: 2.6120 - val_accuracy: 0.3927 - 4s/epoch - 78ms/step
# Epoch 80/300
#
# Epoch 80: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2845 - accuracy: 0.8477 - val_loss: 4.2340 - val_accuracy: 0.5692 - 4s/epoch - 78ms/step
# Epoch 81/300
#
# Epoch 81: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2919 - accuracy: 0.8466 - val_loss: 3.4475 - val_accuracy: 0.4407 - 4s/epoch - 78ms/step
# Epoch 82/300
#
# Epoch 82: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2704 - accuracy: 0.8534 - val_loss: 4.3798 - val_accuracy: 0.4583 - 4s/epoch - 78ms/step
# Epoch 83/300
#
# Epoch 83: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2732 - accuracy: 0.8554 - val_loss: 3.2294 - val_accuracy: 0.3891 - 4s/epoch - 78ms/step
# Epoch 84/300
#
# Epoch 84: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2825 - accuracy: 0.8452 - val_loss: 3.2672 - val_accuracy: 0.4689 - 4s/epoch - 78ms/step
# Epoch 85/300
#
# Epoch 85: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2855 - accuracy: 0.8540 - val_loss: 6.0947 - val_accuracy: 0.4569 - 4s/epoch - 78ms/step
# Epoch 86/300
#
# Epoch 86: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2904 - accuracy: 0.8435 - val_loss: 5.9258 - val_accuracy: 0.4583 - 4s/epoch - 79ms/step
# Epoch 87/300
#
# Epoch 87: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2846 - accuracy: 0.8480 - val_loss: 4.0259 - val_accuracy: 0.4583 - 4s/epoch - 79ms/step
# Epoch 88/300
#
# Epoch 88: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2784 - accuracy: 0.8542 - val_loss: 3.1455 - val_accuracy: 0.3531 - 4s/epoch - 79ms/step
# Epoch 89/300
#
# Epoch 89: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2788 - accuracy: 0.8664 - val_loss: 5.3911 - val_accuracy: 0.4576 - 4s/epoch - 79ms/step
# Epoch 90/300
#
# Epoch 90: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2658 - accuracy: 0.8633 - val_loss: 4.5807 - val_accuracy: 0.4555 - 4s/epoch - 78ms/step
# Epoch 91/300
#
# Epoch 91: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2730 - accuracy: 0.8551 - val_loss: 7.5945 - val_accuracy: 0.4583 - 4s/epoch - 79ms/step
# Epoch 92/300
#
# Epoch 92: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2658 - accuracy: 0.8675 - val_loss: 3.9260 - val_accuracy: 0.4668 - 4s/epoch - 78ms/step
# Epoch 93/300
#
# Epoch 93: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2703 - accuracy: 0.8636 - val_loss: 4.3919 - val_accuracy: 0.4654 - 4s/epoch - 79ms/step
# Epoch 94/300
#
# Epoch 94: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2689 - accuracy: 0.8573 - val_loss: 4.3653 - val_accuracy: 0.4583 - 4s/epoch - 79ms/step
# Epoch 95/300
#
# Epoch 95: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2671 - accuracy: 0.8613 - val_loss: 5.1167 - val_accuracy: 0.4597 - 4s/epoch - 79ms/step
# Epoch 96/300
#
# Epoch 96: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2650 - accuracy: 0.8675 - val_loss: 5.0579 - val_accuracy: 0.4816 - 4s/epoch - 79ms/step
# Epoch 97/300
#
# Epoch 97: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2748 - accuracy: 0.8605 - val_loss: 3.3932 - val_accuracy: 0.4802 - 4s/epoch - 79ms/step
# Epoch 98/300
#
# Epoch 98: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2642 - accuracy: 0.8638 - val_loss: 3.1377 - val_accuracy: 0.4951 - 4s/epoch - 78ms/step
# Epoch 99/300
#
# Epoch 99: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2644 - accuracy: 0.8621 - val_loss: 4.3461 - val_accuracy: 0.4583 - 4s/epoch - 78ms/step
# Epoch 100/300
#
# Epoch 100: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2685 - accuracy: 0.8621 - val_loss: 4.3606 - val_accuracy: 0.4816 - 4s/epoch - 78ms/step
# Epoch 101/300
#
# Epoch 101: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2622 - accuracy: 0.8681 - val_loss: 5.4180 - val_accuracy: 0.4499 - 4s/epoch - 78ms/step
# Epoch 102/300
#
# Epoch 102: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2596 - accuracy: 0.8669 - val_loss: 4.8324 - val_accuracy: 0.4915 - 4s/epoch - 78ms/step
# Epoch 103/300
#
# Epoch 103: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2649 - accuracy: 0.8542 - val_loss: 4.9370 - val_accuracy: 0.4682 - 4s/epoch - 78ms/step
# Epoch 104/300
#
# Epoch 104: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2602 - accuracy: 0.8720 - val_loss: 3.1963 - val_accuracy: 0.4993 - 4s/epoch - 79ms/step
# Epoch 105/300
#
# Epoch 105: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2602 - accuracy: 0.8641 - val_loss: 5.9642 - val_accuracy: 0.5417 - 4s/epoch - 78ms/step
# Epoch 106/300
#
# Epoch 106: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2531 - accuracy: 0.8749 - val_loss: 3.6378 - val_accuracy: 0.5290 - 4s/epoch - 79ms/step
# Epoch 107/300
#
# Epoch 107: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2544 - accuracy: 0.8729 - val_loss: 9.5037 - val_accuracy: 0.4583 - 4s/epoch - 79ms/step
# Epoch 108/300
#
# Epoch 108: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2451 - accuracy: 0.8797 - val_loss: 9.9263 - val_accuracy: 0.4583 - 4s/epoch - 78ms/step
# Epoch 109/300
#
# Epoch 109: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2589 - accuracy: 0.8698 - val_loss: 7.9851 - val_accuracy: 0.4583 - 4s/epoch - 79ms/step
# Epoch 110/300
#
# Epoch 110: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2591 - accuracy: 0.8638 - val_loss: 5.2288 - val_accuracy: 0.4633 - 4s/epoch - 78ms/step
# Epoch 111/300
#
# Epoch 111: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2525 - accuracy: 0.8712 - val_loss: 4.0200 - val_accuracy: 0.3305 - 4s/epoch - 78ms/step
# Epoch 112/300
#
# Epoch 112: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2528 - accuracy: 0.8763 - val_loss: 6.1113 - val_accuracy: 0.4597 - 4s/epoch - 78ms/step
# Epoch 113/300
#
# Epoch 113: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2568 - accuracy: 0.8692 - val_loss: 3.7160 - val_accuracy: 0.4499 - 4s/epoch - 80ms/step
# Epoch 114/300
#
# Epoch 114: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2571 - accuracy: 0.8686 - val_loss: 2.5194 - val_accuracy: 0.4887 - 4s/epoch - 79ms/step
# Epoch 115/300
#
# Epoch 115: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2534 - accuracy: 0.8811 - val_loss: 8.0680 - val_accuracy: 0.4597 - 4s/epoch - 78ms/step
# Epoch 116/300
#
# Epoch 116: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2556 - accuracy: 0.8695 - val_loss: 3.3135 - val_accuracy: 0.4025 - 4s/epoch - 79ms/step
# Epoch 117/300
#
# Epoch 117: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2438 - accuracy: 0.8780 - val_loss: 3.3827 - val_accuracy: 0.4958 - 4s/epoch - 79ms/step
# Epoch 118/300
#
# Epoch 118: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2730 - accuracy: 0.8605 - val_loss: 3.4070 - val_accuracy: 0.5431 - 4s/epoch - 78ms/step
# Epoch 119/300
#
# Epoch 119: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2570 - accuracy: 0.8715 - val_loss: 10.0062 - val_accuracy: 0.4583 - 4s/epoch - 78ms/step
# Epoch 120/300
#
# Epoch 120: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2565 - accuracy: 0.8732 - val_loss: 6.3348 - val_accuracy: 0.4654 - 4s/epoch - 79ms/step
# Epoch 121/300
#
# Epoch 121: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2500 - accuracy: 0.8763 - val_loss: 4.3705 - val_accuracy: 0.4958 - 4s/epoch - 78ms/step
# Epoch 122/300
#
# Epoch 122: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2504 - accuracy: 0.8763 - val_loss: 5.3079 - val_accuracy: 0.4760 - 4s/epoch - 78ms/step
# Epoch 123/300
#
# Epoch 123: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2393 - accuracy: 0.8828 - val_loss: 3.2539 - val_accuracy: 0.4951 - 4s/epoch - 78ms/step
# Epoch 124/300
#
# Epoch 124: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2426 - accuracy: 0.8805 - val_loss: 5.9949 - val_accuracy: 0.4725 - 4s/epoch - 78ms/step
# Epoch 125/300
#
# Epoch 125: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2449 - accuracy: 0.8751 - val_loss: 9.4085 - val_accuracy: 0.4569 - 4s/epoch - 78ms/step
# Epoch 126/300
#
# Epoch 126: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2450 - accuracy: 0.8811 - val_loss: 5.5076 - val_accuracy: 0.4929 - 4s/epoch - 79ms/step
# Epoch 127/300
#
# Epoch 127: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2457 - accuracy: 0.8808 - val_loss: 7.0232 - val_accuracy: 0.4583 - 4s/epoch - 78ms/step
# Epoch 128/300
#
# Epoch 128: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2495 - accuracy: 0.8734 - val_loss: 9.5224 - val_accuracy: 0.4583 - 4s/epoch - 79ms/step
# Epoch 129/300
#
# Epoch 129: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2406 - accuracy: 0.8876 - val_loss: 6.6664 - val_accuracy: 0.4795 - 4s/epoch - 79ms/step
# Epoch 130/300
#
# Epoch 130: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2671 - accuracy: 0.8720 - val_loss: 7.7851 - val_accuracy: 0.4576 - 4s/epoch - 79ms/step
# Epoch 131/300
#
# Epoch 131: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2370 - accuracy: 0.8850 - val_loss: 3.4543 - val_accuracy: 0.4364 - 4s/epoch - 79ms/step
# Epoch 132/300
#
# Epoch 132: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2240 - accuracy: 0.8859 - val_loss: 4.5095 - val_accuracy: 0.4682 - 4s/epoch - 79ms/step
# Epoch 133/300
#
# Epoch 133: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2499 - accuracy: 0.8794 - val_loss: 4.4050 - val_accuracy: 0.5155 - 4s/epoch - 79ms/step
# Epoch 134/300
#
# Epoch 134: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2401 - accuracy: 0.8867 - val_loss: 5.5264 - val_accuracy: 0.4470 - 4s/epoch - 79ms/step
# Epoch 135/300
#
# Epoch 135: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2296 - accuracy: 0.8895 - val_loss: 6.0827 - val_accuracy: 0.4555 - 4s/epoch - 79ms/step
# Epoch 136/300
#
# Epoch 136: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2265 - accuracy: 0.8907 - val_loss: 11.3249 - val_accuracy: 0.4583 - 4s/epoch - 79ms/step
# Epoch 137/300
#
# Epoch 137: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2345 - accuracy: 0.8853 - val_loss: 5.7832 - val_accuracy: 0.4915 - 4s/epoch - 79ms/step
# Epoch 138/300
#
# Epoch 138: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2312 - accuracy: 0.8938 - val_loss: 9.3443 - val_accuracy: 0.4583 - 4s/epoch - 79ms/step
# Epoch 139/300
#
# Epoch 139: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2230 - accuracy: 0.8932 - val_loss: 8.5329 - val_accuracy: 0.4583 - 4s/epoch - 79ms/step
# Epoch 140/300
#
# Epoch 140: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2333 - accuracy: 0.8944 - val_loss: 4.3641 - val_accuracy: 0.5311 - 4s/epoch - 78ms/step
# Epoch 141/300
#
# Epoch 141: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2284 - accuracy: 0.8963 - val_loss: 5.2157 - val_accuracy: 0.4689 - 4s/epoch - 78ms/step
# Epoch 142/300
#
# Epoch 142: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2178 - accuracy: 0.8935 - val_loss: 4.1493 - val_accuracy: 0.5028 - 4s/epoch - 79ms/step
# Epoch 143/300
#
# Epoch 143: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2215 - accuracy: 0.8893 - val_loss: 8.4653 - val_accuracy: 0.5417 - 4s/epoch - 79ms/step
# Epoch 144/300
#
# Epoch 144: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2300 - accuracy: 0.8901 - val_loss: 10.1269 - val_accuracy: 0.5692 - 4s/epoch - 78ms/step
# Epoch 145/300
#
# Epoch 145: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2156 - accuracy: 0.9011 - val_loss: 5.8893 - val_accuracy: 0.4718 - 4s/epoch - 79ms/step
# Epoch 146/300
#
# Epoch 146: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2282 - accuracy: 0.8876 - val_loss: 6.0132 - val_accuracy: 0.4873 - 4s/epoch - 79ms/step
# Epoch 147/300
#
# Epoch 147: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2316 - accuracy: 0.8870 - val_loss: 4.6692 - val_accuracy: 0.4802 - 4s/epoch - 79ms/step
# Epoch 148/300
#
# Epoch 148: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2209 - accuracy: 0.8975 - val_loss: 3.5389 - val_accuracy: 0.4944 - 4s/epoch - 79ms/step
# Epoch 149/300
#
# Epoch 149: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2288 - accuracy: 0.8884 - val_loss: 4.7292 - val_accuracy: 0.5064 - 4s/epoch - 79ms/step
# Epoch 150/300
#
# Epoch 150: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2172 - accuracy: 0.8963 - val_loss: 5.1185 - val_accuracy: 0.5678 - 4s/epoch - 79ms/step
# Epoch 151/300
#
# Epoch 151: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2098 - accuracy: 0.8997 - val_loss: 5.7586 - val_accuracy: 0.4901 - 4s/epoch - 78ms/step
# Epoch 152/300
#
# Epoch 152: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2231 - accuracy: 0.8927 - val_loss: 5.0767 - val_accuracy: 0.5191 - 4s/epoch - 80ms/step
# Epoch 153/300
#
# Epoch 153: val_loss did not improve from 0.66236
# 56/56 - 13s - loss: 0.2288 - accuracy: 0.8907 - val_loss: 8.1955 - val_accuracy: 0.4605 - 13s/epoch - 232ms/step
# Epoch 154/300
#
# Epoch 154: val_loss did not improve from 0.66236
# 56/56 - 5s - loss: 0.2330 - accuracy: 0.8884 - val_loss: 4.8746 - val_accuracy: 0.5650 - 5s/epoch - 97ms/step
# Epoch 155/300
#
# Epoch 155: val_loss did not improve from 0.66236
# 56/56 - 5s - loss: 0.2153 - accuracy: 0.9006 - val_loss: 4.2343 - val_accuracy: 0.5621 - 5s/epoch - 90ms/step
# Epoch 156/300
#
# Epoch 156: val_loss did not improve from 0.66236
# 56/56 - 5s - loss: 0.2204 - accuracy: 0.8935 - val_loss: 5.9044 - val_accuracy: 0.4590 - 5s/epoch - 81ms/step
# Epoch 157/300
#
# Epoch 157: val_loss did not improve from 0.66236
# 56/56 - 5s - loss: 0.2326 - accuracy: 0.8893 - val_loss: 4.8808 - val_accuracy: 0.5360 - 5s/epoch - 83ms/step
# Epoch 158/300
#
# Epoch 158: val_loss did not improve from 0.66236
# 56/56 - 5s - loss: 0.2258 - accuracy: 0.8881 - val_loss: 8.5240 - val_accuracy: 0.4661 - 5s/epoch - 85ms/step
# Epoch 159/300
#
# Epoch 159: val_loss did not improve from 0.66236
# 56/56 - 5s - loss: 0.2192 - accuracy: 0.8997 - val_loss: 6.6824 - val_accuracy: 0.4908 - 5s/epoch - 81ms/step
# Epoch 160/300
#
# Epoch 160: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2196 - accuracy: 0.8955 - val_loss: 8.1857 - val_accuracy: 0.4583 - 4s/epoch - 80ms/step
# Epoch 161/300
#
# Epoch 161: val_loss did not improve from 0.66236
# 56/56 - 5s - loss: 0.2046 - accuracy: 0.9079 - val_loss: 4.4502 - val_accuracy: 0.5141 - 5s/epoch - 81ms/step
# Epoch 162/300
#
# Epoch 162: val_loss did not improve from 0.66236
# 56/56 - 5s - loss: 0.2350 - accuracy: 0.8912 - val_loss: 4.3269 - val_accuracy: 0.5537 - 5s/epoch - 81ms/step
# Epoch 163/300
#
# Epoch 163: val_loss did not improve from 0.66236
# 56/56 - 5s - loss: 0.2189 - accuracy: 0.9014 - val_loss: 5.8742 - val_accuracy: 0.4795 - 5s/epoch - 81ms/step
# Epoch 164/300
#
# Epoch 164: val_loss did not improve from 0.66236
# 56/56 - 5s - loss: 0.2097 - accuracy: 0.9045 - val_loss: 5.9259 - val_accuracy: 0.5056 - 5s/epoch - 82ms/step
# Epoch 165/300
#
# Epoch 165: val_loss did not improve from 0.66236
# 56/56 - 5s - loss: 0.1994 - accuracy: 0.9082 - val_loss: 6.0624 - val_accuracy: 0.5487 - 5s/epoch - 81ms/step
# Epoch 166/300
#
# Epoch 166: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2178 - accuracy: 0.8977 - val_loss: 5.6088 - val_accuracy: 0.5551 - 4s/epoch - 80ms/step
# Epoch 167/300
#
# Epoch 167: val_loss did not improve from 0.66236
# 56/56 - 5s - loss: 0.2287 - accuracy: 0.8881 - val_loss: 6.9879 - val_accuracy: 0.4958 - 5s/epoch - 80ms/step
# Epoch 168/300
#
# Epoch 168: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2156 - accuracy: 0.8977 - val_loss: 5.5979 - val_accuracy: 0.5219 - 4s/epoch - 80ms/step
# Epoch 169/300
#
# Epoch 169: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2148 - accuracy: 0.8972 - val_loss: 5.1718 - val_accuracy: 0.5445 - 4s/epoch - 80ms/step
# Epoch 170/300
#
# Epoch 170: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2172 - accuracy: 0.8949 - val_loss: 8.0140 - val_accuracy: 0.4605 - 4s/epoch - 79ms/step
# Epoch 171/300
#
# Epoch 171: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2022 - accuracy: 0.9124 - val_loss: 7.2302 - val_accuracy: 0.4951 - 4s/epoch - 80ms/step
# Epoch 172/300
#
# Epoch 172: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2057 - accuracy: 0.9054 - val_loss: 5.8638 - val_accuracy: 0.5388 - 4s/epoch - 79ms/step
# Epoch 173/300
#
# Epoch 173: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2064 - accuracy: 0.9059 - val_loss: 5.1057 - val_accuracy: 0.5600 - 4s/epoch - 79ms/step
# Epoch 174/300
#
# Epoch 174: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2086 - accuracy: 0.9017 - val_loss: 4.5542 - val_accuracy: 0.4103 - 4s/epoch - 79ms/step
# Epoch 175/300
#
# Epoch 175: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2125 - accuracy: 0.9031 - val_loss: 7.4037 - val_accuracy: 0.4915 - 4s/epoch - 79ms/step
# Epoch 176/300
#
# Epoch 176: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2083 - accuracy: 0.9037 - val_loss: 7.4111 - val_accuracy: 0.4929 - 4s/epoch - 78ms/step
# Epoch 177/300
#
# Epoch 177: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1969 - accuracy: 0.9121 - val_loss: 5.5142 - val_accuracy: 0.5466 - 4s/epoch - 78ms/step
# Epoch 178/300
#
# Epoch 178: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2034 - accuracy: 0.9169 - val_loss: 6.6463 - val_accuracy: 0.4831 - 4s/epoch - 79ms/step
# Epoch 179/300
#
# Epoch 179: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2018 - accuracy: 0.9099 - val_loss: 8.4376 - val_accuracy: 0.4823 - 4s/epoch - 78ms/step
# Epoch 180/300
#
# Epoch 180: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2000 - accuracy: 0.9071 - val_loss: 5.4917 - val_accuracy: 0.5078 - 4s/epoch - 78ms/step
# Epoch 181/300
#
# Epoch 181: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2207 - accuracy: 0.9011 - val_loss: 5.3751 - val_accuracy: 0.4845 - 4s/epoch - 78ms/step
# Epoch 182/300
#
# Epoch 182: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2030 - accuracy: 0.9113 - val_loss: 9.8608 - val_accuracy: 0.4993 - 4s/epoch - 78ms/step
# Epoch 183/300
#
# Epoch 183: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1952 - accuracy: 0.9107 - val_loss: 6.2789 - val_accuracy: 0.4774 - 4s/epoch - 78ms/step
# Epoch 184/300
#
# Epoch 184: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2106 - accuracy: 0.9062 - val_loss: 7.3310 - val_accuracy: 0.4859 - 4s/epoch - 79ms/step
# Epoch 185/300
#
# Epoch 185: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1995 - accuracy: 0.9105 - val_loss: 10.4384 - val_accuracy: 0.4859 - 4s/epoch - 78ms/step
# Epoch 186/300
#
# Epoch 186: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2014 - accuracy: 0.9062 - val_loss: 11.5296 - val_accuracy: 0.4590 - 4s/epoch - 78ms/step
# Epoch 187/300
#
# Epoch 187: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1951 - accuracy: 0.9127 - val_loss: 5.3172 - val_accuracy: 0.4788 - 4s/epoch - 78ms/step
# Epoch 188/300
#
# Epoch 188: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1982 - accuracy: 0.9082 - val_loss: 9.8350 - val_accuracy: 0.4845 - 4s/epoch - 78ms/step
# Epoch 189/300
#
# Epoch 189: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2278 - accuracy: 0.8912 - val_loss: 13.7758 - val_accuracy: 0.4583 - 4s/epoch - 78ms/step
# Epoch 190/300
#
# Epoch 190: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2018 - accuracy: 0.9102 - val_loss: 8.8713 - val_accuracy: 0.4979 - 4s/epoch - 78ms/step
# Epoch 191/300
#
# Epoch 191: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1944 - accuracy: 0.9102 - val_loss: 3.5077 - val_accuracy: 0.5734 - 4s/epoch - 78ms/step
# Epoch 192/300
#
# Epoch 192: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1808 - accuracy: 0.9201 - val_loss: 4.7241 - val_accuracy: 0.5339 - 4s/epoch - 78ms/step
# Epoch 193/300
#
# Epoch 193: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2020 - accuracy: 0.9130 - val_loss: 4.4417 - val_accuracy: 0.4986 - 4s/epoch - 78ms/step
# Epoch 194/300
#
# Epoch 194: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1820 - accuracy: 0.9206 - val_loss: 6.6819 - val_accuracy: 0.4915 - 4s/epoch - 78ms/step
# Epoch 195/300
#
# Epoch 195: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1937 - accuracy: 0.9138 - val_loss: 5.9017 - val_accuracy: 0.4774 - 4s/epoch - 78ms/step
# Epoch 196/300
#
# Epoch 196: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1826 - accuracy: 0.9175 - val_loss: 4.0828 - val_accuracy: 0.5699 - 4s/epoch - 78ms/step
# Epoch 197/300
#
# Epoch 197: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1851 - accuracy: 0.9175 - val_loss: 7.4050 - val_accuracy: 0.4915 - 4s/epoch - 78ms/step
# Epoch 198/300
#
# Epoch 198: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1847 - accuracy: 0.9212 - val_loss: 4.3411 - val_accuracy: 0.4958 - 4s/epoch - 78ms/step
# Epoch 199/300
#
# Epoch 199: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1744 - accuracy: 0.9271 - val_loss: 9.4455 - val_accuracy: 0.4583 - 4s/epoch - 78ms/step
# Epoch 200/300
#
# Epoch 200: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2009 - accuracy: 0.9073 - val_loss: 8.8482 - val_accuracy: 0.4795 - 4s/epoch - 78ms/step
# Epoch 201/300
#
# Epoch 201: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1952 - accuracy: 0.9124 - val_loss: 6.7631 - val_accuracy: 0.5452 - 4s/epoch - 78ms/step
# Epoch 202/300
#
# Epoch 202: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1766 - accuracy: 0.9274 - val_loss: 7.2408 - val_accuracy: 0.4774 - 4s/epoch - 78ms/step
# Epoch 203/300
#
# Epoch 203: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1901 - accuracy: 0.9138 - val_loss: 7.3984 - val_accuracy: 0.4661 - 4s/epoch - 78ms/step
# Epoch 204/300
#
# Epoch 204: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1785 - accuracy: 0.9220 - val_loss: 5.9104 - val_accuracy: 0.4922 - 4s/epoch - 78ms/step
# Epoch 205/300
#
# Epoch 205: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1837 - accuracy: 0.9206 - val_loss: 5.9858 - val_accuracy: 0.4859 - 4s/epoch - 78ms/step
# Epoch 206/300
#
# Epoch 206: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2119 - accuracy: 0.9028 - val_loss: 4.7466 - val_accuracy: 0.5685 - 4s/epoch - 78ms/step
# Epoch 207/300
#
# Epoch 207: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1795 - accuracy: 0.9277 - val_loss: 6.2313 - val_accuracy: 0.5233 - 4s/epoch - 78ms/step
# Epoch 208/300
#
# Epoch 208: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.2033 - accuracy: 0.9082 - val_loss: 8.0533 - val_accuracy: 0.4583 - 4s/epoch - 78ms/step
# Epoch 209/300
#
# Epoch 209: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1887 - accuracy: 0.9203 - val_loss: 9.5964 - val_accuracy: 0.4760 - 4s/epoch - 78ms/step
# Epoch 210/300
#
# Epoch 210: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1777 - accuracy: 0.9206 - val_loss: 5.3046 - val_accuracy: 0.5311 - 4s/epoch - 78ms/step
# Epoch 211/300
#
# Epoch 211: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1746 - accuracy: 0.9263 - val_loss: 9.4178 - val_accuracy: 0.4915 - 4s/epoch - 79ms/step
# Epoch 212/300
#
# Epoch 212: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1888 - accuracy: 0.9093 - val_loss: 7.5231 - val_accuracy: 0.4569 - 4s/epoch - 78ms/step
# Epoch 213/300
#
# Epoch 213: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1910 - accuracy: 0.9181 - val_loss: 5.0360 - val_accuracy: 0.5742 - 4s/epoch - 78ms/step
# Epoch 214/300
#
# Epoch 214: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1873 - accuracy: 0.9229 - val_loss: 6.6632 - val_accuracy: 0.5184 - 4s/epoch - 78ms/step
# Epoch 215/300
#
# Epoch 215: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1827 - accuracy: 0.9192 - val_loss: 6.4603 - val_accuracy: 0.5445 - 4s/epoch - 80ms/step
# Epoch 216/300
#
# Epoch 216: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1833 - accuracy: 0.9169 - val_loss: 5.6422 - val_accuracy: 0.5720 - 4s/epoch - 78ms/step
# Epoch 217/300
#
# Epoch 217: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1842 - accuracy: 0.9218 - val_loss: 4.6268 - val_accuracy: 0.5968 - 4s/epoch - 78ms/step
# Epoch 218/300
#
# Epoch 218: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1827 - accuracy: 0.9237 - val_loss: 4.8583 - val_accuracy: 0.5975 - 4s/epoch - 78ms/step
# Epoch 219/300
#
# Epoch 219: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1650 - accuracy: 0.9299 - val_loss: 7.0817 - val_accuracy: 0.4831 - 4s/epoch - 78ms/step
# Epoch 220/300
#
# Epoch 220: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1836 - accuracy: 0.9161 - val_loss: 5.8012 - val_accuracy: 0.4696 - 4s/epoch - 78ms/step
# Epoch 221/300
#
# Epoch 221: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1669 - accuracy: 0.9311 - val_loss: 7.4723 - val_accuracy: 0.5092 - 4s/epoch - 78ms/step
# Epoch 222/300
#
# Epoch 222: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1789 - accuracy: 0.9260 - val_loss: 6.4354 - val_accuracy: 0.5812 - 4s/epoch - 78ms/step
# Epoch 223/300
#
# Epoch 223: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1787 - accuracy: 0.9226 - val_loss: 5.7180 - val_accuracy: 0.4979 - 4s/epoch - 79ms/step
# Epoch 224/300
#
# Epoch 224: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1779 - accuracy: 0.9271 - val_loss: 5.2198 - val_accuracy: 0.4873 - 4s/epoch - 78ms/step
# Epoch 225/300
#
# Epoch 225: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1757 - accuracy: 0.9234 - val_loss: 5.3452 - val_accuracy: 0.6073 - 4s/epoch - 78ms/step
# Epoch 226/300
#
# Epoch 226: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1669 - accuracy: 0.9277 - val_loss: 10.8965 - val_accuracy: 0.4866 - 4s/epoch - 78ms/step
# Epoch 227/300
#
# Epoch 227: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1818 - accuracy: 0.9232 - val_loss: 5.8105 - val_accuracy: 0.5007 - 4s/epoch - 78ms/step
# Epoch 228/300
#
# Epoch 228: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1669 - accuracy: 0.9342 - val_loss: 7.7425 - val_accuracy: 0.5106 - 4s/epoch - 78ms/step
# Epoch 229/300
#
# Epoch 229: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1506 - accuracy: 0.9395 - val_loss: 7.2663 - val_accuracy: 0.5056 - 4s/epoch - 78ms/step
# Epoch 230/300
#
# Epoch 230: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1828 - accuracy: 0.9220 - val_loss: 8.1824 - val_accuracy: 0.4915 - 4s/epoch - 78ms/step
# Epoch 231/300
#
# Epoch 231: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1705 - accuracy: 0.9316 - val_loss: 9.2319 - val_accuracy: 0.5049 - 4s/epoch - 78ms/step
# Epoch 232/300
#
# Epoch 232: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1741 - accuracy: 0.9274 - val_loss: 6.5929 - val_accuracy: 0.5007 - 4s/epoch - 78ms/step
# Epoch 233/300
#
# Epoch 233: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1726 - accuracy: 0.9302 - val_loss: 9.4260 - val_accuracy: 0.4965 - 4s/epoch - 78ms/step
# Epoch 234/300
#
# Epoch 234: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1719 - accuracy: 0.9314 - val_loss: 5.0923 - val_accuracy: 0.4442 - 4s/epoch - 78ms/step
# Epoch 235/300
#
# Epoch 235: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1760 - accuracy: 0.9237 - val_loss: 4.9467 - val_accuracy: 0.4364 - 4s/epoch - 78ms/step
# Epoch 236/300
#
# Epoch 236: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1726 - accuracy: 0.9260 - val_loss: 6.3846 - val_accuracy: 0.5395 - 4s/epoch - 78ms/step
# Epoch 237/300
#
# Epoch 237: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1575 - accuracy: 0.9384 - val_loss: 5.7587 - val_accuracy: 0.5501 - 4s/epoch - 79ms/step
# Epoch 238/300
#
# Epoch 238: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1660 - accuracy: 0.9364 - val_loss: 4.9944 - val_accuracy: 0.5982 - 4s/epoch - 78ms/step
# Epoch 239/300
#
# Epoch 239: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1933 - accuracy: 0.9189 - val_loss: 5.5306 - val_accuracy: 0.5395 - 4s/epoch - 78ms/step
# Epoch 240/300
#
# Epoch 240: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1620 - accuracy: 0.9316 - val_loss: 5.8919 - val_accuracy: 0.5162 - 4s/epoch - 78ms/step
# Epoch 241/300
#
# Epoch 241: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1705 - accuracy: 0.9263 - val_loss: 5.1902 - val_accuracy: 0.5127 - 4s/epoch - 78ms/step
# Epoch 242/300
#
# Epoch 242: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1639 - accuracy: 0.9370 - val_loss: 7.7587 - val_accuracy: 0.5028 - 4s/epoch - 78ms/step
# Epoch 243/300
#
# Epoch 243: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1685 - accuracy: 0.9316 - val_loss: 7.6721 - val_accuracy: 0.4788 - 4s/epoch - 78ms/step
# Epoch 244/300
#
# Epoch 244: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1678 - accuracy: 0.9345 - val_loss: 8.4621 - val_accuracy: 0.4612 - 4s/epoch - 79ms/step
# Epoch 245/300
#
# Epoch 245: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1606 - accuracy: 0.9376 - val_loss: 7.4744 - val_accuracy: 0.4583 - 4s/epoch - 78ms/step
# Epoch 246/300
#
# Epoch 246: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1657 - accuracy: 0.9316 - val_loss: 5.0936 - val_accuracy: 0.5551 - 4s/epoch - 78ms/step
# Epoch 247/300
#
# Epoch 247: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1606 - accuracy: 0.9367 - val_loss: 5.4066 - val_accuracy: 0.6045 - 4s/epoch - 78ms/step
# Epoch 248/300
#
# Epoch 248: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1562 - accuracy: 0.9339 - val_loss: 5.8352 - val_accuracy: 0.5791 - 4s/epoch - 78ms/step
# Epoch 249/300
#
# Epoch 249: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1674 - accuracy: 0.9299 - val_loss: 5.1204 - val_accuracy: 0.4831 - 4s/epoch - 78ms/step
# Epoch 250/300
#
# Epoch 250: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1636 - accuracy: 0.9308 - val_loss: 5.2606 - val_accuracy: 0.6024 - 4s/epoch - 78ms/step
# Epoch 251/300
#
# Epoch 251: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1644 - accuracy: 0.9328 - val_loss: 4.8604 - val_accuracy: 0.4661 - 4s/epoch - 78ms/step
# Epoch 252/300
#
# Epoch 252: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1710 - accuracy: 0.9319 - val_loss: 4.4531 - val_accuracy: 0.6081 - 4s/epoch - 78ms/step
# Epoch 253/300
#
# Epoch 253: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1494 - accuracy: 0.9407 - val_loss: 6.5806 - val_accuracy: 0.4986 - 4s/epoch - 79ms/step
# Epoch 254/300
#
# Epoch 254: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1494 - accuracy: 0.9370 - val_loss: 5.1529 - val_accuracy: 0.6066 - 4s/epoch - 78ms/step
# Epoch 255/300
#
# Epoch 255: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1498 - accuracy: 0.9407 - val_loss: 9.2873 - val_accuracy: 0.5071 - 4s/epoch - 78ms/step
# Epoch 256/300
#
# Epoch 256: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1514 - accuracy: 0.9410 - val_loss: 3.9420 - val_accuracy: 0.6066 - 4s/epoch - 79ms/step
# Epoch 257/300
#
# Epoch 257: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1533 - accuracy: 0.9401 - val_loss: 7.0728 - val_accuracy: 0.4979 - 4s/epoch - 79ms/step
# Epoch 258/300
#
# Epoch 258: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1628 - accuracy: 0.9345 - val_loss: 7.3039 - val_accuracy: 0.5078 - 4s/epoch - 78ms/step
# Epoch 259/300
#
# Epoch 259: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1678 - accuracy: 0.9302 - val_loss: 6.0102 - val_accuracy: 0.5862 - 4s/epoch - 78ms/step
# Epoch 260/300
#
# Epoch 260: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1629 - accuracy: 0.9362 - val_loss: 5.4843 - val_accuracy: 0.5968 - 4s/epoch - 78ms/step
# Epoch 261/300
#
# Epoch 261: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1622 - accuracy: 0.9345 - val_loss: 6.7400 - val_accuracy: 0.5021 - 4s/epoch - 79ms/step
# Epoch 262/300
#
# Epoch 262: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1522 - accuracy: 0.9379 - val_loss: 5.2496 - val_accuracy: 0.5862 - 4s/epoch - 78ms/step
# Epoch 263/300
#
# Epoch 263: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1553 - accuracy: 0.9410 - val_loss: 7.0447 - val_accuracy: 0.5233 - 4s/epoch - 78ms/step
# Epoch 264/300
#
# Epoch 264: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1495 - accuracy: 0.9393 - val_loss: 6.5220 - val_accuracy: 0.5056 - 4s/epoch - 78ms/step
# Epoch 265/300
#
# Epoch 265: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1550 - accuracy: 0.9367 - val_loss: 7.2827 - val_accuracy: 0.5000 - 4s/epoch - 78ms/step
# Epoch 266/300
#
# Epoch 266: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1446 - accuracy: 0.9424 - val_loss: 8.0084 - val_accuracy: 0.5014 - 4s/epoch - 78ms/step
# Epoch 267/300
#
# Epoch 267: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1637 - accuracy: 0.9347 - val_loss: 5.7213 - val_accuracy: 0.5106 - 4s/epoch - 79ms/step
# Epoch 268/300
#
# Epoch 268: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1471 - accuracy: 0.9407 - val_loss: 5.1935 - val_accuracy: 0.5855 - 4s/epoch - 78ms/step
# Epoch 269/300
#
# Epoch 269: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1400 - accuracy: 0.9475 - val_loss: 5.8847 - val_accuracy: 0.5713 - 4s/epoch - 78ms/step
# Epoch 270/300
#
# Epoch 270: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1489 - accuracy: 0.9435 - val_loss: 7.7063 - val_accuracy: 0.5466 - 4s/epoch - 78ms/step
# Epoch 271/300
#
# Epoch 271: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1633 - accuracy: 0.9322 - val_loss: 7.2100 - val_accuracy: 0.5706 - 4s/epoch - 78ms/step
# Epoch 272/300
#
# Epoch 272: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1472 - accuracy: 0.9412 - val_loss: 5.1194 - val_accuracy: 0.6045 - 4s/epoch - 79ms/step
# Epoch 273/300
#
# Epoch 273: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1785 - accuracy: 0.9249 - val_loss: 7.2001 - val_accuracy: 0.5014 - 4s/epoch - 78ms/step
# Epoch 274/300
#
# Epoch 274: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1556 - accuracy: 0.9350 - val_loss: 5.0726 - val_accuracy: 0.4965 - 4s/epoch - 78ms/step
# Epoch 275/300
#
# Epoch 275: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1556 - accuracy: 0.9438 - val_loss: 5.4482 - val_accuracy: 0.4619 - 4s/epoch - 79ms/step
# Epoch 276/300
#
# Epoch 276: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1418 - accuracy: 0.9466 - val_loss: 8.1424 - val_accuracy: 0.5028 - 4s/epoch - 78ms/step
# Epoch 277/300
#
# Epoch 277: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1503 - accuracy: 0.9404 - val_loss: 7.3048 - val_accuracy: 0.5000 - 4s/epoch - 78ms/step
# Epoch 278/300
#
# Epoch 278: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1568 - accuracy: 0.9376 - val_loss: 9.1875 - val_accuracy: 0.5064 - 4s/epoch - 79ms/step
# Epoch 279/300
#
# Epoch 279: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1499 - accuracy: 0.9350 - val_loss: 7.2876 - val_accuracy: 0.5000 - 4s/epoch - 79ms/step
# Epoch 280/300
#
# Epoch 280: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1544 - accuracy: 0.9407 - val_loss: 6.2743 - val_accuracy: 0.4816 - 4s/epoch - 79ms/step
# Epoch 281/300
#
# Epoch 281: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1392 - accuracy: 0.9446 - val_loss: 7.3510 - val_accuracy: 0.5021 - 4s/epoch - 78ms/step
# Epoch 282/300
#
# Epoch 282: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1466 - accuracy: 0.9398 - val_loss: 9.0441 - val_accuracy: 0.4944 - 4s/epoch - 78ms/step
# Epoch 283/300
#
# Epoch 283: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1488 - accuracy: 0.9398 - val_loss: 5.2789 - val_accuracy: 0.5685 - 4s/epoch - 78ms/step
# Epoch 284/300
#
# Epoch 284: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1477 - accuracy: 0.9395 - val_loss: 5.1546 - val_accuracy: 0.5946 - 4s/epoch - 78ms/step
# Epoch 285/300
#
# Epoch 285: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1656 - accuracy: 0.9347 - val_loss: 7.7713 - val_accuracy: 0.5000 - 4s/epoch - 78ms/step
# Epoch 286/300
#
# Epoch 286: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1463 - accuracy: 0.9435 - val_loss: 6.1088 - val_accuracy: 0.5523 - 4s/epoch - 78ms/step
# Epoch 287/300
#
# Epoch 287: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1540 - accuracy: 0.9350 - val_loss: 7.9179 - val_accuracy: 0.5000 - 4s/epoch - 79ms/step
# Epoch 288/300
#
# Epoch 288: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1452 - accuracy: 0.9432 - val_loss: 5.3948 - val_accuracy: 0.5516 - 4s/epoch - 78ms/step
# Epoch 289/300
#
# Epoch 289: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1758 - accuracy: 0.9260 - val_loss: 5.5329 - val_accuracy: 0.6102 - 4s/epoch - 78ms/step
# Epoch 290/300
#
# Epoch 290: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1584 - accuracy: 0.9356 - val_loss: 5.6527 - val_accuracy: 0.5530 - 4s/epoch - 79ms/step
# Epoch 291/300
#
# Epoch 291: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1535 - accuracy: 0.9395 - val_loss: 5.8729 - val_accuracy: 0.5678 - 4s/epoch - 78ms/step
# Epoch 292/300
#
# Epoch 292: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1581 - accuracy: 0.9390 - val_loss: 6.3220 - val_accuracy: 0.5014 - 4s/epoch - 79ms/step
# Epoch 293/300
#
# Epoch 293: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1454 - accuracy: 0.9415 - val_loss: 6.6746 - val_accuracy: 0.5565 - 4s/epoch - 78ms/step
# Epoch 294/300
#
# Epoch 294: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1452 - accuracy: 0.9429 - val_loss: 6.1477 - val_accuracy: 0.5805 - 4s/epoch - 78ms/step
# Epoch 295/300
#
# Epoch 295: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1491 - accuracy: 0.9401 - val_loss: 5.9445 - val_accuracy: 0.4739 - 4s/epoch - 78ms/step
# Epoch 296/300
#
# Epoch 296: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1432 - accuracy: 0.9404 - val_loss: 7.3633 - val_accuracy: 0.4887 - 4s/epoch - 80ms/step
# Epoch 297/300
#
# Epoch 297: val_loss did not improve from 0.66236
# 56/56 - 4s - loss: 0.1359 - accuracy: 0.9460 - val_loss: 6.8519 - val_accuracy: 0.4753 - 4s/epoch - 75ms/step
# Epoch 298/300
#
# Epoch 298: val_loss did not improve from 0.66236
# 56/56 - 16s - loss: 0.1497 - accuracy: 0.9367 - val_loss: 7.2436 - val_accuracy: 0.5000 - 16s/epoch - 290ms/step
# Epoch 299/300
#
# Epoch 299: val_loss did not improve from 0.66236
# 56/56 - 5s - loss: 0.1469 - accuracy: 0.9432 - val_loss: 5.7065 - val_accuracy: 0.6088 - 5s/epoch - 96ms/step
# Epoch 300/300
#
# Epoch 300: val_loss did not improve from 0.66236
# 56/56 - 5s - loss: 0.1392 - accuracy: 0.9466 - val_loss: 6.5397 - val_accuracy: 0.5282 - 5s/epoch - 86ms/step
# 45/45 [==============================] - 0s 8ms/step
# Classification accuracy: 0.541667
# /Users/idaandreassen/opt/anaconda3/envs/mne/lib/python3.9/site-packages/pyriemann/utils/viz.py:24: RuntimeWarning: invalid value encountered in true_divide
#   cm = 100 * cm.astype("float") / cm.sum(axis=1)[:, np.newaxis]
