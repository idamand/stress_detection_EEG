# %%
from prepare_data import prepare_data
from features import time_series_features, hjorth_features
from classifiers import svm

# %%
data_type = 'raw'
label_type = 'STAI'
epoch_duration = 2

train_data, train_labels, test_data, test_labels = prepare_data(data_type=data_type, label_type=label_type, epoch_duration=epoch_duration)
# Out:
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# ...

# %%
train_h_feature = hjorth_features(train_data)
test_h_feature = hjorth_features(test_data)

# %%
svm(train_data=train_h_feature, test_data=test_h_feature, train_labels=train_labels, test_labels=test_labels)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/idaandreassen/Desktop/MASTER/stress_detection_EEG/test.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/idaandreassen/Desktop/MASTER/stress_detection_EEG/test.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> svm(train_data=train_h_feature, test_data=test_h_feature, train_labels=train_labels, test_labels=test_labels)
#
# File ~/Desktop/MASTER/stress_detection_EEG/classifiers.py:54, in svm(train_data, test_data, train_labels, test_labels)
#      51 test_data = scaler.transform(test_data)
#      53 svm_clf = GridSearchCV(SVC(), param_grid=param_grid, refit=True, n_jobs=-1, cv=10)
# ---> 54 svm_clf.fit(train_data, train_labels)
#      56 y_pred = svm_clf.predict(test_data)
#      57 y_true = test_labels
#
# ...
